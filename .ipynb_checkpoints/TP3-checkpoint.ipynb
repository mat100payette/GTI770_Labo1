# %% [markdown]
# # GTI770 - TP2

# %%
# %matplotlib inline   
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
import graphviz
import decimal
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import optimizers as opt

from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import GridSearchCV

# from sklearn import tree
# from sklearn.naive_bayes import GaussianNB
# from sklearn.naive_bayes import MultinomialNB
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.ensemble import RandomForestClassifier
# from mdlp.discretization import MDLP
# from sklearn.preprocessing import MinMaxScaler

# %%
#Utility methods
def SplitVectorData_Holdout(primitives_vector, train_portion):
    
    size = len(primitives_vector)
    subsize = len(primitives_vector[0])
    
    val_portion = (1 - train_portion) / 2
    test_portion = (1 - train_portion) / 2

    nbTrain = int(size * train_portion)
    nbVal = int(size * val_portion)
    nbTest = int(size * test_portion)

    array_train = np.zeros((nbTrain, subsize), dtype=np.float64)
    array_val = np.zeros((nbVal, subsize), dtype=np.float64)
    array_test = np.zeros((nbTest, subsize), dtype=np.float64)

    array_train = primitives_vector[:nbTrain]
    array_val = primitives_vector[nbTrain : nbTrain + nbVal]
    array_test = primitives_vector[-nbTest:]
    return array_train, array_val, array_test

def SplitVectorData_KFold(primitives_vector, k, test_portion):
    
    size = len(primitives_vector)
    subsize = len(primitives_vector[0])
    subsetNb = int(size * (1 - test_portion) / k)
    testNb = int(size * test_portion)
    
    array_kfold_train = np.zeros((k, subsetNb, subsize), dtype=np.float64)
    array_kfold_test = np.zeros((testNb, subsize), dtype=np.float64)
    
    for i in range(0, k):
        if i == 0 :
            array_kfold_train[i] = primitives_vector[i * subsetNb]
        else :
            array_kfold_train[i] = primitives_vector[(i-1) * subsetNb : i * subsetNb]
    
    array_kfold_test = primitives_vector[-testNb:]

    return array_kfold_train, array_kfold_test

def concatenateWithoutTestPortion(full_array, index):
    result_array = []
    for i in range(0, len(full_array)):
        if len(result_array) == 0:
            result_array = full_array[i]
        elif i != index :
            result_array = np.concatenate((result_array, full_array[i]), axis=0)
    return result_array

def scores_mean(array_scores):
    
    size = len(array_scores)
    subsize = len(array_scores[0])
    array_mean = np.zeros(subsize, dtype=float)
    
    for i in range(0, size):
        for j in range(0, subsize):
            array_mean[j] += array_scores[i][j]
            
    for j in range(0, subsize):
            array_mean[j] = array_mean[j] / size
    
    return array_mean

def UseModelOnTestData(array, model, transformer=None):
    array_train, array_val, array_test = SplitVectorData_Holdout(array, 0.6)
    if transformer is not None:
        transform_train, transform_val, transform_test, Y_train, Y_val, Y_test = TransformData(array_train, array_val, array_test, len(array_train[0]), transformer)
    array_model_result, array_prediction_train_result, array_prediction_val_result, array_prediction_test_result, array_train_result, array_val_result, array_test_result = GenerateModelDataFromTransform(transform_train, transform_val, transform_test, Y_train, Y_val, Y_test, len(array[0]), model)
    result = [[array_test_result, array_prediction_test_result]]
    return GenerateScores(result) 

# ----- For debug -----
#Filter_train, Filter_val, Filter_test = SplitVectorDataTrainValTest(Filter, 0.6)
#print(len(Filter_train))
#print(len(Filter_val))
#print(len(Filter_test))
#print(len(Filter))
#----------------------

# %%
#Transforms and Models generation methods
def GenerateModelDataFromVector(array_train, array_val, array_test, num_features, chosen_model):
    
    num_features = num_features - 1
    
    data_train = array_train
    X_train  = data_train[:,0:num_features]
    Y_train  = data_train[:,num_features]
    
    data_val = array_val
    X_val = data_val[:,0:num_features]
    Y_val = data_val[:,num_features]
    
    data_test = array_test
    X_test = data_test[:,0:num_features]
    Y_test = data_test[:,num_features]
    
    
    model = chosen_model
    model = model.fit(X_train, Y_train)
    prediction_train = model.predict(X_train)
    prediction_val = model.predict(X_val)
    prediction_test = model.predict(X_test)
    return model, prediction_train, prediction_val, prediction_test, Y_train, Y_val, Y_test

def TransformData(array_train, array_val, array_test, num_features, chosen_transformer):
    
    num_features = num_features - 1
    
    data_train = array_train
    X_train  = data_train[:,0:num_features]
    Y_train  = data_train[:,num_features]
    
    data_val = array_val
    X_val  = data_val[:,0:num_features]
    Y_val  = data_val[:,num_features]
    
    data_test = array_test
    X_test  = data_test[:,0:num_features]
    Y_test  = data_test[:,num_features]
    
    transformer_train = chosen_transformer
    transformer_train = transformer_train.fit_transform(X_train, Y_train)
    
    transformer_val = chosen_transformer
    transformer_val = transformer_val.fit_transform(X_val, Y_val)
    
    transformer_test = chosen_transformer
    transformer_test = transformer_test.fit_transform(X_test, Y_test)
    return transformer_train, transformer_val, transformer_test, Y_train, Y_val, Y_test

def GenerateModelDataFromTransform(array_train, array_val, array_test, y_train, y_val, y_test, num_features, chosen_model):
    
    num_features = num_features - 1
    
    X_train  = array_train
    Y_train = y_train
    
    X_val = array_val
    Y_val = y_val
    
    X_test  = array_test
    Y_test = y_test
    
    model = chosen_model
    model = model.fit(X_train, Y_train)
    prediction_train = model.predict(X_train)
    prediction_val = model.predict(X_val)
    prediction_test = model.predict(X_test)
    return model, prediction_train, prediction_val, prediction_test, Y_train, Y_val, Y_test

# %%
#display methods
def ExportTree(model):
    dot_data = tree.export_graphviz(model, out_file=None, 
                         #feature_names = ['', '', ''],  
                         class_names = ['spam', 'mail'],
                         filled=True, rounded=True,  
                         special_characters=True)  
    graph = graphviz.Source(dot_data)
    graph.format = 'png'
    graph.render("Filter_data") 
    return graph

def GenerateScores(array):
    AccScores = np.zeros(len(array), dtype=float)
    F1Scores = np.zeros(len(array), dtype=float)

    for i in range(0, len(array)):
        AccScores[i] = accuracy_score(array[i][0], array[i][1])
        F1Scores[i] = f1_score(array[i][0], array[i][1], average='weighted')
    
    return AccScores, F1Scores

def GenerateAccScores(array):
    AccScores = np.zeros(len(array), dtype=float)

    for i in range(0, len(array)):
        AccScores[i] = accuracy_score(array[i][0], array[i][1])
    
    return AccScores

#Extraction de primitive
def TracePlot(array_acc_X, array_acc_Y, array_f1_X, array_f1_Y, titre, titre_x, titre_y):        
    
    plt.plot(array_acc_X, array_acc_Y, 'ro')
    plt.plot(array_f1_X, array_f1_Y, 'g*')
    plt.xlabel(titre_x)
    plt.ylabel(titre_y)
    plt.legend(['Accuracy Score','F1 Score'])
    plt.title(titre)
    plt.grid(True)
    plt.show()

# %%
#model creations methods
def CreateDecisionTreeModel(depth):
    return tree.DecisionTreeClassifier(criterion='entropy', max_depth=depth, min_samples_leaf=1)

def CreateKNNModel(k, weight):
    return KNeighborsClassifier(n_neighbors=k, weights=weight)

def CreateRandomForestModel(depth):
    return RandomForestClassifier(criterion='entropy', max_depth=depth, random_state=0)

# %%
#Decision tree methods
def DecisionTree_Holdout(array):
    array_train, array_val, array_test = SplitVectorData_Holdout(array, 0.6)

    array_model_none, array_prediction_train_none, array_prediction_val_none, array_prediction_test_none, array_train_none, array_val_none, array_test_none = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateDecisionTreeModel(None))
    array_model_3, array_prediction_train_3, array_prediction_val_3, array_prediction_test_3, array_train_3, array_val_3, array_test_3 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateDecisionTreeModel(3))
    array_model_5, array_prediction_train_5, array_prediction_val_5, array_prediction_test_5, array_train_5, array_val_5, array_test_5 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateDecisionTreeModel(5))
    array_model_10, array_prediction_train_10, array_prediction_val_10, array_prediction_test_10, array_train_10, array_val_10, array_test_10 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateDecisionTreeModel(10))

    validations = [[array_val_none, array_prediction_val_none],
    [array_val_3, array_prediction_val_3],
    [array_val_5, array_prediction_val_5],
    [array_val_10, array_prediction_val_10]]

    return GenerateScores(validations)

def DecisionTree_KFold(array,k):

    array_kfold_train, array_kfold_test = SplitVectorData_KFold(array, k, 0.2)
    all_accScores = np.zeros((k, 4), dtype=float)
    all_f1Scores = np.zeros((k, 4), dtype=float)

    for i in range(1, k):

        array_train = concatenateWithoutTestPortion(array_kfold_train, i)
        array_val = array_kfold_train[i]
        array_test = array_kfold_test

        array_model_none, array_prediction_train_none, array_prediction_val_none, array_prediction_test_none, array_train_none, array_val_none, array_test_none = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateDecisionTreeModel(None))
        array_model_3, array_prediction_train_3, array_prediction_val_3, array_prediction_test_3, array_train_3, array_val_3, array_test_3 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateDecisionTreeModel(3))
        array_model_5, array_prediction_train_5, array_prediction_val_5, array_prediction_test_tree_5, array_train_5, array_val_5, array_test_5 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateDecisionTreeModel(5))
        array_model_10, array_prediction_train_10, array_prediction_val_10, array_prediction_test_tree_10, array_train_10, array_val_10, array_test_10 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateDecisionTreeModel(10))

        validations = [[array_val_none, array_prediction_val_none],
        [array_val_3, array_prediction_val_3],
        [array_val_5, array_prediction_val_5],
        [array_val_10, array_prediction_val_10]]

        Array_AccScores, Array_F1Scores = GenerateScores(validations)

        all_accScores[i] = Array_AccScores
        all_f1Scores[i] = Array_F1Scores

    accScores_mean = scores_mean(all_accScores)
    f1Scores_mean = scores_mean(all_f1Scores)
    
    return accScores_mean, f1Scores_mean

# %%
#Bayes Methods
def Bayes_Holdout(array, array_prob ,array_transform=None):
    array_train, array_val, array_test = SplitVectorData_Holdout(array, 0.6)
    if array_transform is not None:
        array_train_tr, array_val_tr, array_test_tr = SplitVectorData_Holdout(array_transform, 0.6)

    transform_train_mdlp, transform_val_mdlp, transform_test_mdlp, Y_train_mdlp, Y_val_mdlp, Y_test_mdlp = TransformData(array_train, array_val, array_test, len(array_train[0]), MDLP())
    transform_train_minmax, transform_val_minmax, transform_test_minmax, Y_train_minmax, Y_val_minmax, Y_test_minmax = TransformData(array_train, array_val, array_test, len(array_train[0]), MinMaxScaler())

    array_model_5, array_prediction_train_5, array_prediction_val_5, array_prediction_test_5, array_train_5, array_val_5, array_test_5 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), GaussianNB(priors=array_prob))
    if array_transform is not None:
        array_model_10, array_prediction_train_10, array_prediction_val_10, array_prediction_test_10, array_train_10, array_val_10, array_test_10 = GenerateModelDataFromVector(array_train_tr, array_val_tr, array_test_tr, len(array[0]), MultinomialNB(fit_prior=True, class_prior=array_prob))
    else:
        array_model_10, array_prediction_train_10, array_prediction_val_10, array_prediction_test_10, array_train_10, array_val_10, array_test_10 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), MultinomialNB(fit_prior=True, class_prior=array_prob))

    array_model_mdlp, array_prediction_train_mdlp, array_prediction_val_mdlp, array_prediction_test_mdlp, array_train_mdlp, array_val_mdlp, array_test_mdlp = GenerateModelDataFromTransform(transform_train_mdlp, transform_val_mdlp, transform_test_mdlp, Y_train_mdlp, Y_val_mdlp, Y_test_mdlp, len(array[0]), MultinomialNB())
    array_model_minmax, array_prediction_train_minmax, array_prediction_val_minmax, array_prediction_test_minmax, array_train_minmax, array_val_minmax, array_test_minmax = GenerateModelDataFromTransform(transform_train_minmax, transform_val_minmax, transform_test_minmax, Y_train_minmax, Y_val_minmax, Y_test_minmax, len(array[0]), MultinomialNB())


    validations = [[array_val_5, array_prediction_val_5],
    [array_val_10, array_prediction_val_10],
    [array_val_mdlp, array_prediction_val_mdlp],
    [array_val_minmax, array_prediction_val_minmax]]

    return GenerateScores(validations)  
    
def Bayes_KFold(array, array_prob, k, array_transform=None):
    
    array_kfold_train, array_kfold_test = SplitVectorData_KFold(array, k, 0.2)
    if array_transform is not None:
        array_kfold_train_tr, array_kfold_test_tr = SplitVectorData_KFold(array_transform, k, 0.2)
    all_accScores = np.zeros((k, 4), dtype=float)
    all_f1Scores = np.zeros((k, 4), dtype=float)

    for i in range(1, k):

        array_train = concatenateWithoutTestPortion(array_kfold_train, i)
        array_val = array_kfold_train[i]
        array_test = array_kfold_test
        
        if array_transform is not None:
            array_train_tr = concatenateWithoutTestPortion(array_kfold_train_tr, i)
            array_val_tr = array_kfold_train_tr[i]
            array_test_tr = array_kfold_test_tr

        transform_train_mdlp, transform_val_mdlp, transform_test_mdlp, Y_train_mdlp, Y_val_mdlp, Y_test_mdlp = TransformData(array_train, array_val, array_test, len(array_train[0]), MDLP())
        transform_train_minmax, transform_val_minmax, transform_test_minmax, Y_train_minmax, Y_val_minmax, Y_test_minmax = TransformData(array_train, array_val, array_test, len(array_train[0]), MinMaxScaler())

        array_model_5, array_prediction_train_5, array_prediction_val_5, array_prediction_test_5, array_train_5, array_val_5, array_test_5 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), GaussianNB(priors=array_prob))
        if array_transform is not None:
            array_model_10, array_prediction_train_10, array_prediction_val_10, array_prediction_test_10, array_train_10, array_val_10, array_test_10 = GenerateModelDataFromVector(array_train_tr, array_val_tr, array_test_tr, len(array[0]), MultinomialNB(fit_prior=True, class_prior=array_prob))
        else:
            array_model_10, array_prediction_train_10, array_prediction_val_10, array_prediction_test_10, array_train_10, array_val_10, array_test_10 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), MultinomialNB(fit_prior=True, class_prior=array_prob))
        array_model_mdlp, array_prediction_train_mdlp, array_prediction_val_mdlp, array_prediction_test_mdlp, array_train_mdlp, array_val_mdlp, array_test_mdlp = GenerateModelDataFromTransform(transform_train_mdlp, transform_val_mdlp, transform_test_mdlp, Y_train_mdlp, Y_val_mdlp, Y_test_mdlp, len(array[0]), MultinomialNB())
        array_model_minmax, array_prediction_train_minmax, array_prediction_val_minmax, array_prediction_test_minmax, array_train_minmax, array_val_minmax, array_test_minmax = GenerateModelDataFromTransform(transform_train_minmax, transform_val_minmax, transform_test_minmax, Y_train_minmax, Y_val_minmax, Y_test_minmax, len(array[0]), MultinomialNB())


        validations = [[array_val_5, array_prediction_val_5],
                     [array_val_10, array_prediction_val_10],
                     [array_val_mdlp, array_prediction_val_mdlp],
                     [array_val_minmax, array_prediction_val_minmax]]

        Array_AccScores, Array_F1Scores = GenerateScores(validations)

        all_accScores[i] = Array_AccScores
        all_f1Scores[i] = Array_F1Scores 
        
    accScores_mean = scores_mean(all_accScores)
    f1Scores_mean = scores_mean(all_f1Scores)

    return accScores_mean, f1Scores_mean

# %%
#KNN Methods
def KNN_Holdout(array):
    array_train, array_val, array_test = SplitVectorData_Holdout(array, 0.6)

    array_model_3u, array_prediction_train_3u, array_prediction_val_3u, array_prediction_test_3u, array_train_3u, array_val_3u, array_test_3u = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateKNNModel(3, 'uniform'))
    array_model_5u, array_prediction_train_5u, array_prediction_val_5u, array_prediction_test_5u, array_train_5u, array_val_5u, array_test_5u = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateKNNModel(5, 'uniform'))
    array_model_10u, array_prediction_train_10u, array_prediction_val_10u, array_prediction_test_10u, array_train_10u, array_val_10u, array_test_10u = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateKNNModel(10, 'uniform'))
    array_model_3d, array_prediction_train_3d, array_prediction_val_3d, array_prediction_test_3d, array_train_3d, array_val_3d, array_test_3d = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateKNNModel(3, 'distance'))
    array_model_5d, array_prediction_train_5d, array_prediction_val_5d, array_prediction_test_5d, array_train_5d, array_val_5d, array_test_5d = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateKNNModel(5, 'distance'))
    array_model_10d, array_prediction_train_10d, array_prediction_val_10d, array_prediction_test_10d, array_train_10d, array_val_10d, array_test_10d = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateKNNModel(10, 'distance'))

    validations_uniform = [[array_val_3u, array_prediction_val_3u],
                        [array_val_5u, array_prediction_val_5u],
                        [array_val_10u, array_prediction_val_10u]]

    validations_distance = [[array_val_3d, array_prediction_val_3d],
                        [array_val_5d, array_prediction_val_5d],
                        [array_val_10d, array_prediction_val_10d]]

    accScores_uniform, f1Scores_uniform = GenerateScores(validations_uniform)
    accScores_distance, f1Scores_dsitance = GenerateScores(validations_distance)

    return accScores_uniform, f1Scores_uniform, accScores_distance, f1Scores_dsitance
    
def KNN_KFold(array, k):

    array_kfold_train, array_kfold_test = SplitVectorData_KFold(array, k, 0.2)
    all_accScores_uniform = np.zeros((k, 3), dtype=float)
    all_f1Scores_uniform = np.zeros((k, 3), dtype=float)
    all_accScores_distance = np.zeros((k, 3), dtype=float)
    all_f1Scores_distance = np.zeros((k, 3), dtype=float)

    for i in range(1, k):

        array_train = concatenateWithoutTestPortion(array_kfold_train, i)
        array_val = array_kfold_train[i]
        array_test = array_kfold_test

        array_model_3u, array_prediction_train_3u, array_prediction_val_3u, array_prediction_test_3u, array_train_3u, array_val_3u, array_test_3u = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateKNNModel(3, 'uniform'))
        array_model_5u, array_prediction_train_5u, array_prediction_val_5u, array_prediction_test_5u, array_train_5u, array_val_5u, array_test_5u = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateKNNModel(5, 'uniform'))
        array_model_10u, array_prediction_train_10u, array_prediction_val_10u, array_prediction_test_10u, array_train_10u, array_val_10u, array_test_10u = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateKNNModel(10, 'uniform'))
        array_model_3d, array_prediction_train_3d, array_prediction_val_3d, array_prediction_test_3d, array_train_3d, array_val_3d, array_test_3d = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateKNNModel(3, 'distance'))
        array_model_5d, array_prediction_train_5d, array_prediction_val_5d, array_prediction_test_5d, array_train_5d, array_val_5d, array_test_5d = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateKNNModel(5, 'distance'))
        array_model_10d, array_prediction_train_10d, array_prediction_val_10d, array_prediction_test_10d, array_train_10d, array_val_10d, array_test_10d = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateKNNModel(10, 'distance'))

        validations_uniform = [[array_val_3u, array_prediction_val_3u],
        [array_val_5u, array_prediction_val_5u],
        [array_val_10u, array_prediction_val_10u]]

        validations_distance = [[array_val_3d, array_prediction_val_3d],
        [array_val_5d, array_prediction_val_5d],
        [array_val_10d, array_prediction_val_10d]]

        Array_AccScores_uniform, Array_F1Scores_uniform = GenerateScores(validations_uniform)
        Array_AccScores_distance, Array_F1Scores_distance = GenerateScores(validations_distance)

        all_accScores_uniform[i] = Array_AccScores_uniform
        all_f1Scores_uniform[i] = Array_F1Scores_uniform
        all_accScores_distance[i] = Array_AccScores_distance
        all_f1Scores_distance[i] = Array_F1Scores_distance

    accScores_mean_uniform = scores_mean(all_accScores_uniform)
    f1Scores_mean_uniform = scores_mean(all_f1Scores_uniform)
    accScores_mean_distance = scores_mean(all_accScores_distance)
    f1Scores_mean_distance = scores_mean(all_f1Scores_distance)

    return accScores_mean_uniform, f1Scores_mean_uniform, accScores_mean_distance, f1Scores_mean_distance

# %%
#Random forest methods
def RandomForest_Holdout(array):
    array_train, array_val, array_test = SplitVectorData_Holdout(array, 0.6)

    array_model_none, array_prediction_train_none, array_prediction_val_none, array_prediction_test_none, array_train_none, array_val_none, array_test_none = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateRandomForestModel(None))
    array_model_3, array_prediction_train_3, array_prediction_val_3, array_prediction_test_3, array_train_3, array_val_3, array_test_3 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateRandomForestModel(3))
    array_model_5, array_prediction_train_5, array_prediction_val_5, array_prediction_test_5, array_train_5, array_val_5, array_test_5 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateRandomForestModel(5))
    array_model_10, array_prediction_train_10, array_prediction_val_10, array_prediction_test_10, array_train_10, array_val_10, array_test_10 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateRandomForestModel(10))

    validations = [[array_val_none, array_prediction_val_none],
    [array_val_3, array_prediction_val_3],
    [array_val_5, array_prediction_val_5],
    [array_val_10, array_prediction_val_10]]

    return GenerateScores(validations)

def RandomForest_KFold(array,k):

    array_kfold_train, array_kfold_test = SplitVectorData_KFold(array, k, 0.2)
    all_accScores = np.zeros((k, 4), dtype=float)
    all_f1Scores = np.zeros((k, 4), dtype=float)

    for i in range(1, k):

        array_train = concatenateWithoutTestPortion(array_kfold_train, i)
        array_val = array_kfold_train[i]
        array_test = array_kfold_test

        array_model_none, array_prediction_train_none, array_prediction_val_none, array_prediction_test_none, array_train_none, array_val_none, array_test_none = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateRandomForestModel(None))
        array_model_3, array_prediction_train_3, array_prediction_val_3, array_prediction_test_3, array_train_3, array_val_3, array_test_3 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateRandomForestModel(3))
        array_model_5, array_prediction_train_5, array_prediction_val_5, array_prediction_test_tree_5, array_train_5, array_val_5, array_test_5 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateRandomForestModel(5))
        array_model_10, array_prediction_train_10, array_prediction_val_10, array_prediction_test_tree_10, array_train_10, array_val_10, array_test_10 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateRandomForestModel(10))

        validations = [[array_val_none, array_prediction_val_none],
        [array_val_3, array_prediction_val_3],
        [array_val_5, array_prediction_val_5],
        [array_val_10, array_prediction_val_10]]

        Array_AccScores, Array_F1Scores = GenerateScores(validations)

        all_accScores[i] = Array_AccScores
        all_f1Scores[i] = Array_F1Scores

    accScores_mean = scores_mean(all_accScores)
    f1Scores_mean = scores_mean(all_f1Scores)
    
    return accScores_mean, f1Scores_mean

# %%
# accScores_filter_tree_holdout, f1Scores_filter_tree_holdout = DecisionTree_Holdout(Filter)
# accScores_filter_tree_kfold, f1Scores_filter_tree_kfold = DecisionTree_KFold(Filter,10)
# accScores_filter_bayes_holdout, f1Scores_filter_bayes_holdout = Bayes_Holdout(Filter, [0.4003,0.5997])
# accScores_filter_bayes_kfold, f1Scores_filter_bayes_kfold = Bayes_KFold(Filter, [0.4003,0.5997], 10)
# accScores_filter_knn_holdout_uniform, f1Scores_filter_knn_holdout_uniform, accScores_filter_knn_holdout_distance, f1Scores_filter_knn_holdout_distance = KNN_Holdout(Filter)
# accScores_filter_knn_kfold_uniform, f1Scores_filter_knn_kfold_uniform, accScores_filter_knn_kfold_distance, f1Scores_filter_knn_kfold_distance = KNN_KFold(Filter, 10) 
# accScores_filter_test, f1Scores_filter_test = UseModelOnTestData(Filter, MultinomialNB(), MinMaxScaler())
# accScores_filter_forest_holdout, f1Scores_filter_forest_holdout = RandomForest_Holdout(Filter)
# accScores_filter_forest_kfold, f1Scores_filter_forest_kfold = RandomForest_KFold(Filter,10)

# %% [markdown]
# ### Galaxies

# %%
# Get some galaxies
fid = open('galaxy_feature_vectors.csv', 'r') 

NbGalaxy = 1000 #16000 total
Galaxies = np.zeros((NbGalaxy, 7), dtype=np.float64)

count = 0
count_smooth = 0
count_spiral = 0

for line in fid:
    element = line.rstrip('\n').split(',')
    
    label = float(element[75])
    
    if label == 0.0 and count_smooth < NbGalaxy/2:
        count_smooth += 1     
    elif label == 1.0 and count_spiral < NbGalaxy/2:
        count_spiral += 1
    else:
        continue

    Galaxies[count] = [element[4], element[5], element[6], element[17], element[23], element[24], element[75]]
        
    count += 1
    if count >= NbGalaxy:
        break

fid.close() 

# ----- For debug -----
#print(count_smooth)
#print(count_spiral)
#print(count)
#print(Galaxies)
#----------------------

# %%
def NormalizeData(data):
    transform = MinMaxScaler()
    return transform.fit_transform(data, data[:,len(Galaxies[0])-1])

def GetGalaxiesClassProbabilities():
    count_smooth = 0
    count_spiral = 0
    
    fid = open('galaxy_feature_vectors.csv', 'r') 
    for line in fid:
        element = line.rstrip('\n').split(',')

        label = float(element[75])

        if label == 0.0:
            count_smooth += 1     
        elif label == 1.0:
            count_spiral += 1
    return [count_smooth/(count_smooth+count_spiral), count_spiral/(count_smooth+count_spiral)]

# %%
def SplitLabelsFromPrimitives(data_train, data_val, data_test):
    num_features = len(data_train[0]) - 1
    
    X_train  = data_train[:,0:num_features]
    Y_train  = data_train[:,num_features]

    X_val  = data_val[:,0:num_features]
    Y_val  = data_val[:,num_features]

    X_test  = data_test[:,0:num_features]
    Y_test  = data_test[:,num_features]
    return X_train, Y_train, X_val, Y_val, X_test, Y_test

def GenerateModel(data_train, data_val, data_test, layers, perceptrons, epochs, learnRate, name):
    
    #Split labels from the primitives
    X_train, Y_train, X_val, Y_val, X_test, Y_test = SplitLabelsFromPrimitives(data_train, data_val, data_test)
    
    #Create model
    model = Sequential()

    #Add layers
    model.add(Dense(units=perceptrons, activation='sigmoid', input_shape=(len(X_train[0]),)))
    model.add(Dropout(0.2))
    for i in range(0, layers - 2):
        model.add(Dense(units=perceptrons, activation='sigmoid'))
        model.add(Dropout(0.2))
    model.add(Dense(units=2, activation='sigmoid'))
    
    #Set optimizers and compile
    sgd = opt.SGD(lr=learnRate, decay=0, momentum=0, nesterov=False)
    model.compile(loss='sparse_categorical_crossentropy', 
              optimizer= sgd,
              metrics=['accuracy'])
    
    #Use TensorBoard
    tb_callback = tf.keras.callbacks.TensorBoard(log_dir='./logs/'+name)
    
    #Train
    model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=epochs, batch_size=100, callbacks=[tb_callback])
    
    model.evaluate(X_test, Y_test)
    
    Y_probs = model.predict(X_test)
    
    Y_pred = Y_probs.argmax(axis=1)
    
    #plt.scatter(X_test[:, 0], X_test[:, 1], c=Y_pred)
    #plt.scatter(X_test[:, 0], X_test[:, 1], c=Y_test)

    return Y_test, Y_pred

def Neurone_Holdout(array):
    array_train, array_val, array_test = SplitVectorData_Holdout(array, 0.6)
    
    AccScores = np.zeros(13, dtype=float)
    
    #base
    y_true_base, y_pred_base = GenerateModel(array_train, array_val, array_test, 4, 100, 60, 0.0005, 'base')
    
    #perceptrons
    y_true_perc1, y_pred_perc1 = GenerateModel(array_train, array_val, array_test, 4, 50, 60, 0.0005, 'perc1')
    y_true_perc2, y_pred_perc2 = GenerateModel(array_train, array_val, array_test, 4, 300, 60, 0.0005, 'perc2')
    y_true_perc3, y_pred_perc3 = GenerateModel(array_train, array_val, array_test, 4, 600, 60, 0.0005, 'perc3')

    #epochs
    y_true_epoch1, y_pred_epoch1 = GenerateModel(array_train, array_val, array_test, 4, 100, 30, 0.0005, 'epoch1')
    y_true_epoch2, y_pred_epoch2 = GenerateModel(array_train, array_val, array_test, 4, 100, 120, 0.0005, 'epoch2')
    y_true_epoch3, y_pred_epoch3 = GenerateModel(array_train, array_val, array_test, 4, 100, 240, 0.0005, 'epoch3')
    
    #layers
    y_true_layer1, y_pred_layer1 = GenerateModel(array_train, array_val, array_test, 6, 100, 60, 0.0005, 'layer1')
    y_true_layer2, y_pred_layer2 = GenerateModel(array_train, array_val, array_test, 12, 100, 60, 0.0005, 'layer2')
    y_true_layer3, y_pred_layer3 = GenerateModel(array_train, array_val, array_test, 24, 100, 60, 0.0005, 'layer3')
    
    #learning rate
    y_true_lr1, y_pred_lr1 = GenerateModel(array_train, array_val, array_test, 4, 100, 60, 0.1, 'lr1')
    y_true_lr2, y_pred_lr2 = GenerateModel(array_train, array_val, array_test, 4, 100, 60, 0.5, 'lr2')
    y_true_lr3, y_pred_lr3 = GenerateModel(array_train, array_val, array_test, 4, 100, 60, 1, 'lr3')

    validations = [[y_true_base, y_pred_base],
    [y_true_perc1, y_pred_perc1],
    [y_true_perc2, y_pred_perc2],
    [y_true_perc3, y_pred_perc3],
    [y_true_epoch1, y_pred_epoch1],
    [y_true_epoch2, y_pred_epoch2],
    [y_true_epoch3, y_pred_epoch3],
    [y_true_layer1, y_pred_epoch1],
    [y_true_layer2, y_pred_layer2],
    [y_true_layer3, y_pred_layer3],
    [y_true_lr1, y_pred_lr1],
    [y_true_lr2, y_pred_lr2],
    [y_true_lr3, y_pred_lr3]]
    
    return GenerateAccScores(validations)
    
def Neurone_KFold(array,k):

    array_kfold_train, array_kfold_test = SplitVectorData_KFold(array, k, 0.2)
    all_accScores = np.zeros((k, 13), dtype=float)
    all_f1Scores = np.zeros((k, 13), dtype=float)

    for i in range(1, k):

        array_train = concatenateWithoutTestPortion(array_kfold_train, i)
        array_val = array_kfold_train[i]
        array_test = array_kfold_test
        
        #base
        y_true_base, y_pred_base = GenerateModel(array_train, array_val, array_test, 4, 100, 60, 0.0005, 'kfold/k'+str(i)+'_base')

        #perceptrons
        y_true_perc1, y_pred_perc1 = GenerateModel(array_train, array_val, array_test, 4, 50, 60, 0.0005, 'kfold/k'+str(i)+'_perc1')
        y_true_perc2, y_pred_perc2 = GenerateModel(array_train, array_val, array_test, 4, 300, 60, 0.0005, 'kfold/k'+str(i)+'_perc2')
        y_true_perc3, y_pred_perc3 = GenerateModel(array_train, array_val, array_test, 4, 600, 60, 0.0005, 'kfold/k'+str(i)+'_perc3')

        #epochs
        y_true_epoch1, y_pred_epoch1 = GenerateModel(array_train, array_val, array_test, 4, 100, 30, 0.0005, 'kfold/k'+str(i)+'_epoch1')
        y_true_epoch2, y_pred_epoch2 = GenerateModel(array_train, array_val, array_test, 4, 100, 120, 0.0005, 'kfold/k'+str(i)+'_epoch2')
        y_true_epoch3, y_pred_epoch3 = GenerateModel(array_train, array_val, array_test, 4, 100, 240, 0.0005, 'kfold/k'+str(i)+'_epoch3')

        #layers
        y_true_layer1, y_pred_layer1 = GenerateModel(array_train, array_val, array_test, 6, 100, 60, 0.0005, 'kfold/k'+str(i)+'_layer1')
        y_true_layer2, y_pred_layer2 = GenerateModel(array_train, array_val, array_test, 12, 100, 60, 0.0005, 'kfold/k'+str(i)+'_layer2')
        y_true_layer3, y_pred_layer3 = GenerateModel(array_train, array_val, array_test, 24, 100, 60, 0.0005, 'kfold/k'+str(i)+'_layer3')

        #learning rate
        y_true_lr1, y_pred_lr1 = GenerateModel(array_train, array_val, array_test, 4, 100, 60, 0.1, 'kfold/k'+str(i)+'_lr1')
        y_true_lr2, y_pred_lr2 = GenerateModel(array_train, array_val, array_test, 4, 100, 60, 0.5, 'kfold/k'+str(i)+'_lr2')
        y_true_lr3, y_pred_lr3 = GenerateModel(array_train, array_val, array_test, 4, 100, 60, 1, 'kfold/k'+str(i)+'_lr3')

        validations = [[y_true_base, y_pred_base],
        [y_true_perc1, y_pred_perc1],
        [y_true_perc2, y_pred_perc2],
        [y_true_perc3, y_pred_perc3],
        [y_true_epoch1, y_pred_epoch1],
        [y_true_epoch2, y_pred_epoch2],
        [y_true_epoch3, y_pred_epoch3],
        [y_true_layer1, y_pred_epoch1],
        [y_true_layer2, y_pred_layer2],
        [y_true_layer3, y_pred_layer3],
        [y_true_lr1, y_pred_lr1],
        [y_true_lr2, y_pred_lr2],
        [y_true_lr3, y_pred_lr3]]

        Array_AccScores = GenerateAccScores(validations)

        all_accScores[i] = Array_AccScores

    accScores_mean = scores_mean(all_accScores)
    
    return accScores_mean

# %%
accScores_neurone_holdout = Neurone_Holdout(Galaxies)
# Out:
# Train on 600 samples, validate on 200 samples
# Epoch 1/60
# 600/600 [==============================] - 1s 1ms/step - loss: 1.0939 - acc: 0.4750 - val_loss: 1.0457 - val_acc: 0.4850
# Epoch 2/60
# 600/600 [==============================] - 0s 48us/step - loss: 1.0725 - acc: 0.4750 - val_loss: 1.0352 - val_acc: 0.4850
# Epoch 3/60
# 600/600 [==============================] - 0s 40us/step - loss: 1.0347 - acc: 0.4750 - val_loss: 1.0251 - val_acc: 0.4850
# Epoch 4/60
# 600/600 [==============================] - 0s 42us/step - loss: 1.0461 - acc: 0.4750 - val_loss: 1.0153 - val_acc: 0.4850
# Epoch 5/60
# 600/600 [==============================] - 0s 39us/step - loss: 1.0283 - acc: 0.4750 - val_loss: 1.0057 - val_acc: 0.4850
# Epoch 6/60
# 600/600 [==============================] - 0s 49us/step - loss: 1.0276 - acc: 0.4750 - val_loss: 0.9964 - val_acc: 0.4850
# Epoch 7/60
# 600/600 [==============================] - 0s 51us/step - loss: 1.0011 - acc: 0.4750 - val_loss: 0.9875 - val_acc: 0.4850
# Epoch 8/60
# 600/600 [==============================] - 0s 45us/step - loss: 0.9895 - acc: 0.4750 - val_loss: 0.9787 - val_acc: 0.4850
# Epoch 9/60
# 600/600 [==============================] - 0s 50us/step - loss: 0.9981 - acc: 0.4750 - val_loss: 0.9701 - val_acc: 0.4850
# Epoch 10/60
# 600/600 [==============================] - 0s 44us/step - loss: 0.9815 - acc: 0.4750 - val_loss: 0.9618 - val_acc: 0.4850
# Epoch 11/60
# 600/600 [==============================] - 0s 45us/step - loss: 0.9846 - acc: 0.4750 - val_loss: 0.9538 - val_acc: 0.4850
# Epoch 12/60
# 600/600 [==============================] - 0s 38us/step - loss: 0.9759 - acc: 0.4750 - val_loss: 0.9459 - val_acc: 0.4850
# Epoch 13/60
# 600/600 [==============================] - 0s 56us/step - loss: 0.9602 - acc: 0.4750 - val_loss: 0.9382 - val_acc: 0.4850
# Epoch 14/60
# 600/600 [==============================] - 0s 47us/step - loss: 0.9610 - acc: 0.4750 - val_loss: 0.9307 - val_acc: 0.4850
# Epoch 15/60
# 600/600 [==============================] - 0s 43us/step - loss: 0.9371 - acc: 0.4750 - val_loss: 0.9237 - val_acc: 0.4850
# Epoch 16/60
# 600/600 [==============================] - 0s 48us/step - loss: 0.9390 - acc: 0.4750 - val_loss: 0.9166 - val_acc: 0.4850
# Epoch 17/60
# 600/600 [==============================] - 0s 38us/step - loss: 0.9166 - acc: 0.4750 - val_loss: 0.9100 - val_acc: 0.4850
# Epoch 18/60
# 600/600 [==============================] - 0s 39us/step - loss: 0.9167 - acc: 0.4750 - val_loss: 0.9034 - val_acc: 0.4850
# Epoch 19/60
# 600/600 [==============================] - 0s 44us/step - loss: 0.9263 - acc: 0.4750 - val_loss: 0.8970 - val_acc: 0.4850
# Epoch 20/60
# 600/600 [==============================] - 0s 39us/step - loss: 0.9138 - acc: 0.4750 - val_loss: 0.8908 - val_acc: 0.4850
# Epoch 21/60
# 600/600 [==============================] - 0s 40us/step - loss: 0.9227 - acc: 0.4750 - val_loss: 0.8848 - val_acc: 0.4850
# Epoch 22/60
# 600/600 [==============================] - 0s 42us/step - loss: 0.9003 - acc: 0.4750 - val_loss: 0.8789 - val_acc: 0.4850
# Epoch 23/60
# 600/600 [==============================] - 0s 42us/step - loss: 0.8929 - acc: 0.4750 - val_loss: 0.8732 - val_acc: 0.4850
# Epoch 24/60
# 600/600 [==============================] - 0s 46us/step - loss: 0.8927 - acc: 0.4750 - val_loss: 0.8678 - val_acc: 0.4850
# Epoch 25/60
# 600/600 [==============================] - 0s 42us/step - loss: 0.8846 - acc: 0.4750 - val_loss: 0.8623 - val_acc: 0.4850
# Epoch 26/60
# 600/600 [==============================] - 0s 43us/step - loss: 0.8769 - acc: 0.4750 - val_loss: 0.8572 - val_acc: 0.4850
# Epoch 27/60
# 600/600 [==============================] - 0s 42us/step - loss: 0.8701 - acc: 0.4750 - val_loss: 0.8522 - val_acc: 0.4850
# Epoch 28/60
# 600/600 [==============================] - 0s 47us/step - loss: 0.8677 - acc: 0.4750 - val_loss: 0.8474 - val_acc: 0.4850
# Epoch 29/60
# 600/600 [==============================] - 0s 42us/step - loss: 0.8588 - acc: 0.4767 - val_loss: 0.8427 - val_acc: 0.4850
# Epoch 30/60
# 600/600 [==============================] - 0s 41us/step - loss: 0.8609 - acc: 0.4733 - val_loss: 0.8382 - val_acc: 0.4850
# Epoch 31/60
# 600/600 [==============================] - 0s 47us/step - loss: 0.8455 - acc: 0.4750 - val_loss: 0.8338 - val_acc: 0.4850
# Epoch 32/60
# 600/600 [==============================] - 0s 50us/step - loss: 0.8578 - acc: 0.4750 - val_loss: 0.8294 - val_acc: 0.4850
# Epoch 33/60
# 600/600 [==============================] - 0s 47us/step - loss: 0.8387 - acc: 0.4767 - val_loss: 0.8253 - val_acc: 0.4850
# Epoch 34/60
# 600/600 [==============================] - 0s 41us/step - loss: 0.8454 - acc: 0.4750 - val_loss: 0.8212 - val_acc: 0.4850
# Epoch 35/60
# 600/600 [==============================] - 0s 43us/step - loss: 0.8336 - acc: 0.4783 - val_loss: 0.8173 - val_acc: 0.4850
# Epoch 36/60
# 600/600 [==============================] - 0s 39us/step - loss: 0.8440 - acc: 0.4750 - val_loss: 0.8135 - val_acc: 0.4850
# Epoch 37/60
# 600/600 [==============================] - 0s 40us/step - loss: 0.8347 - acc: 0.4733 - val_loss: 0.8096 - val_acc: 0.4850
# Epoch 38/60
# 600/600 [==============================] - 0s 40us/step - loss: 0.8128 - acc: 0.4750 - val_loss: 0.8062 - val_acc: 0.4850
# Epoch 39/60
# 600/600 [==============================] - 0s 39us/step - loss: 0.8263 - acc: 0.4767 - val_loss: 0.8027 - val_acc: 0.4850
# Epoch 40/60
# 600/600 [==============================] - 0s 37us/step - loss: 0.8341 - acc: 0.4783 - val_loss: 0.7993 - val_acc: 0.4850
# Epoch 41/60
# 600/600 [==============================] - 0s 35us/step - loss: 0.8113 - acc: 0.4767 - val_loss: 0.7961 - val_acc: 0.4850
# Epoch 42/60
# 600/600 [==============================] - 0s 35us/step - loss: 0.8094 - acc: 0.4800 - val_loss: 0.7930 - val_acc: 0.4850
# Epoch 43/60
# 600/600 [==============================] - 0s 41us/step - loss: 0.8160 - acc: 0.4767 - val_loss: 0.7900 - val_acc: 0.4850
# Epoch 44/60
# 600/600 [==============================] - 0s 37us/step - loss: 0.8127 - acc: 0.4767 - val_loss: 0.7870 - val_acc: 0.4850
# Epoch 45/60
# 600/600 [==============================] - 0s 50us/step - loss: 0.7928 - acc: 0.4833 - val_loss: 0.7842 - val_acc: 0.4850
# Epoch 46/60
# 600/600 [==============================] - 0s 38us/step - loss: 0.8023 - acc: 0.4733 - val_loss: 0.7815 - val_acc: 0.4850
# Epoch 47/60
# 600/600 [==============================] - 0s 38us/step - loss: 0.8145 - acc: 0.4750 - val_loss: 0.7787 - val_acc: 0.4850
# Epoch 48/60
# 600/600 [==============================] - 0s 40us/step - loss: 0.8036 - acc: 0.4783 - val_loss: 0.7761 - val_acc: 0.4850
# Epoch 49/60
# 600/600 [==============================] - 0s 39us/step - loss: 0.7839 - acc: 0.4850 - val_loss: 0.7736 - val_acc: 0.4850
# Epoch 50/60
# 600/600 [==============================] - 0s 37us/step - loss: 0.7863 - acc: 0.4717 - val_loss: 0.7712 - val_acc: 0.4850
# Epoch 51/60
# 600/600 [==============================] - 0s 38us/step - loss: 0.7751 - acc: 0.4700 - val_loss: 0.7688 - val_acc: 0.4850
# Epoch 52/60
# 600/600 [==============================] - 0s 48us/step - loss: 0.7775 - acc: 0.4750 - val_loss: 0.7665 - val_acc: 0.4850
# Epoch 53/60
# 600/600 [==============================] - 0s 49us/step - loss: 0.7822 - acc: 0.4733 - val_loss: 0.7643 - val_acc: 0.4850
# Epoch 54/60
# 600/600 [==============================] - 0s 48us/step - loss: 0.7731 - acc: 0.4750 - val_loss: 0.7621 - val_acc: 0.4850
# Epoch 55/60
# 600/600 [==============================] - 0s 46us/step - loss: 0.7701 - acc: 0.4717 - val_loss: 0.7601 - val_acc: 0.4850
# Epoch 56/60
# 600/600 [==============================] - 0s 52us/step - loss: 0.7740 - acc: 0.4800 - val_loss: 0.7581 - val_acc: 0.4850
# Epoch 57/60
# 600/600 [==============================] - 0s 43us/step - loss: 0.7698 - acc: 0.4783 - val_loss: 0.7562 - val_acc: 0.4850
# Epoch 58/60
# 600/600 [==============================] - 0s 40us/step - loss: 0.7682 - acc: 0.4733 - val_loss: 0.7542 - val_acc: 0.4850
# Epoch 59/60
# 600/600 [==============================] - 0s 43us/step - loss: 0.7754 - acc: 0.4783 - val_loss: 0.7525 - val_acc: 0.4850
# Epoch 60/60
# 600/600 [==============================] - 0s 45us/step - loss: 0.7764 - acc: 0.4683 - val_loss: 0.7506 - val_acc: 0.4850
# 200/200 [==============================] - 0s 36us/step
# Train on 600 samples, validate on 200 samples
# Epoch 1/60
# 600/600 [==============================] - 1s 1ms/step - loss: 0.8508 - acc: 0.4750 - val_loss: 0.8270 - val_acc: 0.4850
# Epoch 2/60
# 600/600 [==============================] - 0s 36us/step - loss: 0.8458 - acc: 0.4750 - val_loss: 0.8249 - val_acc: 0.4850
# Epoch 3/60
# 600/600 [==============================] - 0s 33us/step - loss: 0.8490 - acc: 0.4750 - val_loss: 0.8227 - val_acc: 0.4850
# Epoch 4/60
# 600/600 [==============================] - 0s 23us/step - loss: 0.8362 - acc: 0.4717 - val_loss: 0.8206 - val_acc: 0.4850
# Epoch 5/60
# 600/600 [==============================] - 0s 31us/step - loss: 0.8265 - acc: 0.4750 - val_loss: 0.8185 - val_acc: 0.4850
# Epoch 6/60
# 600/600 [==============================] - 0s 30us/step - loss: 0.8493 - acc: 0.4750 - val_loss: 0.8165 - val_acc: 0.4850
# Epoch 7/60
# 600/600 [==============================] - 0s 30us/step - loss: 0.8370 - acc: 0.4733 - val_loss: 0.8145 - val_acc: 0.4850
# Epoch 8/60
# 600/600 [==============================] - 0s 31us/step - loss: 0.8528 - acc: 0.4750 - val_loss: 0.8125 - val_acc: 0.4850
# Epoch 9/60
# 600/600 [==============================] - 0s 40us/step - loss: 0.8286 - acc: 0.4767 - val_loss: 0.8106 - val_acc: 0.4850
# Epoch 10/60
# 600/600 [==============================] - 0s 42us/step - loss: 0.8359 - acc: 0.4767 - val_loss: 0.8087 - val_acc: 0.4850
# Epoch 11/60
# 600/600 [==============================] - 0s 32us/step - loss: 0.8290 - acc: 0.4767 - val_loss: 0.8068 - val_acc: 0.4850
# Epoch 12/60
# 600/600 [==============================] - 0s 43us/step - loss: 0.8101 - acc: 0.4733 - val_loss: 0.8050 - val_acc: 0.4850
# Epoch 13/60
# 600/600 [==============================] - 0s 36us/step - loss: 0.8320 - acc: 0.4750 - val_loss: 0.8032 - val_acc: 0.4850
# Epoch 14/60
# 600/600 [==============================] - 0s 41us/step - loss: 0.8251 - acc: 0.4750 - val_loss: 0.8014 - val_acc: 0.4850
# Epoch 15/60
# 600/600 [==============================] - 0s 32us/step - loss: 0.8176 - acc: 0.4767 - val_loss: 0.7996 - val_acc: 0.4850
# Epoch 16/60
# 600/600 [==============================] - 0s 28us/step - loss: 0.8274 - acc: 0.4750 - val_loss: 0.7978 - val_acc: 0.4850
# Epoch 17/60
# 600/600 [==============================] - 0s 29us/step - loss: 0.8270 - acc: 0.4733 - val_loss: 0.7961 - val_acc: 0.4850
# Epoch 18/60
# 600/600 [==============================] - 0s 29us/step - loss: 0.8165 - acc: 0.4767 - val_loss: 0.7943 - val_acc: 0.4850
# Epoch 19/60
# 600/600 [==============================] - 0s 30us/step - loss: 0.8124 - acc: 0.4750 - val_loss: 0.7927 - val_acc: 0.4850
# Epoch 20/60
# 600/600 [==============================] - 0s 29us/step - loss: 0.8093 - acc: 0.4750 - val_loss: 0.7910 - val_acc: 0.4850
# Epoch 21/60
# 600/600 [==============================] - 0s 42us/step - loss: 0.8134 - acc: 0.4767 - val_loss: 0.7894 - val_acc: 0.4850
# Epoch 22/60
# 600/600 [==============================] - 0s 33us/step - loss: 0.8108 - acc: 0.4717 - val_loss: 0.7879 - val_acc: 0.4850
# Epoch 23/60
# 600/600 [==============================] - 0s 25us/step - loss: 0.8026 - acc: 0.4800 - val_loss: 0.7863 - val_acc: 0.4850
# Epoch 24/60
# 600/600 [==============================] - 0s 30us/step - loss: 0.8040 - acc: 0.4750 - val_loss: 0.7848 - val_acc: 0.4850
# Epoch 25/60
# 600/600 [==============================] - 0s 29us/step - loss: 0.7953 - acc: 0.4800 - val_loss: 0.7833 - val_acc: 0.4850
# Epoch 26/60
# 600/600 [==============================] - 0s 37us/step - loss: 0.8044 - acc: 0.4767 - val_loss: 0.7818 - val_acc: 0.4850
# Epoch 27/60
# 600/600 [==============================] - 0s 35us/step - loss: 0.8168 - acc: 0.4700 - val_loss: 0.7803 - val_acc: 0.4850
# Epoch 28/60
# 600/600 [==============================] - 0s 29us/step - loss: 0.7976 - acc: 0.4783 - val_loss: 0.7788 - val_acc: 0.4850
# Epoch 29/60
# 600/600 [==============================] - 0s 34us/step - loss: 0.8066 - acc: 0.4783 - val_loss: 0.7774 - val_acc: 0.4850
# Epoch 30/60
# 600/600 [==============================] - 0s 36us/step - loss: 0.7896 - acc: 0.4833 - val_loss: 0.7760 - val_acc: 0.4850
# Epoch 31/60
# 600/600 [==============================] - 0s 32us/step - loss: 0.8030 - acc: 0.4733 - val_loss: 0.7747 - val_acc: 0.4850
# Epoch 32/60
# 600/600 [==============================] - 0s 29us/step - loss: 0.7843 - acc: 0.4750 - val_loss: 0.7733 - val_acc: 0.4850
# Epoch 33/60
# 600/600 [==============================] - 0s 27us/step - loss: 0.7825 - acc: 0.4750 - val_loss: 0.7720 - val_acc: 0.4850
# Epoch 34/60
# 600/600 [==============================] - 0s 28us/step - loss: 0.7946 - acc: 0.4767 - val_loss: 0.7707 - val_acc: 0.4850
# Epoch 35/60
# 600/600 [==============================] - 0s 31us/step - loss: 0.7862 - acc: 0.4733 - val_loss: 0.7694 - val_acc: 0.4850
# Epoch 36/60
# 600/600 [==============================] - 0s 29us/step - loss: 0.7798 - acc: 0.4733 - val_loss: 0.7682 - val_acc: 0.4850
# Epoch 37/60
# 600/600 [==============================] - 0s 39us/step - loss: 0.7739 - acc: 0.4817 - val_loss: 0.7670 - val_acc: 0.4850
# Epoch 38/60
# 600/600 [==============================] - 0s 29us/step - loss: 0.7871 - acc: 0.4717 - val_loss: 0.7658 - val_acc: 0.4850
# Epoch 39/60
# 600/600 [==============================] - 0s 29us/step - loss: 0.7982 - acc: 0.4733 - val_loss: 0.7645 - val_acc: 0.4850
# Epoch 40/60
# 600/600 [==============================] - 0s 32us/step - loss: 0.7898 - acc: 0.4667 - val_loss: 0.7633 - val_acc: 0.4850
# Epoch 41/60
# 600/600 [==============================] - 0s 35us/step - loss: 0.7799 - acc: 0.4783 - val_loss: 0.7621 - val_acc: 0.4850
# Epoch 42/60
# 600/600 [==============================] - 0s 30us/step - loss: 0.7721 - acc: 0.4750 - val_loss: 0.7610 - val_acc: 0.4850
# Epoch 43/60
# 600/600 [==============================] - 0s 27us/step - loss: 0.7807 - acc: 0.4667 - val_loss: 0.7599 - val_acc: 0.4850
# Epoch 44/60
# 600/600 [==============================] - 0s 29us/step - loss: 0.7802 - acc: 0.4733 - val_loss: 0.7587 - val_acc: 0.4850
# Epoch 45/60
# 600/600 [==============================] - 0s 33us/step - loss: 0.7771 - acc: 0.4700 - val_loss: 0.7577 - val_acc: 0.4850
# Epoch 46/60
# 600/600 [==============================] - 0s 29us/step - loss: 0.7844 - acc: 0.4683 - val_loss: 0.7566 - val_acc: 0.4850
# Epoch 47/60
# 600/600 [==============================] - 0s 27us/step - loss: 0.7621 - acc: 0.4833 - val_loss: 0.7556 - val_acc: 0.4850
# Epoch 48/60
# 600/600 [==============================] - 0s 29us/step - loss: 0.7693 - acc: 0.4767 - val_loss: 0.7546 - val_acc: 0.4850
# Epoch 49/60
# 600/600 [==============================] - 0s 34us/step - loss: 0.7648 - acc: 0.4683 - val_loss: 0.7536 - val_acc: 0.4850
# Epoch 50/60
# 600/600 [==============================] - 0s 33us/step - loss: 0.7818 - acc: 0.4767 - val_loss: 0.7526 - val_acc: 0.4850
# Epoch 51/60
# 600/600 [==============================] - 0s 32us/step - loss: 0.7704 - acc: 0.4700 - val_loss: 0.7516 - val_acc: 0.4850
# Epoch 52/60
# 600/600 [==============================] - 0s 33us/step - loss: 0.7623 - acc: 0.4783 - val_loss: 0.7506 - val_acc: 0.4850
# Epoch 53/60
# 600/600 [==============================] - 0s 18us/step - loss: 0.7720 - acc: 0.4733 - val_loss: 0.7497 - val_acc: 0.4850
# Epoch 54/60
# 600/600 [==============================] - 0s 32us/step - loss: 0.7676 - acc: 0.4667 - val_loss: 0.7487 - val_acc: 0.4850
# Epoch 55/60
# 600/600 [==============================] - 0s 28us/step - loss: 0.7577 - acc: 0.4683 - val_loss: 0.7478 - val_acc: 0.4850
# Epoch 56/60
# 600/600 [==============================] - 0s 20us/step - loss: 0.7669 - acc: 0.4733 - val_loss: 0.7469 - val_acc: 0.4850
# Epoch 57/60
# 600/600 [==============================] - 0s 34us/step - loss: 0.7640 - acc: 0.4783 - val_loss: 0.7460 - val_acc: 0.4850
# Epoch 58/60
# 600/600 [==============================] - 0s 30us/step - loss: 0.7678 - acc: 0.4667 - val_loss: 0.7451 - val_acc: 0.4850
# Epoch 59/60
# 600/600 [==============================] - 0s 32us/step - loss: 0.7537 - acc: 0.4633 - val_loss: 0.7442 - val_acc: 0.4850
# Epoch 60/60
# 600/600 [==============================] - 0s 30us/step - loss: 0.7634 - acc: 0.4733 - val_loss: 0.7434 - val_acc: 0.4850
# 200/200 [==============================] - 0s 43us/step
# Train on 600 samples, validate on 200 samples
# Epoch 1/60
# 600/600 [==============================] - 1s 2ms/step - loss: 0.7690 - acc: 0.4817 - val_loss: 0.7455 - val_acc: 0.4850
# Epoch 2/60
# 600/600 [==============================] - 0s 101us/step - loss: 0.7619 - acc: 0.4733 - val_loss: 0.7390 - val_acc: 0.4850
# Epoch 3/60
# 600/600 [==============================] - 0s 87us/step - loss: 0.7432 - acc: 0.4900 - val_loss: 0.7335 - val_acc: 0.4850
# Epoch 4/60
# 600/600 [==============================] - 0s 92us/step - loss: 0.7506 - acc: 0.4950 - val_loss: 0.7282 - val_acc: 0.4850
# Epoch 5/60
# 600/600 [==============================] - 0s 100us/step - loss: 0.7643 - acc: 0.4483 - val_loss: 0.7236 - val_acc: 0.4850
# Epoch 6/60
# 600/600 [==============================] - 0s 101us/step - loss: 0.7338 - acc: 0.5017 - val_loss: 0.7197 - val_acc: 0.4850
# Epoch 7/60
# 600/600 [==============================] - 0s 86us/step - loss: 0.7481 - acc: 0.4867 - val_loss: 0.7162 - val_acc: 0.4850
# Epoch 8/60
# 600/600 [==============================] - 0s 90us/step - loss: 0.7359 - acc: 0.4850 - val_loss: 0.7134 - val_acc: 0.4850
# Epoch 9/60
# 600/600 [==============================] - 0s 94us/step - loss: 0.7291 - acc: 0.4933 - val_loss: 0.7107 - val_acc: 0.4850
# Epoch 10/60
# 600/600 [==============================] - 0s 95us/step - loss: 0.7243 - acc: 0.5017 - val_loss: 0.7082 - val_acc: 0.4850
# Epoch 11/60
# 600/600 [==============================] - 0s 92us/step - loss: 0.7215 - acc: 0.4917 - val_loss: 0.7062 - val_acc: 0.4850
# Epoch 12/60
# 600/600 [==============================] - 0s 91us/step - loss: 0.7085 - acc: 0.5117 - val_loss: 0.7045 - val_acc: 0.4850
# Epoch 13/60
# 600/600 [==============================] - 0s 87us/step - loss: 0.7285 - acc: 0.4883 - val_loss: 0.7029 - val_acc: 0.4850
# Epoch 14/60
# 600/600 [==============================] - 0s 95us/step - loss: 0.7170 - acc: 0.4900 - val_loss: 0.7016 - val_acc: 0.4850
# Epoch 15/60
# 600/600 [==============================] - 0s 79us/step - loss: 0.7103 - acc: 0.5233 - val_loss: 0.7003 - val_acc: 0.4850
# Epoch 16/60
# 600/600 [==============================] - 0s 92us/step - loss: 0.7241 - acc: 0.4967 - val_loss: 0.6993 - val_acc: 0.4850
# Epoch 17/60
# 600/600 [==============================] - 0s 91us/step - loss: 0.7200 - acc: 0.4817 - val_loss: 0.6984 - val_acc: 0.4850
# Epoch 18/60
# 600/600 [==============================] - 0s 83us/step - loss: 0.7079 - acc: 0.4883 - val_loss: 0.6977 - val_acc: 0.4850
# Epoch 19/60
# 600/600 [==============================] - 0s 84us/step - loss: 0.7075 - acc: 0.4967 - val_loss: 0.6970 - val_acc: 0.4850
# Epoch 20/60
# 600/600 [==============================] - 0s 90us/step - loss: 0.7124 - acc: 0.4950 - val_loss: 0.6964 - val_acc: 0.4850
# Epoch 21/60
# 600/600 [==============================] - 0s 85us/step - loss: 0.7111 - acc: 0.4817 - val_loss: 0.6959 - val_acc: 0.4850
# Epoch 22/60
# 600/600 [==============================] - 0s 81us/step - loss: 0.7098 - acc: 0.5167 - val_loss: 0.6955 - val_acc: 0.4850
# Epoch 23/60
# 600/600 [==============================] - 0s 86us/step - loss: 0.7136 - acc: 0.4850 - val_loss: 0.6951 - val_acc: 0.4850
# Epoch 24/60
# 600/600 [==============================] - 0s 88us/step - loss: 0.7089 - acc: 0.5117 - val_loss: 0.6948 - val_acc: 0.4850
# Epoch 25/60
# 600/600 [==============================] - 0s 84us/step - loss: 0.7194 - acc: 0.4900 - val_loss: 0.6945 - val_acc: 0.4850
# Epoch 26/60
# 600/600 [==============================] - 0s 91us/step - loss: 0.7169 - acc: 0.5117 - val_loss: 0.6943 - val_acc: 0.4850
# Epoch 27/60
# 600/600 [==============================] - 0s 84us/step - loss: 0.7032 - acc: 0.5183 - val_loss: 0.6941 - val_acc: 0.4850
# Epoch 28/60
# 600/600 [==============================] - 0s 173us/step - loss: 0.7168 - acc: 0.5100 - val_loss: 0.6939 - val_acc: 0.4850
# Epoch 29/60
# 600/600 [==============================] - 0s 81us/step - loss: 0.7034 - acc: 0.5200 - val_loss: 0.6938 - val_acc: 0.4850
# Epoch 30/60
# 600/600 [==============================] - 0s 81us/step - loss: 0.7263 - acc: 0.4800 - val_loss: 0.6936 - val_acc: 0.4850
# Epoch 31/60
# 600/600 [==============================] - ETA: 0s - loss: 0.7252 - acc: 0.470 - 0s 79us/step - loss: 0.7216 - acc: 0.4683 - val_loss: 0.6935 - val_acc: 0.4800
# Epoch 32/60
# 600/600 [==============================] - 0s 98us/step - loss: 0.7265 - acc: 0.4583 - val_loss: 0.6934 - val_acc: 0.4050
# Epoch 33/60
# 600/600 [==============================] - 0s 80us/step - loss: 0.7049 - acc: 0.5333 - val_loss: 0.6933 - val_acc: 0.5000
# Epoch 34/60
# 600/600 [==============================] - 0s 87us/step - loss: 0.7075 - acc: 0.4933 - val_loss: 0.6933 - val_acc: 0.5100
# Epoch 35/60
# 600/600 [==============================] - 0s 81us/step - loss: 0.7185 - acc: 0.4800 - val_loss: 0.6932 - val_acc: 0.5150
# Epoch 36/60
# 600/600 [==============================] - 0s 89us/step - loss: 0.7195 - acc: 0.4700 - val_loss: 0.6931 - val_acc: 0.5150
# Epoch 37/60
# 600/600 [==============================] - 0s 92us/step - loss: 0.7168 - acc: 0.5183 - val_loss: 0.6931 - val_acc: 0.5150
# Epoch 38/60
# 600/600 [==============================] - 0s 95us/step - loss: 0.7139 - acc: 0.4983 - val_loss: 0.6931 - val_acc: 0.5150
# Epoch 39/60
# 600/600 [==============================] - 0s 90us/step - loss: 0.7104 - acc: 0.5100 - val_loss: 0.6930 - val_acc: 0.5150
# Epoch 40/60
# 600/600 [==============================] - 0s 83us/step - loss: 0.7234 - acc: 0.4967 - val_loss: 0.6930 - val_acc: 0.5150
# Epoch 41/60
# 600/600 [==============================] - 0s 95us/step - loss: 0.7102 - acc: 0.5017 - val_loss: 0.6930 - val_acc: 0.5150
# Epoch 42/60
# 600/600 [==============================] - 0s 91us/step - loss: 0.7271 - acc: 0.4750 - val_loss: 0.6930 - val_acc: 0.5150
# Epoch 43/60
# 600/600 [==============================] - 0s 101us/step - loss: 0.7041 - acc: 0.5233 - val_loss: 0.6930 - val_acc: 0.5150
# Epoch 44/60
# 600/600 [==============================] - 0s 89us/step - loss: 0.7072 - acc: 0.4717 - val_loss: 0.6930 - val_acc: 0.5150
# Epoch 45/60
# 600/600 [==============================] - 0s 92us/step - loss: 0.7155 - acc: 0.4833 - val_loss: 0.6930 - val_acc: 0.5150
# Epoch 46/60
# 600/600 [==============================] - 0s 100us/step - loss: 0.7094 - acc: 0.5033 - val_loss: 0.6930 - val_acc: 0.5150
# Epoch 47/60
# 600/600 [==============================] - 0s 85us/step - loss: 0.6949 - acc: 0.5317 - val_loss: 0.6930 - val_acc: 0.5150
# Epoch 48/60
# 600/600 [==============================] - 0s 92us/step - loss: 0.7106 - acc: 0.4917 - val_loss: 0.6930 - val_acc: 0.5150
# Epoch 49/60
# 600/600 [==============================] - 0s 95us/step - loss: 0.6983 - acc: 0.5267 - val_loss: 0.6930 - val_acc: 0.5150
# Epoch 50/60
# 600/600 [==============================] - 0s 94us/step - loss: 0.7043 - acc: 0.5317 - val_loss: 0.6930 - val_acc: 0.5150
# Epoch 51/60
# 600/600 [==============================] - 0s 85us/step - loss: 0.7153 - acc: 0.4883 - val_loss: 0.6930 - val_acc: 0.5150
# Epoch 52/60
# 600/600 [==============================] - 0s 89us/step - loss: 0.7112 - acc: 0.5117 - val_loss: 0.6930 - val_acc: 0.5150
# Epoch 53/60
# 600/600 [==============================] - 0s 102us/step - loss: 0.7052 - acc: 0.5283 - val_loss: 0.6930 - val_acc: 0.5150
# Epoch 54/60
# 600/600 [==============================] - 0s 104us/step - loss: 0.7195 - acc: 0.4783 - val_loss: 0.6930 - val_acc: 0.5150
# Epoch 55/60
# 600/600 [==============================] - 0s 96us/step - loss: 0.7065 - acc: 0.4917 - val_loss: 0.6930 - val_acc: 0.5150
# Epoch 56/60
# 600/600 [==============================] - 0s 91us/step - loss: 0.7039 - acc: 0.5217 - val_loss: 0.6930 - val_acc: 0.5150
# Epoch 57/60
# 600/600 [==============================] - 0s 92us/step - loss: 0.7027 - acc: 0.5467 - val_loss: 0.6930 - val_acc: 0.5150
# Epoch 58/60
# 600/600 [==============================] - 0s 90us/step - loss: 0.7078 - acc: 0.5267 - val_loss: 0.6930 - val_acc: 0.5150
# Epoch 59/60
# 600/600 [==============================] - 0s 81us/step - loss: 0.7170 - acc: 0.4983 - val_loss: 0.6930 - val_acc: 0.5150
# Epoch 60/60
# 600/600 [==============================] - 0s 85us/step - loss: 0.7113 - acc: 0.4917 - val_loss: 0.6930 - val_acc: 0.5150
# 200/200 [==============================] - 0s 64us/step
# Train on 600 samples, validate on 200 samples
# Epoch 1/60
# 600/600 [==============================] - 1s 2ms/step - loss: 0.7262 - acc: 0.5167 - val_loss: 0.7143 - val_acc: 0.5150
# Epoch 2/60
# 600/600 [==============================] - 0s 268us/step - loss: 0.7115 - acc: 0.5250 - val_loss: 0.7121 - val_acc: 0.5150
# Epoch 3/60
# 600/600 [==============================] - 0s 271us/step - loss: 0.7228 - acc: 0.5067 - val_loss: 0.7101 - val_acc: 0.5150
# Epoch 4/60
# 600/600 [==============================] - 0s 270us/step - loss: 0.7147 - acc: 0.5350 - val_loss: 0.7084 - val_acc: 0.5150
# Epoch 5/60
# 600/600 [==============================] - 0s 282us/step - loss: 0.7167 - acc: 0.5200 - val_loss: 0.7068 - val_acc: 0.5150
# Epoch 6/60
# 600/600 [==============================] - 0s 259us/step - loss: 0.7108 - acc: 0.5100 - val_loss: 0.7055 - val_acc: 0.5150
# Epoch 7/60
# 600/600 [==============================] - 0s 263us/step - loss: 0.7085 - acc: 0.5167 - val_loss: 0.7043 - val_acc: 0.5150
# Epoch 8/60
# 600/600 [==============================] - 0s 267us/step - loss: 0.7256 - acc: 0.4750 - val_loss: 0.7032 - val_acc: 0.5150
# Epoch 9/60
# 600/600 [==============================] - 0s 268us/step - loss: 0.7043 - acc: 0.5300 - val_loss: 0.7023 - val_acc: 0.5150
# Epoch 10/60
# 600/600 [==============================] - 0s 278us/step - loss: 0.6995 - acc: 0.5100 - val_loss: 0.7014 - val_acc: 0.5150
# Epoch 11/60
# 600/600 [==============================] - 0s 268us/step - loss: 0.6988 - acc: 0.5267 - val_loss: 0.7007 - val_acc: 0.5150
# Epoch 12/60
# 600/600 [==============================] - 0s 252us/step - loss: 0.7103 - acc: 0.5217 - val_loss: 0.7000 - val_acc: 0.5150
# Epoch 13/60
# 600/600 [==============================] - 0s 280us/step - loss: 0.7072 - acc: 0.5317 - val_loss: 0.6993 - val_acc: 0.5150
# Epoch 14/60
# 600/600 [==============================] - 0s 275us/step - loss: 0.7093 - acc: 0.5183 - val_loss: 0.6987 - val_acc: 0.5150
# Epoch 15/60
# 600/600 [==============================] - 0s 275us/step - loss: 0.7059 - acc: 0.5333 - val_loss: 0.6981 - val_acc: 0.5150
# Epoch 16/60
# 600/600 [==============================] - 0s 355us/step - loss: 0.7000 - acc: 0.5133 - val_loss: 0.6977 - val_acc: 0.5150
# Epoch 17/60
# 600/600 [==============================] - 0s 265us/step - loss: 0.6971 - acc: 0.5283 - val_loss: 0.6973 - val_acc: 0.5150
# Epoch 18/60
# 600/600 [==============================] - 0s 254us/step - loss: 0.7005 - acc: 0.5300 - val_loss: 0.6969 - val_acc: 0.5150
# Epoch 19/60
# 600/600 [==============================] - 0s 285us/step - loss: 0.7013 - acc: 0.5167 - val_loss: 0.6966 - val_acc: 0.5150
# Epoch 20/60
# 600/600 [==============================] - 0s 270us/step - loss: 0.7029 - acc: 0.5133 - val_loss: 0.6963 - val_acc: 0.5150
# Epoch 21/60
# 600/600 [==============================] - 0s 278us/step - loss: 0.7002 - acc: 0.5267 - val_loss: 0.6961 - val_acc: 0.5150
# Epoch 22/60
# 600/600 [==============================] - 0s 277us/step - loss: 0.6973 - acc: 0.5317 - val_loss: 0.6958 - val_acc: 0.5150
# Epoch 23/60
# 600/600 [==============================] - 0s 270us/step - loss: 0.7003 - acc: 0.4983 - val_loss: 0.6957 - val_acc: 0.5150
# Epoch 24/60
# 600/600 [==============================] - 0s 257us/step - loss: 0.6927 - acc: 0.5350 - val_loss: 0.6955 - val_acc: 0.5150
# Epoch 25/60
# 600/600 [==============================] - 0s 271us/step - loss: 0.6975 - acc: 0.5033 - val_loss: 0.6953 - val_acc: 0.5150
# Epoch 26/60
# 600/600 [==============================] - 0s 255us/step - loss: 0.7049 - acc: 0.4950 - val_loss: 0.6951 - val_acc: 0.5150
# Epoch 27/60
# 600/600 [==============================] - 0s 257us/step - loss: 0.7010 - acc: 0.5083 - val_loss: 0.6949 - val_acc: 0.5150
# Epoch 28/60
# 600/600 [==============================] - 0s 261us/step - loss: 0.7019 - acc: 0.4917 - val_loss: 0.6948 - val_acc: 0.5150
# Epoch 29/60
# 600/600 [==============================] - 0s 279us/step - loss: 0.7070 - acc: 0.5083 - val_loss: 0.6947 - val_acc: 0.5150
# Epoch 30/60
# 600/600 [==============================] - 0s 267us/step - loss: 0.6917 - acc: 0.5333 - val_loss: 0.6946 - val_acc: 0.5150
# Epoch 31/60
# 600/600 [==============================] - 0s 271us/step - loss: 0.7008 - acc: 0.5033 - val_loss: 0.6944 - val_acc: 0.5150
# Epoch 32/60
# 600/600 [==============================] - 0s 268us/step - loss: 0.6991 - acc: 0.4800 - val_loss: 0.6943 - val_acc: 0.5150
# Epoch 33/60
# 600/600 [==============================] - 0s 251us/step - loss: 0.6971 - acc: 0.5200 - val_loss: 0.6943 - val_acc: 0.5150
# Epoch 34/60
# 600/600 [==============================] - 0s 266us/step - loss: 0.6986 - acc: 0.5150 - val_loss: 0.6942 - val_acc: 0.5150
# Epoch 35/60
# 600/600 [==============================] - 0s 276us/step - loss: 0.6951 - acc: 0.5250 - val_loss: 0.6942 - val_acc: 0.5150
# Epoch 36/60
# 600/600 [==============================] - 0s 274us/step - loss: 0.7012 - acc: 0.4833 - val_loss: 0.6941 - val_acc: 0.5150
# Epoch 37/60
# 600/600 [==============================] - 0s 299us/step - loss: 0.6948 - acc: 0.5250 - val_loss: 0.6940 - val_acc: 0.5150
# Epoch 38/60
# 600/600 [==============================] - 0s 296us/step - loss: 0.7013 - acc: 0.5000 - val_loss: 0.6940 - val_acc: 0.5150
# Epoch 39/60
# 600/600 [==============================] - 0s 314us/step - loss: 0.6998 - acc: 0.4967 - val_loss: 0.6939 - val_acc: 0.5150
# Epoch 40/60
# 600/600 [==============================] - 0s 292us/step - loss: 0.6977 - acc: 0.5000 - val_loss: 0.6938 - val_acc: 0.5150
# Epoch 41/60
# 600/600 [==============================] - 0s 308us/step - loss: 0.7105 - acc: 0.4800 - val_loss: 0.6938 - val_acc: 0.5150
# Epoch 42/60
# 600/600 [==============================] - 0s 292us/step - loss: 0.6995 - acc: 0.5150 - val_loss: 0.6937 - val_acc: 0.5150
# Epoch 43/60
# 600/600 [==============================] - 0s 308us/step - loss: 0.6977 - acc: 0.5200 - val_loss: 0.6937 - val_acc: 0.5150
# Epoch 44/60
# 600/600 [==============================] - 0s 293us/step - loss: 0.6943 - acc: 0.5400 - val_loss: 0.6937 - val_acc: 0.5150
# Epoch 45/60
# 600/600 [==============================] - 0s 283us/step - loss: 0.7025 - acc: 0.4983 - val_loss: 0.6936 - val_acc: 0.5150
# Epoch 46/60
# 600/600 [==============================] - 0s 315us/step - loss: 0.6964 - acc: 0.5167 - val_loss: 0.6936 - val_acc: 0.5150
# Epoch 47/60
# 600/600 [==============================] - 0s 272us/step - loss: 0.6997 - acc: 0.5000 - val_loss: 0.6936 - val_acc: 0.5150
# Epoch 48/60
# 600/600 [==============================] - 0s 314us/step - loss: 0.6979 - acc: 0.5150 - val_loss: 0.6935 - val_acc: 0.5150
# Epoch 49/60
# 600/600 [==============================] - 0s 274us/step - loss: 0.6967 - acc: 0.5267 - val_loss: 0.6935 - val_acc: 0.5150
# Epoch 50/60
# 600/600 [==============================] - 0s 279us/step - loss: 0.7049 - acc: 0.4850 - val_loss: 0.6935 - val_acc: 0.5150
# Epoch 51/60
# 600/600 [==============================] - 0s 291us/step - loss: 0.7003 - acc: 0.5200 - val_loss: 0.6935 - val_acc: 0.5150
# Epoch 52/60
# 600/600 [==============================] - 0s 294us/step - loss: 0.6971 - acc: 0.5050 - val_loss: 0.6935 - val_acc: 0.5150
# Epoch 53/60
# 600/600 [==============================] - 0s 276us/step - loss: 0.7022 - acc: 0.4967 - val_loss: 0.6934 - val_acc: 0.5150
# Epoch 54/60
# 600/600 [==============================] - 0s 291us/step - loss: 0.7062 - acc: 0.4967 - val_loss: 0.6934 - val_acc: 0.5150
# Epoch 55/60
# 600/600 [==============================] - 0s 290us/step - loss: 0.6978 - acc: 0.5133 - val_loss: 0.6934 - val_acc: 0.5150
# Epoch 56/60
# 600/600 [==============================] - 0s 307us/step - loss: 0.6947 - acc: 0.5133 - val_loss: 0.6934 - val_acc: 0.5150
# Epoch 57/60
# 600/600 [==============================] - 0s 270us/step - loss: 0.6952 - acc: 0.5033 - val_loss: 0.6934 - val_acc: 0.5150
# Epoch 58/60
# 600/600 [==============================] - 0s 281us/step - loss: 0.6966 - acc: 0.5233 - val_loss: 0.6934 - val_acc: 0.5150
# Epoch 59/60
# 600/600 [==============================] - 0s 274us/step - loss: 0.6962 - acc: 0.5167 - val_loss: 0.6933 - val_acc: 0.5150
# Epoch 60/60
# 600/600 [==============================] - 0s 268us/step - loss: 0.7040 - acc: 0.4817 - val_loss: 0.6933 - val_acc: 0.5150
# 200/200 [==============================] - 0s 143us/step
# Train on 600 samples, validate on 200 samples
# Epoch 1/30
# 600/600 [==============================] - 1s 2ms/step - loss: 0.7287 - acc: 0.5250 - val_loss: 0.7225 - val_acc: 0.5150
# Epoch 2/30
# 600/600 [==============================] - 0s 44us/step - loss: 0.7251 - acc: 0.5267 - val_loss: 0.7219 - val_acc: 0.5150
# Epoch 3/30
# 600/600 [==============================] - 0s 43us/step - loss: 0.7292 - acc: 0.5267 - val_loss: 0.7213 - val_acc: 0.5150
# Epoch 4/30
# 600/600 [==============================] - 0s 53us/step - loss: 0.7280 - acc: 0.5133 - val_loss: 0.7208 - val_acc: 0.5150
# Epoch 5/30
# 600/600 [==============================] - 0s 46us/step - loss: 0.7228 - acc: 0.5217 - val_loss: 0.7202 - val_acc: 0.5150
# Epoch 6/30
# 600/600 [==============================] - 0s 46us/step - loss: 0.7234 - acc: 0.5183 - val_loss: 0.7197 - val_acc: 0.5150
# Epoch 7/30
# 600/600 [==============================] - 0s 46us/step - loss: 0.7183 - acc: 0.5083 - val_loss: 0.7191 - val_acc: 0.5150
# Epoch 8/30
# 600/600 [==============================] - 0s 41us/step - loss: 0.7236 - acc: 0.5233 - val_loss: 0.7186 - val_acc: 0.5150
# Epoch 9/30
# 600/600 [==============================] - 0s 45us/step - loss: 0.7150 - acc: 0.5250 - val_loss: 0.7181 - val_acc: 0.5150
# Epoch 10/30
# 600/600 [==============================] - 0s 45us/step - loss: 0.7201 - acc: 0.5200 - val_loss: 0.7176 - val_acc: 0.5150
# Epoch 11/30
# 600/600 [==============================] - 0s 48us/step - loss: 0.7247 - acc: 0.5217 - val_loss: 0.7171 - val_acc: 0.5150
# Epoch 12/30
# 600/600 [==============================] - 0s 47us/step - loss: 0.7155 - acc: 0.5183 - val_loss: 0.7167 - val_acc: 0.5150
# Epoch 13/30
# 600/600 [==============================] - 0s 45us/step - loss: 0.7101 - acc: 0.5250 - val_loss: 0.7162 - val_acc: 0.5150
# Epoch 14/30
# 600/600 [==============================] - 0s 45us/step - loss: 0.7249 - acc: 0.5333 - val_loss: 0.7158 - val_acc: 0.5150
# Epoch 15/30
# 600/600 [==============================] - 0s 51us/step - loss: 0.7181 - acc: 0.5267 - val_loss: 0.7153 - val_acc: 0.5150
# Epoch 16/30
# 600/600 [==============================] - 0s 46us/step - loss: 0.7194 - acc: 0.5183 - val_loss: 0.7149 - val_acc: 0.5150
# Epoch 17/30
# 600/600 [==============================] - 0s 47us/step - loss: 0.7164 - acc: 0.5183 - val_loss: 0.7144 - val_acc: 0.5150
# Epoch 18/30
# 600/600 [==============================] - 0s 45us/step - loss: 0.7142 - acc: 0.5283 - val_loss: 0.7140 - val_acc: 0.5150
# Epoch 19/30
# 600/600 [==============================] - 0s 42us/step - loss: 0.7206 - acc: 0.5200 - val_loss: 0.7136 - val_acc: 0.5150
# Epoch 20/30
# 600/600 [==============================] - 0s 50us/step - loss: 0.7078 - acc: 0.5283 - val_loss: 0.7132 - val_acc: 0.5150
# Epoch 21/30
# 600/600 [==============================] - 0s 47us/step - loss: 0.7073 - acc: 0.5233 - val_loss: 0.7128 - val_acc: 0.5150
# Epoch 22/30
# 600/600 [==============================] - 0s 53us/step - loss: 0.7151 - acc: 0.5450 - val_loss: 0.7125 - val_acc: 0.5150
# Epoch 23/30
# 600/600 [==============================] - 0s 37us/step - loss: 0.7147 - acc: 0.5317 - val_loss: 0.7121 - val_acc: 0.5150
# Epoch 24/30
# 600/600 [==============================] - 0s 56us/step - loss: 0.7143 - acc: 0.5283 - val_loss: 0.7117 - val_acc: 0.5150
# Epoch 25/30
# 600/600 [==============================] - 0s 43us/step - loss: 0.7157 - acc: 0.5250 - val_loss: 0.7114 - val_acc: 0.5150
# Epoch 26/30
# 600/600 [==============================] - 0s 45us/step - loss: 0.7166 - acc: 0.5217 - val_loss: 0.7111 - val_acc: 0.5150
# Epoch 27/30
# 600/600 [==============================] - 0s 45us/step - loss: 0.7103 - acc: 0.5300 - val_loss: 0.7107 - val_acc: 0.5150
# Epoch 28/30
# 600/600 [==============================] - 0s 43us/step - loss: 0.7201 - acc: 0.5200 - val_loss: 0.7104 - val_acc: 0.5150
# Epoch 29/30
# 600/600 [==============================] - 0s 53us/step - loss: 0.7100 - acc: 0.5200 - val_loss: 0.7101 - val_acc: 0.5150
# Epoch 30/30
# 600/600 [==============================] - 0s 42us/step - loss: 0.7121 - acc: 0.5133 - val_loss: 0.7097 - val_acc: 0.5150
# 200/200 [==============================] - 0s 32us/step
# Train on 600 samples, validate on 200 samples
# Epoch 1/120
# 600/600 [==============================] - 1s 2ms/step - loss: 0.7160 - acc: 0.4900 - val_loss: 0.7041 - val_acc: 0.4850
# Epoch 2/120
# 600/600 [==============================] - 0s 88us/step - loss: 0.7182 - acc: 0.5067 - val_loss: 0.7038 - val_acc: 0.4850
# Epoch 3/120
# 600/600 [==============================] - 0s 65us/step - loss: 0.7063 - acc: 0.4817 - val_loss: 0.7035 - val_acc: 0.4850
# Epoch 4/120
# 600/600 [==============================] - 0s 52us/step - loss: 0.7198 - acc: 0.4717 - val_loss: 0.7032 - val_acc: 0.4850
# Epoch 5/120
# 600/600 [==============================] - 0s 42us/step - loss: 0.7063 - acc: 0.5217 - val_loss: 0.7030 - val_acc: 0.4850
# Epoch 6/120
# 600/600 [==============================] - 0s 42us/step - loss: 0.7272 - acc: 0.4783 - val_loss: 0.7027 - val_acc: 0.4850
# Epoch 7/120
# 600/600 [==============================] - 0s 38us/step - loss: 0.7157 - acc: 0.4783 - val_loss: 0.7025 - val_acc: 0.4850
# Epoch 8/120
# 600/600 [==============================] - 0s 40us/step - loss: 0.7081 - acc: 0.4750 - val_loss: 0.7022 - val_acc: 0.4850
# Epoch 9/120
# 600/600 [==============================] - 0s 41us/step - loss: 0.7170 - acc: 0.4633 - val_loss: 0.7020 - val_acc: 0.4850
# Epoch 10/120
# 600/600 [==============================] - 0s 41us/step - loss: 0.7137 - acc: 0.4733 - val_loss: 0.7018 - val_acc: 0.4850
# Epoch 11/120
# 600/600 [==============================] - 0s 47us/step - loss: 0.7098 - acc: 0.4967 - val_loss: 0.7016 - val_acc: 0.4850
# Epoch 12/120
# 600/600 [==============================] - 0s 42us/step - loss: 0.7090 - acc: 0.4950 - val_loss: 0.7014 - val_acc: 0.4850
# Epoch 13/120
# 600/600 [==============================] - 0s 54us/step - loss: 0.7114 - acc: 0.4800 - val_loss: 0.7012 - val_acc: 0.4850
# Epoch 14/120
# 600/600 [==============================] - 0s 50us/step - loss: 0.7136 - acc: 0.4950 - val_loss: 0.7009 - val_acc: 0.4850
# Epoch 15/120
# 600/600 [==============================] - 0s 41us/step - loss: 0.7143 - acc: 0.4850 - val_loss: 0.7007 - val_acc: 0.4850
# Epoch 16/120
# 600/600 [==============================] - 0s 42us/step - loss: 0.7191 - acc: 0.4667 - val_loss: 0.7006 - val_acc: 0.4850
# Epoch 17/120
# 600/600 [==============================] - 0s 45us/step - loss: 0.7137 - acc: 0.4817 - val_loss: 0.7004 - val_acc: 0.4850
# Epoch 18/120
# 600/600 [==============================] - 0s 42us/step - loss: 0.7067 - acc: 0.5117 - val_loss: 0.7002 - val_acc: 0.4850
# Epoch 19/120
# 600/600 [==============================] - 0s 42us/step - loss: 0.7032 - acc: 0.4833 - val_loss: 0.7000 - val_acc: 0.4850
# Epoch 20/120
# 600/600 [==============================] - 0s 39us/step - loss: 0.7088 - acc: 0.4867 - val_loss: 0.6999 - val_acc: 0.4850
# Epoch 21/120
# 600/600 [==============================] - 0s 48us/step - loss: 0.7221 - acc: 0.4633 - val_loss: 0.6997 - val_acc: 0.4850
# Epoch 22/120
# 600/600 [==============================] - 0s 45us/step - loss: 0.7163 - acc: 0.4683 - val_loss: 0.6995 - val_acc: 0.4850
# Epoch 23/120
# 600/600 [==============================] - 0s 37us/step - loss: 0.7039 - acc: 0.4983 - val_loss: 0.6994 - val_acc: 0.4850
# Epoch 24/120
# 600/600 [==============================] - 0s 49us/step - loss: 0.7198 - acc: 0.4700 - val_loss: 0.6992 - val_acc: 0.4850
# Epoch 25/120
# 600/600 [==============================] - 0s 41us/step - loss: 0.7170 - acc: 0.4783 - val_loss: 0.6991 - val_acc: 0.4850
# Epoch 26/120
# 600/600 [==============================] - 0s 46us/step - loss: 0.7025 - acc: 0.5117 - val_loss: 0.6989 - val_acc: 0.4850
# Epoch 27/120
# 600/600 [==============================] - 0s 40us/step - loss: 0.7086 - acc: 0.4900 - val_loss: 0.6988 - val_acc: 0.4850
# Epoch 28/120
# 600/600 [==============================] - 0s 48us/step - loss: 0.7049 - acc: 0.5050 - val_loss: 0.6986 - val_acc: 0.4850
# Epoch 29/120
# 600/600 [==============================] - 0s 38us/step - loss: 0.7106 - acc: 0.4733 - val_loss: 0.6985 - val_acc: 0.4850
# Epoch 30/120
# 600/600 [==============================] - 0s 44us/step - loss: 0.7131 - acc: 0.4900 - val_loss: 0.6983 - val_acc: 0.4850
# Epoch 31/120
# 600/600 [==============================] - 0s 45us/step - loss: 0.7072 - acc: 0.4717 - val_loss: 0.6982 - val_acc: 0.4850
# Epoch 32/120
# 600/600 [==============================] - 0s 39us/step - loss: 0.7023 - acc: 0.5100 - val_loss: 0.6980 - val_acc: 0.4850
# Epoch 33/120
# 600/600 [==============================] - 0s 36us/step - loss: 0.7141 - acc: 0.5000 - val_loss: 0.6979 - val_acc: 0.4850
# Epoch 34/120
# 600/600 [==============================] - 0s 42us/step - loss: 0.7014 - acc: 0.5233 - val_loss: 0.6978 - val_acc: 0.4850
# Epoch 35/120
# 600/600 [==============================] - 0s 42us/step - loss: 0.7077 - acc: 0.5117 - val_loss: 0.6977 - val_acc: 0.4850
# Epoch 36/120
# 600/600 [==============================] - 0s 40us/step - loss: 0.7090 - acc: 0.4917 - val_loss: 0.6975 - val_acc: 0.4850
# Epoch 37/120
# 600/600 [==============================] - 0s 42us/step - loss: 0.7081 - acc: 0.4867 - val_loss: 0.6974 - val_acc: 0.4850
# Epoch 38/120
# 600/600 [==============================] - 0s 49us/step - loss: 0.7076 - acc: 0.5050 - val_loss: 0.6973 - val_acc: 0.4850
# Epoch 39/120
# 600/600 [==============================] - 0s 49us/step - loss: 0.7092 - acc: 0.5000 - val_loss: 0.6972 - val_acc: 0.4850
# Epoch 40/120
# 600/600 [==============================] - 0s 42us/step - loss: 0.7063 - acc: 0.5067 - val_loss: 0.6971 - val_acc: 0.4850
# Epoch 41/120
# 600/600 [==============================] - 0s 41us/step - loss: 0.7155 - acc: 0.5017 - val_loss: 0.6970 - val_acc: 0.4850
# Epoch 42/120
# 600/600 [==============================] - 0s 46us/step - loss: 0.6974 - acc: 0.5100 - val_loss: 0.6969 - val_acc: 0.4850
# Epoch 43/120
# 600/600 [==============================] - 0s 44us/step - loss: 0.7060 - acc: 0.5133 - val_loss: 0.6968 - val_acc: 0.4850
# Epoch 44/120
# 600/600 [==============================] - 0s 45us/step - loss: 0.7126 - acc: 0.4867 - val_loss: 0.6967 - val_acc: 0.4850
# Epoch 45/120
# 600/600 [==============================] - 0s 47us/step - loss: 0.7019 - acc: 0.5067 - val_loss: 0.6966 - val_acc: 0.4850
# Epoch 46/120
# 600/600 [==============================] - 0s 51us/step - loss: 0.7082 - acc: 0.4967 - val_loss: 0.6965 - val_acc: 0.4850
# Epoch 47/120
# 600/600 [==============================] - 0s 42us/step - loss: 0.7081 - acc: 0.4867 - val_loss: 0.6964 - val_acc: 0.4850
# Epoch 48/120
# 600/600 [==============================] - 0s 41us/step - loss: 0.7092 - acc: 0.4883 - val_loss: 0.6963 - val_acc: 0.4850
# Epoch 49/120
# 600/600 [==============================] - 0s 52us/step - loss: 0.7021 - acc: 0.4867 - val_loss: 0.6962 - val_acc: 0.4850
# Epoch 50/120
# 600/600 [==============================] - 0s 41us/step - loss: 0.7102 - acc: 0.4700 - val_loss: 0.6962 - val_acc: 0.4850
# Epoch 51/120
# 600/600 [==============================] - 0s 41us/step - loss: 0.7089 - acc: 0.4750 - val_loss: 0.6961 - val_acc: 0.4850
# Epoch 52/120
# 600/600 [==============================] - 0s 38us/step - loss: 0.7052 - acc: 0.4867 - val_loss: 0.6960 - val_acc: 0.4850
# Epoch 53/120
# 600/600 [==============================] - 0s 43us/step - loss: 0.7040 - acc: 0.5033 - val_loss: 0.6959 - val_acc: 0.4850
# Epoch 54/120
# 600/600 [==============================] - 0s 50us/step - loss: 0.7135 - acc: 0.4683 - val_loss: 0.6958 - val_acc: 0.4850
# Epoch 55/120
# 600/600 [==============================] - 0s 46us/step - loss: 0.6980 - acc: 0.5250 - val_loss: 0.6958 - val_acc: 0.4850
# Epoch 56/120
# 600/600 [==============================] - 0s 48us/step - loss: 0.7019 - acc: 0.4733 - val_loss: 0.6957 - val_acc: 0.4850
# Epoch 57/120
# 600/600 [==============================] - 0s 45us/step - loss: 0.7041 - acc: 0.5100 - val_loss: 0.6956 - val_acc: 0.4850
# Epoch 58/120
# 600/600 [==============================] - 0s 42us/step - loss: 0.7140 - acc: 0.4633 - val_loss: 0.6956 - val_acc: 0.4850
# Epoch 59/120
# 600/600 [==============================] - 0s 46us/step - loss: 0.7055 - acc: 0.4733 - val_loss: 0.6955 - val_acc: 0.4850
# Epoch 60/120
# 600/600 [==============================] - 0s 53us/step - loss: 0.6998 - acc: 0.5367 - val_loss: 0.6954 - val_acc: 0.4850
# Epoch 61/120
# 600/600 [==============================] - 0s 49us/step - loss: 0.7024 - acc: 0.4933 - val_loss: 0.6953 - val_acc: 0.4850
# Epoch 62/120
# 600/600 [==============================] - 0s 51us/step - loss: 0.7091 - acc: 0.4933 - val_loss: 0.6953 - val_acc: 0.4850
# Epoch 63/120
# 600/600 [==============================] - 0s 44us/step - loss: 0.6998 - acc: 0.5083 - val_loss: 0.6952 - val_acc: 0.4850
# Epoch 64/120
# 600/600 [==============================] - 0s 37us/step - loss: 0.7072 - acc: 0.4900 - val_loss: 0.6952 - val_acc: 0.4850
# Epoch 65/120
# 600/600 [==============================] - 0s 47us/step - loss: 0.6996 - acc: 0.4967 - val_loss: 0.6951 - val_acc: 0.4850
# Epoch 66/120
# 600/600 [==============================] - 0s 45us/step - loss: 0.7050 - acc: 0.5000 - val_loss: 0.6950 - val_acc: 0.4850
# Epoch 67/120
# 600/600 [==============================] - 0s 45us/step - loss: 0.6956 - acc: 0.5183 - val_loss: 0.6950 - val_acc: 0.4850
# Epoch 68/120
# 600/600 [==============================] - 0s 44us/step - loss: 0.7093 - acc: 0.4767 - val_loss: 0.6949 - val_acc: 0.4850
# Epoch 69/120
# 600/600 [==============================] - 0s 50us/step - loss: 0.7169 - acc: 0.4600 - val_loss: 0.6949 - val_acc: 0.4850
# Epoch 70/120
# 600/600 [==============================] - 0s 47us/step - loss: 0.7077 - acc: 0.4883 - val_loss: 0.6948 - val_acc: 0.4850
# Epoch 71/120
# 600/600 [==============================] - 0s 46us/step - loss: 0.7089 - acc: 0.4883 - val_loss: 0.6948 - val_acc: 0.4850
# Epoch 72/120
# 600/600 [==============================] - 0s 41us/step - loss: 0.6998 - acc: 0.5067 - val_loss: 0.6947 - val_acc: 0.4850
# Epoch 73/120
# 600/600 [==============================] - 0s 47us/step - loss: 0.7088 - acc: 0.4850 - val_loss: 0.6947 - val_acc: 0.4850
# Epoch 74/120
# 600/600 [==============================] - 0s 43us/step - loss: 0.7066 - acc: 0.4800 - val_loss: 0.6946 - val_acc: 0.4850
# Epoch 75/120
# 600/600 [==============================] - 0s 40us/step - loss: 0.7090 - acc: 0.4633 - val_loss: 0.6946 - val_acc: 0.4850
# Epoch 76/120
# 600/600 [==============================] - 0s 46us/step - loss: 0.6981 - acc: 0.5100 - val_loss: 0.6945 - val_acc: 0.4850
# Epoch 77/120
# 600/600 [==============================] - 0s 50us/step - loss: 0.7086 - acc: 0.4783 - val_loss: 0.6945 - val_acc: 0.4850
# Epoch 78/120
# 600/600 [==============================] - 0s 40us/step - loss: 0.7013 - acc: 0.4833 - val_loss: 0.6945 - val_acc: 0.4850
# Epoch 79/120
# 600/600 [==============================] - 0s 51us/step - loss: 0.7136 - acc: 0.4600 - val_loss: 0.6944 - val_acc: 0.4850
# Epoch 80/120
# 600/600 [==============================] - 0s 39us/step - loss: 0.7061 - acc: 0.4867 - val_loss: 0.6944 - val_acc: 0.4850
# Epoch 81/120
# 600/600 [==============================] - 0s 40us/step - loss: 0.7034 - acc: 0.5000 - val_loss: 0.6943 - val_acc: 0.4850
# Epoch 82/120
# 600/600 [==============================] - 0s 40us/step - loss: 0.6971 - acc: 0.5167 - val_loss: 0.6943 - val_acc: 0.4850
# Epoch 83/120
# 600/600 [==============================] - 0s 39us/step - loss: 0.7170 - acc: 0.4733 - val_loss: 0.6943 - val_acc: 0.4850
# Epoch 84/120
# ...
# Epoch 3/60
# 600/600 [==============================] - 0s 47us/step - loss: 0.6964 - acc: 0.5017 - val_loss: 0.6925 - val_acc: 0.5150
# Epoch 4/60
# 600/600 [==============================] - 0s 46us/step - loss: 0.6925 - acc: 0.5300 - val_loss: 0.6925 - val_acc: 0.5150
# Epoch 5/60
# 600/600 [==============================] - 0s 48us/step - loss: 0.6901 - acc: 0.5300 - val_loss: 0.6926 - val_acc: 0.5150
# Epoch 6/60
# 600/600 [==============================] - 0s 50us/step - loss: 0.6885 - acc: 0.5550 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 7/60
# 600/600 [==============================] - 0s 45us/step - loss: 0.6947 - acc: 0.5033 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 8/60
# 600/600 [==============================] - 0s 44us/step - loss: 0.6959 - acc: 0.4617 - val_loss: 0.6927 - val_acc: 0.5150
# Epoch 9/60
# 600/600 [==============================] - 0s 42us/step - loss: 0.6949 - acc: 0.5233 - val_loss: 0.6925 - val_acc: 0.5150
# Epoch 10/60
# 600/600 [==============================] - 0s 48us/step - loss: 0.6918 - acc: 0.5300 - val_loss: 0.6926 - val_acc: 0.5150
# Epoch 11/60
# 600/600 [==============================] - 0s 48us/step - loss: 0.6928 - acc: 0.5267 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 12/60
# 600/600 [==============================] - 0s 48us/step - loss: 0.6922 - acc: 0.5183 - val_loss: 0.6925 - val_acc: 0.5150
# Epoch 13/60
# 600/600 [==============================] - 0s 63us/step - loss: 0.6914 - acc: 0.5267 - val_loss: 0.6925 - val_acc: 0.5150
# Epoch 14/60
# 600/600 [==============================] - 0s 51us/step - loss: 0.6941 - acc: 0.5133 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 15/60
# 600/600 [==============================] - 0s 48us/step - loss: 0.6916 - acc: 0.5400 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 16/60
# 600/600 [==============================] - 0s 48us/step - loss: 0.6919 - acc: 0.5200 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 17/60
# 600/600 [==============================] - 0s 58us/step - loss: 0.6944 - acc: 0.5183 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 18/60
# 600/600 [==============================] - 0s 48us/step - loss: 0.6907 - acc: 0.5183 - val_loss: 0.6925 - val_acc: 0.5150
# Epoch 19/60
# 600/600 [==============================] - 0s 42us/step - loss: 0.6940 - acc: 0.5133 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 20/60
# 600/600 [==============================] - 0s 43us/step - loss: 0.6903 - acc: 0.5333 - val_loss: 0.6926 - val_acc: 0.5150
# Epoch 21/60
# 600/600 [==============================] - 0s 44us/step - loss: 0.6916 - acc: 0.5233 - val_loss: 0.6925 - val_acc: 0.5150
# Epoch 22/60
# 600/600 [==============================] - 0s 44us/step - loss: 0.6921 - acc: 0.5333 - val_loss: 0.6925 - val_acc: 0.5150
# Epoch 23/60
# 600/600 [==============================] - 0s 69us/step - loss: 0.6920 - acc: 0.5217 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 24/60
# 600/600 [==============================] - 0s 60us/step - loss: 0.6941 - acc: 0.5250 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 25/60
# 600/600 [==============================] - 0s 47us/step - loss: 0.6914 - acc: 0.5367 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 26/60
# 600/600 [==============================] - 0s 46us/step - loss: 0.6914 - acc: 0.5250 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 27/60
# 600/600 [==============================] - 0s 46us/step - loss: 0.6932 - acc: 0.5250 - val_loss: 0.6923 - val_acc: 0.5150
# Epoch 28/60
# 600/600 [==============================] - 0s 56us/step - loss: 0.6929 - acc: 0.5150 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 29/60
# 600/600 [==============================] - 0s 46us/step - loss: 0.6933 - acc: 0.5267 - val_loss: 0.6923 - val_acc: 0.5150
# Epoch 30/60
# 600/600 [==============================] - 0s 46us/step - loss: 0.6925 - acc: 0.5350 - val_loss: 0.6923 - val_acc: 0.5150
# Epoch 31/60
# 600/600 [==============================] - 0s 60us/step - loss: 0.6926 - acc: 0.5300 - val_loss: 0.6923 - val_acc: 0.5150
# Epoch 32/60
# 600/600 [==============================] - 0s 50us/step - loss: 0.6918 - acc: 0.5250 - val_loss: 0.6923 - val_acc: 0.5150
# Epoch 33/60
# 600/600 [==============================] - 0s 58us/step - loss: 0.6900 - acc: 0.5233 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 34/60
# 600/600 [==============================] - 0s 48us/step - loss: 0.6951 - acc: 0.5250 - val_loss: 0.6923 - val_acc: 0.5150
# Epoch 35/60
# 600/600 [==============================] - 0s 51us/step - loss: 0.6916 - acc: 0.5100 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 36/60
# 600/600 [==============================] - 0s 59us/step - loss: 0.6911 - acc: 0.5283 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 37/60
# 600/600 [==============================] - 0s 53us/step - loss: 0.6919 - acc: 0.5300 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 38/60
# 600/600 [==============================] - 0s 45us/step - loss: 0.6915 - acc: 0.5250 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 39/60
# 600/600 [==============================] - 0s 49us/step - loss: 0.6931 - acc: 0.5167 - val_loss: 0.6923 - val_acc: 0.5150
# Epoch 40/60
# 600/600 [==============================] - 0s 39us/step - loss: 0.6894 - acc: 0.5250 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 41/60
# 600/600 [==============================] - 0s 46us/step - loss: 0.6919 - acc: 0.5200 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 42/60
# 600/600 [==============================] - 0s 45us/step - loss: 0.6910 - acc: 0.5167 - val_loss: 0.6925 - val_acc: 0.5150
# Epoch 43/60
# 600/600 [==============================] - 0s 51us/step - loss: 0.6921 - acc: 0.5250 - val_loss: 0.6923 - val_acc: 0.5150
# Epoch 44/60
# 600/600 [==============================] - 0s 47us/step - loss: 0.6912 - acc: 0.5267 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 45/60
# 600/600 [==============================] - 0s 46us/step - loss: 0.6925 - acc: 0.5217 - val_loss: 0.6923 - val_acc: 0.5150
# Epoch 46/60
# 600/600 [==============================] - 0s 48us/step - loss: 0.6928 - acc: 0.5250 - val_loss: 0.6922 - val_acc: 0.5150
# Epoch 47/60
# 600/600 [==============================] - 0s 53us/step - loss: 0.6925 - acc: 0.5317 - val_loss: 0.6922 - val_acc: 0.5150
# Epoch 48/60
# 600/600 [==============================] - 0s 59us/step - loss: 0.6920 - acc: 0.5233 - val_loss: 0.6922 - val_acc: 0.5150
# Epoch 49/60
# 600/600 [==============================] - 0s 46us/step - loss: 0.6927 - acc: 0.5233 - val_loss: 0.6922 - val_acc: 0.5150
# Epoch 50/60
# 600/600 [==============================] - 0s 47us/step - loss: 0.6928 - acc: 0.5200 - val_loss: 0.6922 - val_acc: 0.5150
# Epoch 51/60
# 600/600 [==============================] - 0s 53us/step - loss: 0.6919 - acc: 0.5267 - val_loss: 0.6922 - val_acc: 0.5150
# Epoch 52/60
# 600/600 [==============================] - 0s 50us/step - loss: 0.6903 - acc: 0.5233 - val_loss: 0.6923 - val_acc: 0.5150
# Epoch 53/60
# 600/600 [==============================] - 0s 48us/step - loss: 0.6912 - acc: 0.5283 - val_loss: 0.6922 - val_acc: 0.5150
# Epoch 54/60
# 600/600 [==============================] - 0s 57us/step - loss: 0.6920 - acc: 0.5217 - val_loss: 0.6922 - val_acc: 0.5150
# Epoch 55/60
# 600/600 [==============================] - 0s 44us/step - loss: 0.6905 - acc: 0.5283 - val_loss: 0.6922 - val_acc: 0.5150
# Epoch 56/60
# 600/600 [==============================] - 0s 41us/step - loss: 0.6923 - acc: 0.5267 - val_loss: 0.6922 - val_acc: 0.5150
# Epoch 57/60
# 600/600 [==============================] - 0s 44us/step - loss: 0.6914 - acc: 0.5217 - val_loss: 0.6922 - val_acc: 0.5150
# Epoch 58/60
# 600/600 [==============================] - 0s 48us/step - loss: 0.6920 - acc: 0.5300 - val_loss: 0.6921 - val_acc: 0.5150
# Epoch 59/60
# 600/600 [==============================] - 0s 58us/step - loss: 0.6901 - acc: 0.5167 - val_loss: 0.6922 - val_acc: 0.5150
# Epoch 60/60
# 600/600 [==============================] - 0s 54us/step - loss: 0.6920 - acc: 0.5233 - val_loss: 0.6921 - val_acc: 0.5150
# 200/200 [==============================] - 0s 46us/step
# Train on 600 samples, validate on 200 samples
# Epoch 1/60
# 600/600 [==============================] - 1s 2ms/step - loss: 0.7150 - acc: 0.5333 - val_loss: 0.6931 - val_acc: 0.5150
# Epoch 2/60
# 600/600 [==============================] - 0s 52us/step - loss: 0.6925 - acc: 0.5300 - val_loss: 0.6928 - val_acc: 0.5150
# Epoch 3/60
# 600/600 [==============================] - 0s 45us/step - loss: 0.6935 - acc: 0.5267 - val_loss: 0.6927 - val_acc: 0.5150
# Epoch 4/60
# 600/600 [==============================] - 0s 46us/step - loss: 0.6927 - acc: 0.5200 - val_loss: 0.6926 - val_acc: 0.5150
# Epoch 5/60
# 600/600 [==============================] - 0s 50us/step - loss: 0.6920 - acc: 0.5200 - val_loss: 0.6927 - val_acc: 0.5150
# Epoch 6/60
# 600/600 [==============================] - 0s 70us/step - loss: 0.6923 - acc: 0.5283 - val_loss: 0.6926 - val_acc: 0.5150
# Epoch 7/60
# 600/600 [==============================] - 0s 65us/step - loss: 0.6919 - acc: 0.5250 - val_loss: 0.6926 - val_acc: 0.5150
# Epoch 8/60
# 600/600 [==============================] - 0s 49us/step - loss: 0.6927 - acc: 0.5267 - val_loss: 0.6926 - val_acc: 0.5150
# Epoch 9/60
# 600/600 [==============================] - 0s 56us/step - loss: 0.6932 - acc: 0.5250 - val_loss: 0.6926 - val_acc: 0.5150
# Epoch 10/60
# 600/600 [==============================] - 0s 53us/step - loss: 0.6925 - acc: 0.5200 - val_loss: 0.6926 - val_acc: 0.5150
# Epoch 11/60
# 600/600 [==============================] - 0s 48us/step - loss: 0.6910 - acc: 0.5233 - val_loss: 0.6926 - val_acc: 0.5150
# Epoch 12/60
# 600/600 [==============================] - 0s 59us/step - loss: 0.6934 - acc: 0.5233 - val_loss: 0.6926 - val_acc: 0.5150
# Epoch 13/60
# 600/600 [==============================] - 0s 53us/step - loss: 0.6926 - acc: 0.5250 - val_loss: 0.6926 - val_acc: 0.5150
# Epoch 14/60
# 600/600 [==============================] - 0s 49us/step - loss: 0.6926 - acc: 0.5267 - val_loss: 0.6926 - val_acc: 0.5150
# Epoch 15/60
# 600/600 [==============================] - 0s 52us/step - loss: 0.6916 - acc: 0.5217 - val_loss: 0.6926 - val_acc: 0.5150
# Epoch 16/60
# 600/600 [==============================] - 0s 53us/step - loss: 0.6935 - acc: 0.5233 - val_loss: 0.6925 - val_acc: 0.5150
# Epoch 17/60
# 600/600 [==============================] - 0s 50us/step - loss: 0.6900 - acc: 0.5250 - val_loss: 0.6926 - val_acc: 0.5150
# Epoch 18/60
# 600/600 [==============================] - 0s 46us/step - loss: 0.6919 - acc: 0.5250 - val_loss: 0.6926 - val_acc: 0.5150
# Epoch 19/60
# 600/600 [==============================] - 0s 50us/step - loss: 0.6923 - acc: 0.5250 - val_loss: 0.6925 - val_acc: 0.5150
# Epoch 20/60
# 600/600 [==============================] - 0s 58us/step - loss: 0.6931 - acc: 0.5267 - val_loss: 0.6925 - val_acc: 0.5150
# Epoch 21/60
# 600/600 [==============================] - 0s 51us/step - loss: 0.6910 - acc: 0.5250 - val_loss: 0.6926 - val_acc: 0.5150
# Epoch 22/60
# 600/600 [==============================] - 0s 57us/step - loss: 0.6924 - acc: 0.5250 - val_loss: 0.6925 - val_acc: 0.5150
# Epoch 23/60
# 600/600 [==============================] - 0s 49us/step - loss: 0.6936 - acc: 0.5250 - val_loss: 0.6925 - val_acc: 0.5150
# Epoch 24/60
# 600/600 [==============================] - 0s 54us/step - loss: 0.6925 - acc: 0.5233 - val_loss: 0.6925 - val_acc: 0.5150
# Epoch 25/60
# 600/600 [==============================] - 0s 51us/step - loss: 0.6925 - acc: 0.5250 - val_loss: 0.6925 - val_acc: 0.5150
# Epoch 26/60
# 600/600 [==============================] - 0s 56us/step - loss: 0.6905 - acc: 0.5250 - val_loss: 0.6925 - val_acc: 0.5150
# Epoch 27/60
# 600/600 [==============================] - 0s 58us/step - loss: 0.6904 - acc: 0.5283 - val_loss: 0.6926 - val_acc: 0.5150
# Epoch 28/60
# 600/600 [==============================] - 0s 48us/step - loss: 0.6930 - acc: 0.5267 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 29/60
# 600/600 [==============================] - 0s 58us/step - loss: 0.6907 - acc: 0.5250 - val_loss: 0.6925 - val_acc: 0.5150
# Epoch 30/60
# 600/600 [==============================] - 0s 52us/step - loss: 0.6930 - acc: 0.5283 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 31/60
# 600/600 [==============================] - 0s 55us/step - loss: 0.6912 - acc: 0.5250 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 32/60
# 600/600 [==============================] - 0s 52us/step - loss: 0.6936 - acc: 0.5250 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 33/60
# 600/600 [==============================] - 0s 50us/step - loss: 0.6919 - acc: 0.5250 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 34/60
# 600/600 [==============================] - 0s 50us/step - loss: 0.6908 - acc: 0.5250 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 35/60
# 600/600 [==============================] - 0s 46us/step - loss: 0.6910 - acc: 0.5233 - val_loss: 0.6925 - val_acc: 0.5150
# Epoch 36/60
# 600/600 [==============================] - 0s 51us/step - loss: 0.6927 - acc: 0.5250 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 37/60
# 600/600 [==============================] - 0s 59us/step - loss: 0.6918 - acc: 0.5250 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 38/60
# 600/600 [==============================] - 0s 48us/step - loss: 0.6912 - acc: 0.5267 - val_loss: 0.6924 - val_acc: 0.5150
# Epoch 39/60
# 600/600 [==============================] - 0s 55us/step - loss: 0.6932 - acc: 0.5250 - val_loss: 0.6923 - val_acc: 0.5150
# Epoch 40/60
# 600/600 [==============================] - 0s 53us/step - loss: 0.6925 - acc: 0.5250 - val_loss: 0.6923 - val_acc: 0.5150
# Epoch 41/60
# 600/600 [==============================] - 0s 55us/step - loss: 0.6921 - acc: 0.5250 - val_loss: 0.6923 - val_acc: 0.5150
# Epoch 42/60
# 600/600 [==============================] - 0s 59us/step - loss: 0.6918 - acc: 0.5250 - val_loss: 0.6923 - val_acc: 0.5150
# Epoch 43/60
# 600/600 [==============================] - 0s 56us/step - loss: 0.6906 - acc: 0.5250 - val_loss: 0.6923 - val_acc: 0.5150
# Epoch 44/60
# 600/600 [==============================] - 0s 54us/step - loss: 0.6911 - acc: 0.5250 - val_loss: 0.6923 - val_acc: 0.5150
# Epoch 45/60
# 600/600 [==============================] - 0s 57us/step - loss: 0.6916 - acc: 0.5250 - val_loss: 0.6923 - val_acc: 0.5150
# Epoch 46/60
# 600/600 [==============================] - 0s 47us/step - loss: 0.6905 - acc: 0.5250 - val_loss: 0.6923 - val_acc: 0.5150
# Epoch 47/60
# 600/600 [==============================] - 0s 54us/step - loss: 0.6928 - acc: 0.5283 - val_loss: 0.6922 - val_acc: 0.5150
# Epoch 48/60
# 600/600 [==============================] - 0s 59us/step - loss: 0.6917 - acc: 0.5250 - val_loss: 0.6923 - val_acc: 0.5150
# Epoch 49/60
# 600/600 [==============================] - 0s 51us/step - loss: 0.6912 - acc: 0.5250 - val_loss: 0.6923 - val_acc: 0.5150
# Epoch 50/60
# 600/600 [==============================] - 0s 56us/step - loss: 0.6934 - acc: 0.5267 - val_loss: 0.6922 - val_acc: 0.5150
# Epoch 51/60
# 600/600 [==============================] - 0s 44us/step - loss: 0.6922 - acc: 0.5267 - val_loss: 0.6922 - val_acc: 0.5150
# Epoch 52/60
# 600/600 [==============================] - 0s 48us/step - loss: 0.6917 - acc: 0.5250 - val_loss: 0.6922 - val_acc: 0.5150
# Epoch 53/60
# 600/600 [==============================] - 0s 44us/step - loss: 0.6914 - acc: 0.5250 - val_loss: 0.6922 - val_acc: 0.5150
# Epoch 54/60
# 600/600 [==============================] - 0s 47us/step - loss: 0.6916 - acc: 0.5267 - val_loss: 0.6922 - val_acc: 0.5150
# Epoch 55/60
# 600/600 [==============================] - 0s 51us/step - loss: 0.6894 - acc: 0.5267 - val_loss: 0.6925 - val_acc: 0.5150
# Epoch 56/60
# 600/600 [==============================] - 0s 51us/step - loss: 0.6923 - acc: 0.5250 - val_loss: 0.6921 - val_acc: 0.5150
# Epoch 57/60
# 600/600 [==============================] - 0s 47us/step - loss: 0.6903 - acc: 0.5250 - val_loss: 0.6921 - val_acc: 0.5150
# Epoch 58/60
# 600/600 [==============================] - 0s 60us/step - loss: 0.6918 - acc: 0.5250 - val_loss: 0.6921 - val_acc: 0.5150
# Epoch 59/60
# 600/600 [==============================] - 0s 44us/step - loss: 0.6921 - acc: 0.5250 - val_loss: 0.6921 - val_acc: 0.5150
# Epoch 60/60
# 600/600 [==============================] - 0s 51us/step - loss: 0.6920 - acc: 0.5250 - val_loss: 0.6921 - val_acc: 0.5150
# 200/200 [==============================] - 0s 33us/step

# %%
accScores_neurone_kfold = Neurone_KFold(Galaxies, 3)
# Out:
# Train on 532 samples, validate on 266 samples
# Epoch 1/60
# 532/532 [==============================] - 1s 3ms/step - loss: 0.7811 - acc: 0.3120 - val_loss: 0.7008 - val_acc: 0.4925
# Epoch 2/60
# 532/532 [==============================] - 0s 61us/step - loss: 0.7744 - acc: 0.3252 - val_loss: 0.7000 - val_acc: 0.4925
# Epoch 3/60
# 532/532 [==============================] - 0s 52us/step - loss: 0.7607 - acc: 0.3496 - val_loss: 0.6993 - val_acc: 0.4925
# Epoch 4/60
# 532/532 [==============================] - 0s 60us/step - loss: 0.7654 - acc: 0.3327 - val_loss: 0.6986 - val_acc: 0.4925
# Epoch 5/60
# 532/532 [==============================] - 0s 62us/step - loss: 0.7514 - acc: 0.3327 - val_loss: 0.6980 - val_acc: 0.4925
# Epoch 6/60
# 532/532 [==============================] - 0s 55us/step - loss: 0.7535 - acc: 0.3515 - val_loss: 0.6975 - val_acc: 0.4925
# Epoch 7/60
# 532/532 [==============================] - 0s 65us/step - loss: 0.7481 - acc: 0.3853 - val_loss: 0.6970 - val_acc: 0.4925
# Epoch 8/60
# 532/532 [==============================] - 0s 49us/step - loss: 0.7451 - acc: 0.3703 - val_loss: 0.6965 - val_acc: 0.4925
# Epoch 9/60
# 532/532 [==============================] - 0s 53us/step - loss: 0.7491 - acc: 0.3440 - val_loss: 0.6960 - val_acc: 0.4925
# Epoch 10/60
# 532/532 [==============================] - 0s 58us/step - loss: 0.7446 - acc: 0.3759 - val_loss: 0.6956 - val_acc: 0.4925
# Epoch 11/60
# 532/532 [==============================] - 0s 55us/step - loss: 0.7442 - acc: 0.3835 - val_loss: 0.6952 - val_acc: 0.4925
# Epoch 12/60
# 532/532 [==============================] - 0s 63us/step - loss: 0.7272 - acc: 0.4267 - val_loss: 0.6948 - val_acc: 0.4925
# Epoch 13/60
# 532/532 [==============================] - 0s 50us/step - loss: 0.7275 - acc: 0.4436 - val_loss: 0.6945 - val_acc: 0.4925
# Epoch 14/60
# 532/532 [==============================] - 0s 62us/step - loss: 0.7300 - acc: 0.4248 - val_loss: 0.6943 - val_acc: 0.4925
# Epoch 15/60
# 532/532 [==============================] - 0s 50us/step - loss: 0.7188 - acc: 0.4662 - val_loss: 0.6940 - val_acc: 0.4925
# Epoch 16/60
# 532/532 [==============================] - 0s 54us/step - loss: 0.7147 - acc: 0.4737 - val_loss: 0.6938 - val_acc: 0.4925
# Epoch 17/60
# 532/532 [==============================] - 0s 53us/step - loss: 0.7187 - acc: 0.4436 - val_loss: 0.6936 - val_acc: 0.4925
# Epoch 18/60
# 532/532 [==============================] - 0s 54us/step - loss: 0.7149 - acc: 0.4774 - val_loss: 0.6934 - val_acc: 0.4925
# Epoch 19/60
# 532/532 [==============================] - 0s 54us/step - loss: 0.7069 - acc: 0.4643 - val_loss: 0.6933 - val_acc: 0.4925
# Epoch 20/60
# 532/532 [==============================] - 0s 50us/step - loss: 0.7183 - acc: 0.4267 - val_loss: 0.6932 - val_acc: 0.4925
# Epoch 21/60
# 532/532 [==============================] - 0s 63us/step - loss: 0.7072 - acc: 0.4831 - val_loss: 0.6931 - val_acc: 0.4925
# Epoch 22/60
# 532/532 [==============================] - 0s 55us/step - loss: 0.6990 - acc: 0.5056 - val_loss: 0.6930 - val_acc: 0.5075
# Epoch 23/60
# 532/532 [==============================] - 0s 55us/step - loss: 0.6896 - acc: 0.5602 - val_loss: 0.6930 - val_acc: 0.5075
# Epoch 24/60
# 532/532 [==============================] - 0s 43us/step - loss: 0.7039 - acc: 0.4925 - val_loss: 0.6929 - val_acc: 0.5075
# Epoch 25/60
# 532/532 [==============================] - 0s 53us/step - loss: 0.6878 - acc: 0.5451 - val_loss: 0.6929 - val_acc: 0.5075
# Epoch 26/60
# 532/532 [==============================] - 0s 57us/step - loss: 0.6930 - acc: 0.5338 - val_loss: 0.6929 - val_acc: 0.5075
# Epoch 27/60
# 532/532 [==============================] - 0s 58us/step - loss: 0.6823 - acc: 0.5714 - val_loss: 0.6930 - val_acc: 0.5075
# Epoch 28/60
# 532/532 [==============================] - 0s 58us/step - loss: 0.6910 - acc: 0.5207 - val_loss: 0.6931 - val_acc: 0.5075
# Epoch 29/60
# 532/532 [==============================] - 0s 53us/step - loss: 0.6866 - acc: 0.5658 - val_loss: 0.6931 - val_acc: 0.5075
# Epoch 30/60
# 532/532 [==============================] - 0s 53us/step - loss: 0.6779 - acc: 0.5752 - val_loss: 0.6932 - val_acc: 0.5075
# Epoch 31/60
# 532/532 [==============================] - 0s 62us/step - loss: 0.6816 - acc: 0.5695 - val_loss: 0.6934 - val_acc: 0.5075
# Epoch 32/60
# 532/532 [==============================] - 0s 54us/step - loss: 0.6715 - acc: 0.5921 - val_loss: 0.6935 - val_acc: 0.5075
# Epoch 33/60
# 532/532 [==============================] - 0s 57us/step - loss: 0.6713 - acc: 0.5940 - val_loss: 0.6937 - val_acc: 0.5075
# Epoch 34/60
# 532/532 [==============================] - 0s 53us/step - loss: 0.6782 - acc: 0.5695 - val_loss: 0.6938 - val_acc: 0.5075
# Epoch 35/60
# 532/532 [==============================] - 0s 57us/step - loss: 0.6722 - acc: 0.5959 - val_loss: 0.6940 - val_acc: 0.5075
# Epoch 36/60
# 532/532 [==============================] - 0s 47us/step - loss: 0.6678 - acc: 0.6053 - val_loss: 0.6943 - val_acc: 0.5075
# Epoch 37/60
# 532/532 [==============================] - 0s 54us/step - loss: 0.6642 - acc: 0.6297 - val_loss: 0.6945 - val_acc: 0.5075
# Epoch 38/60
# 532/532 [==============================] - 0s 51us/step - loss: 0.6672 - acc: 0.6259 - val_loss: 0.6947 - val_acc: 0.5075
# Epoch 39/60
# 532/532 [==============================] - 0s 46us/step - loss: 0.6667 - acc: 0.6372 - val_loss: 0.6950 - val_acc: 0.5075
# Epoch 40/60
# 532/532 [==============================] - 0s 53us/step - loss: 0.6588 - acc: 0.6635 - val_loss: 0.6952 - val_acc: 0.5075
# Epoch 41/60
# 532/532 [==============================] - 0s 49us/step - loss: 0.6569 - acc: 0.6654 - val_loss: 0.6955 - val_acc: 0.5075
# Epoch 42/60
# 532/532 [==============================] - 0s 49us/step - loss: 0.6615 - acc: 0.6203 - val_loss: 0.6958 - val_acc: 0.5075
# Epoch 43/60
# 532/532 [==============================] - 0s 53us/step - loss: 0.6485 - acc: 0.6579 - val_loss: 0.6961 - val_acc: 0.5075
# Epoch 44/60
# 532/532 [==============================] - 0s 57us/step - loss: 0.6534 - acc: 0.6523 - val_loss: 0.6965 - val_acc: 0.5075
# Epoch 45/60
# 532/532 [==============================] - 0s 49us/step - loss: 0.6471 - acc: 0.6729 - val_loss: 0.6968 - val_acc: 0.5075
# Epoch 46/60
# 532/532 [==============================] - 0s 54us/step - loss: 0.6450 - acc: 0.6823 - val_loss: 0.6972 - val_acc: 0.5075
# Epoch 47/60
# 532/532 [==============================] - 0s 48us/step - loss: 0.6422 - acc: 0.7068 - val_loss: 0.6976 - val_acc: 0.5075
# Epoch 48/60
# 532/532 [==============================] - 0s 55us/step - loss: 0.6350 - acc: 0.7086 - val_loss: 0.6979 - val_acc: 0.5075
# Epoch 49/60
# 532/532 [==============================] - 0s 59us/step - loss: 0.6381 - acc: 0.7068 - val_loss: 0.6983 - val_acc: 0.5075
# Epoch 50/60
# 532/532 [==============================] - 0s 51us/step - loss: 0.6420 - acc: 0.6936 - val_loss: 0.6987 - val_acc: 0.5075
# Epoch 51/60
# 532/532 [==============================] - 0s 62us/step - loss: 0.6407 - acc: 0.6936 - val_loss: 0.6992 - val_acc: 0.5075
# Epoch 52/60
# 532/532 [==============================] - 0s 59us/step - loss: 0.6408 - acc: 0.6917 - val_loss: 0.6996 - val_acc: 0.5075
# Epoch 53/60
# 532/532 [==============================] - 0s 50us/step - loss: 0.6420 - acc: 0.6936 - val_loss: 0.7001 - val_acc: 0.5075
# Epoch 54/60
# 532/532 [==============================] - 0s 61us/step - loss: 0.6323 - acc: 0.7180 - val_loss: 0.7005 - val_acc: 0.5075
# Epoch 55/60
# 532/532 [==============================] - 0s 48us/step - loss: 0.6257 - acc: 0.7350 - val_loss: 0.7010 - val_acc: 0.5075
# Epoch 56/60
# 532/532 [==============================] - 0s 54us/step - loss: 0.6240 - acc: 0.7199 - val_loss: 0.7014 - val_acc: 0.5075
# Epoch 57/60
# 532/532 [==============================] - 0s 64us/step - loss: 0.6307 - acc: 0.7293 - val_loss: 0.7019 - val_acc: 0.5075
# Epoch 58/60
# 532/532 [==============================] - 0s 57us/step - loss: 0.6323 - acc: 0.7293 - val_loss: 0.7025 - val_acc: 0.5075
# Epoch 59/60
# 532/532 [==============================] - 0s 52us/step - loss: 0.6255 - acc: 0.7105 - val_loss: 0.7030 - val_acc: 0.5075
# Epoch 60/60
# 532/532 [==============================] - 0s 56us/step - loss: 0.6241 - acc: 0.7256 - val_loss: 0.7035 - val_acc: 0.5075
# 200/200 [==============================] - 0s 52us/step
# Train on 532 samples, validate on 266 samples
# Epoch 1/60
# 532/532 [==============================] - 1s 3ms/step - loss: 0.6300 - acc: 0.7782 - val_loss: 0.6996 - val_acc: 0.5075
# Epoch 2/60
# 532/532 [==============================] - 0s 44us/step - loss: 0.6310 - acc: 0.7782 - val_loss: 0.6997 - val_acc: 0.5075
# Epoch 3/60
# 532/532 [==============================] - 0s 45us/step - loss: 0.6236 - acc: 0.7782 - val_loss: 0.6998 - val_acc: 0.5075
# Epoch 4/60
# 532/532 [==============================] - 0s 41us/step - loss: 0.6265 - acc: 0.7763 - val_loss: 0.6999 - val_acc: 0.5075
# Epoch 5/60
# 532/532 [==============================] - 0s 42us/step - loss: 0.6299 - acc: 0.7782 - val_loss: 0.7000 - val_acc: 0.5075
# Epoch 6/60
# 532/532 [==============================] - 0s 46us/step - loss: 0.6266 - acc: 0.7801 - val_loss: 0.7000 - val_acc: 0.5075
# Epoch 7/60
# 532/532 [==============================] - 0s 38us/step - loss: 0.6254 - acc: 0.7820 - val_loss: 0.7001 - val_acc: 0.5075
# Epoch 8/60
# 532/532 [==============================] - 0s 41us/step - loss: 0.6269 - acc: 0.7801 - val_loss: 0.7002 - val_acc: 0.5075
# Epoch 9/60
# 532/532 [==============================] - 0s 40us/step - loss: 0.6244 - acc: 0.7763 - val_loss: 0.7003 - val_acc: 0.5075
# Epoch 10/60
# 532/532 [==============================] - 0s 32us/step - loss: 0.6309 - acc: 0.7801 - val_loss: 0.7004 - val_acc: 0.5075
# Epoch 11/60
# 532/532 [==============================] - 0s 44us/step - loss: 0.6314 - acc: 0.7744 - val_loss: 0.7004 - val_acc: 0.5075
# Epoch 12/60
# 532/532 [==============================] - 0s 39us/step - loss: 0.6223 - acc: 0.7801 - val_loss: 0.7005 - val_acc: 0.5075
# Epoch 13/60
# 532/532 [==============================] - 0s 39us/step - loss: 0.6271 - acc: 0.7763 - val_loss: 0.7006 - val_acc: 0.5075
# Epoch 14/60
# 532/532 [==============================] - 0s 47us/step - loss: 0.6260 - acc: 0.7782 - val_loss: 0.7007 - val_acc: 0.5075
# Epoch 15/60
# 532/532 [==============================] - 0s 47us/step - loss: 0.6240 - acc: 0.7801 - val_loss: 0.7008 - val_acc: 0.5075
# Epoch 16/60
# 532/532 [==============================] - 0s 49us/step - loss: 0.6259 - acc: 0.7801 - val_loss: 0.7009 - val_acc: 0.5075
# Epoch 17/60
# 532/532 [==============================] - 0s 50us/step - loss: 0.6236 - acc: 0.7782 - val_loss: 0.7009 - val_acc: 0.5075
# Epoch 18/60
# 532/532 [==============================] - 0s 52us/step - loss: 0.6255 - acc: 0.7782 - val_loss: 0.7010 - val_acc: 0.5075
# Epoch 19/60
# 532/532 [==============================] - 0s 44us/step - loss: 0.6257 - acc: 0.7744 - val_loss: 0.7011 - val_acc: 0.5075
# Epoch 20/60
# 532/532 [==============================] - 0s 45us/step - loss: 0.6268 - acc: 0.7801 - val_loss: 0.7012 - val_acc: 0.5075
# Epoch 21/60
# 532/532 [==============================] - 0s 41us/step - loss: 0.6230 - acc: 0.7801 - val_loss: 0.7013 - val_acc: 0.5075
# Epoch 22/60
# 532/532 [==============================] - 0s 42us/step - loss: 0.6275 - acc: 0.7763 - val_loss: 0.7014 - val_acc: 0.5075
# Epoch 23/60
# 532/532 [==============================] - 0s 52us/step - loss: 0.6190 - acc: 0.7782 - val_loss: 0.7015 - val_acc: 0.5075
# Epoch 24/60
# 532/532 [==============================] - 0s 38us/step - loss: 0.6212 - acc: 0.7782 - val_loss: 0.7015 - val_acc: 0.5075
# Epoch 25/60
# 532/532 [==============================] - 0s 47us/step - loss: 0.6211 - acc: 0.7782 - val_loss: 0.7016 - val_acc: 0.5075
# Epoch 26/60
# 532/532 [==============================] - 0s 45us/step - loss: 0.6187 - acc: 0.7782 - val_loss: 0.7017 - val_acc: 0.5075
# Epoch 27/60
# 532/532 [==============================] - 0s 46us/step - loss: 0.6268 - acc: 0.7820 - val_loss: 0.7018 - val_acc: 0.5075
# Epoch 28/60
# 532/532 [==============================] - 0s 41us/step - loss: 0.6217 - acc: 0.7801 - val_loss: 0.7019 - val_acc: 0.5075
# Epoch 29/60
# 532/532 [==============================] - 0s 43us/step - loss: 0.6251 - acc: 0.7763 - val_loss: 0.7020 - val_acc: 0.5075
# Epoch 30/60
# 532/532 [==============================] - 0s 61us/step - loss: 0.6205 - acc: 0.7782 - val_loss: 0.7021 - val_acc: 0.5075
# Epoch 31/60
# 532/532 [==============================] - 0s 52us/step - loss: 0.6231 - acc: 0.7763 - val_loss: 0.7022 - val_acc: 0.5075
# Epoch 32/60
# 532/532 [==============================] - 0s 46us/step - loss: 0.6242 - acc: 0.7782 - val_loss: 0.7023 - val_acc: 0.5075
# Epoch 33/60
# 532/532 [==============================] - 0s 45us/step - loss: 0.6233 - acc: 0.7782 - val_loss: 0.7024 - val_acc: 0.5075
# Epoch 34/60
# 532/532 [==============================] - 0s 47us/step - loss: 0.6201 - acc: 0.7763 - val_loss: 0.7025 - val_acc: 0.5075
# Epoch 35/60
# 532/532 [==============================] - 0s 39us/step - loss: 0.6181 - acc: 0.7801 - val_loss: 0.7026 - val_acc: 0.5075
# Epoch 36/60
# 532/532 [==============================] - 0s 49us/step - loss: 0.6185 - acc: 0.7801 - val_loss: 0.7027 - val_acc: 0.5075
# Epoch 37/60
# 532/532 [==============================] - 0s 48us/step - loss: 0.6225 - acc: 0.7763 - val_loss: 0.7028 - val_acc: 0.5075
# Epoch 38/60
# 532/532 [==============================] - 0s 41us/step - loss: 0.6137 - acc: 0.7801 - val_loss: 0.7029 - val_acc: 0.5075
# Epoch 39/60
# 532/532 [==============================] - 0s 43us/step - loss: 0.6161 - acc: 0.7820 - val_loss: 0.7030 - val_acc: 0.5075
# Epoch 40/60
# 532/532 [==============================] - 0s 41us/step - loss: 0.6190 - acc: 0.7801 - val_loss: 0.7031 - val_acc: 0.5075
# Epoch 41/60
# 532/532 [==============================] - 0s 42us/step - loss: 0.6163 - acc: 0.7782 - val_loss: 0.7032 - val_acc: 0.5075
# Epoch 42/60
# 532/532 [==============================] - 0s 45us/step - loss: 0.6156 - acc: 0.7801 - val_loss: 0.7033 - val_acc: 0.5075
# Epoch 43/60
# 532/532 [==============================] - 0s 45us/step - loss: 0.6174 - acc: 0.7801 - val_loss: 0.7034 - val_acc: 0.5075
# Epoch 44/60
# 532/532 [==============================] - 0s 50us/step - loss: 0.6168 - acc: 0.7782 - val_loss: 0.7035 - val_acc: 0.5075
# Epoch 45/60
# 532/532 [==============================] - 0s 52us/step - loss: 0.6184 - acc: 0.7801 - val_loss: 0.7036 - val_acc: 0.5075
# Epoch 46/60
# 532/532 [==============================] - 0s 47us/step - loss: 0.6137 - acc: 0.7763 - val_loss: 0.7037 - val_acc: 0.5075
# Epoch 47/60
# 532/532 [==============================] - 0s 43us/step - loss: 0.6141 - acc: 0.7801 - val_loss: 0.7038 - val_acc: 0.5075
# Epoch 48/60
# 532/532 [==============================] - 0s 40us/step - loss: 0.6176 - acc: 0.7801 - val_loss: 0.7039 - val_acc: 0.5075
# Epoch 49/60
# 532/532 [==============================] - 0s 43us/step - loss: 0.6147 - acc: 0.7782 - val_loss: 0.7040 - val_acc: 0.5075
# Epoch 50/60
# 532/532 [==============================] - 0s 50us/step - loss: 0.6146 - acc: 0.7801 - val_loss: 0.7041 - val_acc: 0.5075
# Epoch 51/60
# 532/532 [==============================] - 0s 51us/step - loss: 0.6149 - acc: 0.7782 - val_loss: 0.7042 - val_acc: 0.5075
# Epoch 52/60
# 532/532 [==============================] - 0s 46us/step - loss: 0.6146 - acc: 0.7801 - val_loss: 0.7043 - val_acc: 0.5075
# Epoch 53/60
# 532/532 [==============================] - 0s 49us/step - loss: 0.6149 - acc: 0.7801 - val_loss: 0.7044 - val_acc: 0.5075
# Epoch 54/60
# 532/532 [==============================] - 0s 51us/step - loss: 0.6147 - acc: 0.7801 - val_loss: 0.7045 - val_acc: 0.5075
# Epoch 55/60
# 532/532 [==============================] - 0s 44us/step - loss: 0.6131 - acc: 0.7801 - val_loss: 0.7046 - val_acc: 0.5075
# Epoch 56/60
# 532/532 [==============================] - 0s 43us/step - loss: 0.6135 - acc: 0.7801 - val_loss: 0.7047 - val_acc: 0.5075
# Epoch 57/60
# 532/532 [==============================] - 0s 40us/step - loss: 0.6128 - acc: 0.7801 - val_loss: 0.7049 - val_acc: 0.5075
# Epoch 58/60
# 532/532 [==============================] - 0s 47us/step - loss: 0.6137 - acc: 0.7801 - val_loss: 0.7050 - val_acc: 0.5075
# Epoch 59/60
# 532/532 [==============================] - 0s 52us/step - loss: 0.6145 - acc: 0.7801 - val_loss: 0.7051 - val_acc: 0.5075
# Epoch 60/60
# 532/532 [==============================] - 0s 42us/step - loss: 0.6120 - acc: 0.7801 - val_loss: 0.7052 - val_acc: 0.5075
# 200/200 [==============================] - 0s 56us/step
# Train on 532 samples, validate on 266 samples
# Epoch 1/60
# 532/532 [==============================] - 2s 3ms/step - loss: 0.7013 - acc: 0.4793 - val_loss: 0.6931 - val_acc: 0.5376
# Epoch 2/60
# 532/532 [==============================] - 0s 153us/step - loss: 0.7021 - acc: 0.4756 - val_loss: 0.6930 - val_acc: 0.5075
# Epoch 3/60
# 532/532 [==============================] - 0s 127us/step - loss: 0.6880 - acc: 0.5508 - val_loss: 0.6931 - val_acc: 0.5075
# Epoch 4/60
# 532/532 [==============================] - 0s 117us/step - loss: 0.6836 - acc: 0.5639 - val_loss: 0.6934 - val_acc: 0.5075
# Epoch 5/60
# 532/532 [==============================] - 0s 123us/step - loss: 0.6686 - acc: 0.5959 - val_loss: 0.6939 - val_acc: 0.5075
# Epoch 6/60
# 532/532 [==============================] - 0s 235us/step - loss: 0.6745 - acc: 0.5902 - val_loss: 0.6946 - val_acc: 0.5075
# Epoch 7/60
# 532/532 [==============================] - 0s 119us/step - loss: 0.6589 - acc: 0.6128 - val_loss: 0.6954 - val_acc: 0.5075
# Epoch 8/60
# 532/532 [==============================] - 0s 132us/step - loss: 0.6636 - acc: 0.6259 - val_loss: 0.6963 - val_acc: 0.5075
# Epoch 9/60
# 532/532 [==============================] - 0s 122us/step - loss: 0.6445 - acc: 0.6917 - val_loss: 0.6973 - val_acc: 0.5075
# Epoch 10/60
# 532/532 [==============================] - 0s 113us/step - loss: 0.6537 - acc: 0.6711 - val_loss: 0.6984 - val_acc: 0.5075
# Epoch 11/60
# 532/532 [==============================] - 0s 126us/step - loss: 0.6342 - acc: 0.7011 - val_loss: 0.6997 - val_acc: 0.5075
# Epoch 12/60
# 532/532 [==============================] - 0s 123us/step - loss: 0.6442 - acc: 0.6748 - val_loss: 0.7011 - val_acc: 0.5075
# Epoch 13/60
# 532/532 [==============================] - 0s 117us/step - loss: 0.6373 - acc: 0.7237 - val_loss: 0.7027 - val_acc: 0.5075
# Epoch 14/60
# 532/532 [==============================] - 0s 129us/step - loss: 0.6268 - acc: 0.7030 - val_loss: 0.7043 - val_acc: 0.5075
# Epoch 15/60
# 532/532 [==============================] - 0s 117us/step - loss: 0.6193 - acc: 0.7180 - val_loss: 0.7059 - val_acc: 0.5075
# Epoch 16/60
# 532/532 [==============================] - 0s 140us/step - loss: 0.6149 - acc: 0.7462 - val_loss: 0.7076 - val_acc: 0.5075
# Epoch 17/60
# 532/532 [==============================] - 0s 109us/step - loss: 0.6065 - acc: 0.7444 - val_loss: 0.7095 - val_acc: 0.5075
# Epoch 18/60
# 532/532 [==============================] - 0s 119us/step - loss: 0.6141 - acc: 0.7368 - val_loss: 0.7114 - val_acc: 0.5075
# Epoch 19/60
# 532/532 [==============================] - 0s 129us/step - loss: 0.6075 - acc: 0.7538 - val_loss: 0.7136 - val_acc: 0.5075
# Epoch 20/60
# 532/532 [==============================] - 0s 123us/step - loss: 0.5970 - acc: 0.7350 - val_loss: 0.7158 - val_acc: 0.5075
# Epoch 21/60
# 532/532 [==============================] - 0s 116us/step - loss: 0.5961 - acc: 0.7538 - val_loss: 0.7178 - val_acc: 0.5075
# Epoch 22/60
# 532/532 [==============================] - 0s 112us/step - loss: 0.6008 - acc: 0.7688 - val_loss: 0.7197 - val_acc: 0.5075
# Epoch 23/60
# 532/532 [==============================] - 0s 125us/step - loss: 0.5913 - acc: 0.7688 - val_loss: 0.7218 - val_acc: 0.5075
# Epoch 24/60
# 532/532 [==============================] - 0s 126us/step - loss: 0.5963 - acc: 0.7669 - val_loss: 0.7242 - val_acc: 0.5075
# Epoch 25/60
# 532/532 [==============================] - 0s 121us/step - loss: 0.5837 - acc: 0.7575 - val_loss: 0.7266 - val_acc: 0.5075
# Epoch 26/60
# 532/532 [==============================] - 0s 119us/step - loss: 0.5962 - acc: 0.7820 - val_loss: 0.7286 - val_acc: 0.5075
# Epoch 27/60
# 532/532 [==============================] - 0s 118us/step - loss: 0.5839 - acc: 0.7820 - val_loss: 0.7310 - val_acc: 0.5075
# Epoch 28/60
# 532/532 [==============================] - 0s 126us/step - loss: 0.5756 - acc: 0.7707 - val_loss: 0.7337 - val_acc: 0.5075
# Epoch 29/60
# 532/532 [==============================] - 0s 125us/step - loss: 0.5777 - acc: 0.7838 - val_loss: 0.7364 - val_acc: 0.5075
# Epoch 30/60
# 532/532 [==============================] - 0s 116us/step - loss: 0.5768 - acc: 0.7820 - val_loss: 0.7390 - val_acc: 0.5075
# Epoch 31/60
# 532/532 [==============================] - 0s 117us/step - loss: 0.5754 - acc: 0.7669 - val_loss: 0.7416 - val_acc: 0.5075
# Epoch 32/60
# 532/532 [==============================] - 0s 124us/step - loss: 0.5647 - acc: 0.7744 - val_loss: 0.7442 - val_acc: 0.5075
# Epoch 33/60
# 532/532 [==============================] - 0s 131us/step - loss: 0.5646 - acc: 0.7744 - val_loss: 0.7471 - val_acc: 0.5075
# Epoch 34/60
# 532/532 [==============================] - 0s 130us/step - loss: 0.5629 - acc: 0.7726 - val_loss: 0.7495 - val_acc: 0.5075
# Epoch 35/60
# 532/532 [==============================] - 0s 109us/step - loss: 0.5720 - acc: 0.7801 - val_loss: 0.7520 - val_acc: 0.5075
# Epoch 36/60
# 532/532 [==============================] - 0s 120us/step - loss: 0.5784 - acc: 0.7744 - val_loss: 0.7544 - val_acc: 0.5075
# Epoch 37/60
# 532/532 [==============================] - 0s 116us/step - loss: 0.5605 - acc: 0.7801 - val_loss: 0.7563 - val_acc: 0.5075
# Epoch 38/60
# 532/532 [==============================] - 0s 116us/step - loss: 0.5648 - acc: 0.7782 - val_loss: 0.7587 - val_acc: 0.5075
# Epoch 39/60
# 532/532 [==============================] - 0s 115us/step - loss: 0.5653 - acc: 0.7801 - val_loss: 0.7615 - val_acc: 0.5075
# Epoch 40/60
# 532/532 [==============================] - 0s 115us/step - loss: 0.5670 - acc: 0.7801 - val_loss: 0.7636 - val_acc: 0.5075
# Epoch 41/60
# 532/532 [==============================] - 0s 124us/step - loss: 0.5585 - acc: 0.7763 - val_loss: 0.7659 - val_acc: 0.5075
# Epoch 42/60
# 532/532 [==============================] - 0s 110us/step - loss: 0.5445 - acc: 0.7801 - val_loss: 0.7684 - val_acc: 0.5075
# Epoch 43/60
# 532/532 [==============================] - 0s 120us/step - loss: 0.5546 - acc: 0.7801 - val_loss: 0.7708 - val_acc: 0.5075
# Epoch 44/60
# 532/532 [==============================] - 0s 117us/step - loss: 0.5445 - acc: 0.7782 - val_loss: 0.7733 - val_acc: 0.5075
# Epoch 45/60
# 532/532 [==============================] - 0s 141us/step - loss: 0.5590 - acc: 0.7801 - val_loss: 0.7760 - val_acc: 0.5075
# Epoch 46/60
# 532/532 [==============================] - 0s 128us/step - loss: 0.5456 - acc: 0.7820 - val_loss: 0.7785 - val_acc: 0.5075
# Epoch 47/60
# 532/532 [==============================] - 0s 110us/step - loss: 0.5453 - acc: 0.7782 - val_loss: 0.7809 - val_acc: 0.5075
# Epoch 48/60
# 532/532 [==============================] - 0s 104us/step - loss: 0.5517 - acc: 0.7782 - val_loss: 0.7833 - val_acc: 0.5075
# Epoch 49/60
# 532/532 [==============================] - 0s 118us/step - loss: 0.5443 - acc: 0.7801 - val_loss: 0.7854 - val_acc: 0.5075
# Epoch 50/60
# 532/532 [==============================] - 0s 113us/step - loss: 0.5498 - acc: 0.7801 - val_loss: 0.7876 - val_acc: 0.5075
# Epoch 51/60
# 532/532 [==============================] - 0s 117us/step - loss: 0.5568 - acc: 0.7801 - val_loss: 0.7897 - val_acc: 0.5075
# Epoch 52/60
# 532/532 [==============================] - 0s 124us/step - loss: 0.5557 - acc: 0.7763 - val_loss: 0.7915 - val_acc: 0.5075
# Epoch 53/60
# 532/532 [==============================] - 0s 113us/step - loss: 0.5508 - acc: 0.7801 - val_loss: 0.7936 - val_acc: 0.5075
# Epoch 54/60
# 532/532 [==============================] - 0s 130us/step - loss: 0.5480 - acc: 0.7782 - val_loss: 0.7957 - val_acc: 0.5075
# Epoch 55/60
# 532/532 [==============================] - 0s 130us/step - loss: 0.5463 - acc: 0.7801 - val_loss: 0.7975 - val_acc: 0.5075
# Epoch 56/60
# 532/532 [==============================] - 0s 108us/step - loss: 0.5483 - acc: 0.7801 - val_loss: 0.7995 - val_acc: 0.5075
# Epoch 57/60
# 532/532 [==============================] - 0s 105us/step - loss: 0.5449 - acc: 0.7801 - val_loss: 0.8014 - val_acc: 0.5075
# Epoch 58/60
# 532/532 [==============================] - 0s 128us/step - loss: 0.5425 - acc: 0.7801 - val_loss: 0.8036 - val_acc: 0.5075
# Epoch 59/60
# 532/532 [==============================] - 0s 144us/step - loss: 0.5430 - acc: 0.7801 - val_loss: 0.8057 - val_acc: 0.5075
# Epoch 60/60
# 532/532 [==============================] - 0s 129us/step - loss: 0.5443 - acc: 0.7801 - val_loss: 0.8076 - val_acc: 0.5075
# 200/200 [==============================] - 0s 78us/step
# Train on 532 samples, validate on 266 samples
# Epoch 1/60
# 532/532 [==============================] - 2s 3ms/step - loss: 0.5465 - acc: 0.7801 - val_loss: 0.7947 - val_acc: 0.5075
# Epoch 2/60
# 532/532 [==============================] - 0s 324us/step - loss: 0.5441 - acc: 0.7801 - val_loss: 0.7984 - val_acc: 0.5075
# Epoch 3/60
# 532/532 [==============================] - 0s 323us/step - loss: 0.5424 - acc: 0.7801 - val_loss: 0.8016 - val_acc: 0.5075
# Epoch 4/60
# 532/532 [==============================] - 0s 310us/step - loss: 0.5415 - acc: 0.7801 - val_loss: 0.8050 - val_acc: 0.5075
# Epoch 5/60
# 532/532 [==============================] - 0s 308us/step - loss: 0.5371 - acc: 0.7801 - val_loss: 0.8083 - val_acc: 0.5075
# Epoch 6/60
# 532/532 [==============================] - 0s 332us/step - loss: 0.5326 - acc: 0.7801 - val_loss: 0.8112 - val_acc: 0.5075
# Epoch 7/60
# 532/532 [==============================] - 0s 336us/step - loss: 0.5382 - acc: 0.7801 - val_loss: 0.8142 - val_acc: 0.5075
# Epoch 8/60
# 532/532 [==============================] - 0s 306us/step - loss: 0.5397 - acc: 0.7801 - val_loss: 0.8160 - val_acc: 0.5075
# Epoch 9/60
# 532/532 [==============================] - 0s 332us/step - loss: 0.5423 - acc: 0.7801 - val_loss: 0.8179 - val_acc: 0.5075
# Epoch 10/60
# 532/532 [==============================] - 0s 313us/step - loss: 0.5325 - acc: 0.7801 - val_loss: 0.8205 - val_acc: 0.5075
# Epoch 11/60
# 532/532 [==============================] - 0s 311us/step - loss: 0.5397 - acc: 0.7801 - val_loss: 0.8224 - val_acc: 0.5075
# Epoch 12/60
# 532/532 [==============================] - 0s 329us/step - loss: 0.5422 - acc: 0.7801 - val_loss: 0.8249 - val_acc: 0.5075
# Epoch 13/60
# 532/532 [==============================] - 0s 336us/step - loss: 0.5353 - acc: 0.7801 - val_loss: 0.8282 - val_acc: 0.5075
# Epoch 14/60
# 532/532 [==============================] - 0s 304us/step - loss: 0.5333 - acc: 0.7801 - val_loss: 0.8300 - val_acc: 0.5075
# Epoch 15/60
# 532/532 [==============================] - 0s 328us/step - loss: 0.5365 - acc: 0.7801 - val_loss: 0.8324 - val_acc: 0.5075
# Epoch 16/60
# 532/532 [==============================] - 0s 309us/step - loss: 0.5438 - acc: 0.7801 - val_loss: 0.8342 - val_acc: 0.5075
# Epoch 17/60
# 532/532 [==============================] - 0s 328us/step - loss: 0.5319 - acc: 0.7801 - val_loss: 0.8365 - val_acc: 0.5075
# Epoch 18/60
# 532/532 [==============================] - 0s 323us/step - loss: 0.5343 - acc: 0.7801 - val_loss: 0.8396 - val_acc: 0.5075
# Epoch 19/60
# 532/532 [==============================] - 0s 343us/step - loss: 0.5391 - acc: 0.7801 - val_loss: 0.8415 - val_acc: 0.5075
# Epoch 20/60
# 532/532 [==============================] - 0s 305us/step - loss: 0.5443 - acc: 0.7801 - val_loss: 0.8427 - val_acc: 0.5075
# Epoch 21/60
# 532/532 [==============================] - 0s 306us/step - loss: 0.5354 - acc: 0.7801 - val_loss: 0.8443 - val_acc: 0.5075
# Epoch 22/60
# 532/532 [==============================] - 0s 309us/step - loss: 0.5381 - acc: 0.7801 - val_loss: 0.8457 - val_acc: 0.5075
# Epoch 23/60
# 532/532 [==============================] - 0s 326us/step - loss: 0.5295 - acc: 0.7801 - val_loss: 0.8472 - val_acc: 0.5075
# Epoch 24/60
# 532/532 [==============================] - 0s 319us/step - loss: 0.5432 - acc: 0.7801 - val_loss: 0.8478 - val_acc: 0.5075
# Epoch 25/60
# 532/532 [==============================] - 0s 303us/step - loss: 0.5324 - acc: 0.7801 - val_loss: 0.8486 - val_acc: 0.5075
# Epoch 26/60
# 532/532 [==============================] - 0s 328us/step - loss: 0.5326 - acc: 0.7801 - val_loss: 0.8490 - val_acc: 0.5075
# Epoch 27/60
# 532/532 [==============================] - 0s 305us/step - loss: 0.5364 - acc: 0.7801 - val_loss: 0.8515 - val_acc: 0.5075
# Epoch 28/60
# 532/532 [==============================] - 0s 298us/step - loss: 0.5340 - acc: 0.7801 - val_loss: 0.8535 - val_acc: 0.5075
# Epoch 29/60
# 532/532 [==============================] - 0s 311us/step - loss: 0.5361 - acc: 0.7801 - val_loss: 0.8557 - val_acc: 0.5075
# Epoch 30/60
# 532/532 [==============================] - 0s 316us/step - loss: 0.5334 - acc: 0.7801 - val_loss: 0.8563 - val_acc: 0.5075
# Epoch 31/60
# 532/532 [==============================] - 0s 307us/step - loss: 0.5366 - acc: 0.7801 - val_loss: 0.8572 - val_acc: 0.5075
# Epoch 32/60
# 532/532 [==============================] - 0s 300us/step - loss: 0.5392 - acc: 0.7801 - val_loss: 0.8581 - val_acc: 0.5075
# Epoch 33/60
# 532/532 [==============================] - 0s 322us/step - loss: 0.5306 - acc: 0.7801 - val_loss: 0.8595 - val_acc: 0.5075
# Epoch 34/60
# 532/532 [==============================] - 0s 334us/step - loss: 0.5295 - acc: 0.7801 - val_loss: 0.8601 - val_acc: 0.5075
# Epoch 35/60
# 532/532 [==============================] - 0s 330us/step - loss: 0.5422 - acc: 0.7801 - val_loss: 0.8605 - val_acc: 0.5075
# Epoch 36/60
# 532/532 [==============================] - 0s 294us/step - loss: 0.5387 - acc: 0.7801 - val_loss: 0.8610 - val_acc: 0.5075
# Epoch 37/60
# 532/532 [==============================] - 0s 315us/step - loss: 0.5236 - acc: 0.7801 - val_loss: 0.8614 - val_acc: 0.5075
# Epoch 38/60
# 532/532 [==============================] - 0s 344us/step - loss: 0.5306 - acc: 0.7801 - val_loss: 0.8619 - val_acc: 0.5075
# Epoch 39/60
# 532/532 [==============================] - 0s 316us/step - loss: 0.5362 - acc: 0.7801 - val_loss: 0.8623 - val_acc: 0.5075
# Epoch 40/60
# 532/532 [==============================] - 0s 305us/step - loss: 0.5428 - acc: 0.7801 - val_loss: 0.8617 - val_acc: 0.5075
# Epoch 41/60
# 532/532 [==============================] - 0s 305us/step - loss: 0.5381 - acc: 0.7801 - val_loss: 0.8627 - val_acc: 0.5075
# Epoch 42/60
# 532/532 [==============================] - 0s 304us/step - loss: 0.5327 - acc: 0.7801 - val_loss: 0.8639 - val_acc: 0.5075
# Epoch 43/60
# 532/532 [==============================] - 0s 353us/step - loss: 0.5363 - acc: 0.7801 - val_loss: 0.8638 - val_acc: 0.5075
# Epoch 44/60
# 532/532 [==============================] - 0s 328us/step - loss: 0.5309 - acc: 0.7801 - val_loss: 0.8639 - val_acc: 0.5075
# Epoch 45/60
# 532/532 [==============================] - 0s 330us/step - loss: 0.5446 - acc: 0.7801 - val_loss: 0.8645 - val_acc: 0.5075
# Epoch 46/60
# 532/532 [==============================] - 0s 360us/step - loss: 0.5319 - acc: 0.7801 - val_loss: 0.8645 - val_acc: 0.5075
# Epoch 47/60
# 532/532 [==============================] - 0s 333us/step - loss: 0.5438 - acc: 0.7801 - val_loss: 0.8653 - val_acc: 0.5075
# Epoch 48/60
# 532/532 [==============================] - 0s 351us/step - loss: 0.5390 - acc: 0.7801 - val_loss: 0.8671 - val_acc: 0.5075
# Epoch 49/60
# 532/532 [==============================] - 0s 348us/step - loss: 0.5278 - acc: 0.7801 - val_loss: 0.8687 - val_acc: 0.5075
# Epoch 50/60
# 532/532 [==============================] - 0s 328us/step - loss: 0.5423 - acc: 0.7801 - val_loss: 0.8678 - val_acc: 0.5075
# Epoch 51/60
# 532/532 [==============================] - 0s 340us/step - loss: 0.5414 - acc: 0.7801 - val_loss: 0.8685 - val_acc: 0.5075
# Epoch 52/60
# 532/532 [==============================] - 0s 365us/step - loss: 0.5370 - acc: 0.7801 - val_loss: 0.8686 - val_acc: 0.5075
# Epoch 53/60
# 532/532 [==============================] - 0s 351us/step - loss: 0.5367 - acc: 0.7801 - val_loss: 0.8678 - val_acc: 0.5075
# Epoch 54/60
# 532/532 [==============================] - 0s 374us/step - loss: 0.5404 - acc: 0.7801 - val_loss: 0.8681 - val_acc: 0.5075
# Epoch 55/60
# 532/532 [==============================] - 0s 331us/step - loss: 0.5325 - acc: 0.7801 - val_loss: 0.8680 - val_acc: 0.5075
# Epoch 56/60
# 532/532 [==============================] - 0s 340us/step - loss: 0.5340 - acc: 0.7801 - val_loss: 0.8675 - val_acc: 0.5075
# Epoch 57/60
# 532/532 [==============================] - 0s 355us/step - loss: 0.5390 - acc: 0.7801 - val_loss: 0.8676 - val_acc: 0.5075
# Epoch 58/60
# 532/532 [==============================] - 0s 331us/step - loss: 0.5319 - acc: 0.7801 - val_loss: 0.8671 - val_acc: 0.5075
# Epoch 59/60
# 532/532 [==============================] - 0s 355us/step - loss: 0.5451 - acc: 0.7801 - val_loss: 0.8666 - val_acc: 0.5075
# Epoch 60/60
# 532/532 [==============================] - 0s 344us/step - loss: 0.5332 - acc: 0.7801 - val_loss: 0.8662 - val_acc: 0.5075
# 200/200 [==============================] - 0s 164us/step
# Train on 532 samples, validate on 266 samples
# Epoch 1/30
# 532/532 [==============================] - 2s 3ms/step - loss: 0.7310 - acc: 0.4248 - val_loss: 0.6945 - val_acc: 0.4925
# Epoch 2/30
# 532/532 [==============================] - 0s 79us/step - loss: 0.7321 - acc: 0.4398 - val_loss: 0.6941 - val_acc: 0.4925
# Epoch 3/30
# 532/532 [==============================] - 0s 55us/step - loss: 0.7209 - acc: 0.4793 - val_loss: 0.6938 - val_acc: 0.4925
# Epoch 4/30
# 532/532 [==============================] - 0s 55us/step - loss: 0.7092 - acc: 0.4981 - val_loss: 0.6935 - val_acc: 0.4925
# Epoch 5/30
# 532/532 [==============================] - 0s 56us/step - loss: 0.6993 - acc: 0.5545 - val_loss: 0.6934 - val_acc: 0.4925
# Epoch 6/30
# 532/532 [==============================] - 0s 52us/step - loss: 0.7014 - acc: 0.5226 - val_loss: 0.6933 - val_acc: 0.5038
# Epoch 7/30
# 532/532 [==============================] - 0s 53us/step - loss: 0.6988 - acc: 0.5094 - val_loss: 0.6932 - val_acc: 0.5075
# Epoch 8/30
# 532/532 [==============================] - 0s 49us/step - loss: 0.7023 - acc: 0.5188 - val_loss: 0.6933 - val_acc: 0.5075
# Epoch 9/30
# 532/532 [==============================] - 0s 57us/step - loss: 0.6794 - acc: 0.5602 - val_loss: 0.6934 - val_acc: 0.5075
# Epoch 10/30
# 532/532 [==============================] - 0s 54us/step - loss: 0.6861 - acc: 0.5677 - val_loss: 0.6935 - val_acc: 0.5075
# Epoch 11/30
# 532/532 [==============================] - 0s 71us/step - loss: 0.6794 - acc: 0.5602 - val_loss: 0.6937 - val_acc: 0.5075
# Epoch 12/30
# 532/532 [==============================] - 0s 68us/step - loss: 0.6736 - acc: 0.5733 - val_loss: 0.6940 - val_acc: 0.5075
# Epoch 13/30
# 532/532 [==============================] - 0s 50us/step - loss: 0.6880 - acc: 0.5583 - val_loss: 0.6943 - val_acc: 0.5075
# Epoch 14/30
# 532/532 [==============================] - 0s 46us/step - loss: 0.6717 - acc: 0.5808 - val_loss: 0.6947 - val_acc: 0.5075
# Epoch 15/30
# 532/532 [==============================] - 0s 60us/step - loss: 0.6656 - acc: 0.5996 - val_loss: 0.6952 - val_acc: 0.5075
# Epoch 16/30
# 532/532 [==============================] - 0s 53us/step - loss: 0.6565 - acc: 0.6485 - val_loss: 0.6956 - val_acc: 0.5075
# Epoch 17/30
# 532/532 [==============================] - 0s 65us/step - loss: 0.6538 - acc: 0.6485 - val_loss: 0.6961 - val_acc: 0.5075
# Epoch 18/30
# 532/532 [==============================] - 0s 50us/step - loss: 0.6623 - acc: 0.6090 - val_loss: 0.6967 - val_acc: 0.5075
# Epoch 19/30
# 532/532 [==============================] - 0s 54us/step - loss: 0.6466 - acc: 0.6635 - val_loss: 0.6973 - val_acc: 0.5075
# Epoch 20/30
# 532/532 [==============================] - 0s 59us/step - loss: 0.6372 - acc: 0.7011 - val_loss: 0.6979 - val_acc: 0.5075
# Epoch 21/30
# 532/532 [==============================] - 0s 49us/step - loss: 0.6439 - acc: 0.6617 - val_loss: 0.6986 - val_acc: 0.5075
# Epoch 22/30
# 532/532 [==============================] - 0s 56us/step - loss: 0.6505 - acc: 0.6429 - val_loss: 0.6993 - val_acc: 0.5075
# Epoch 23/30
# 532/532 [==============================] - 0s 129us/step - loss: 0.6398 - acc: 0.6842 - val_loss: 0.7000 - val_acc: 0.5075
# Epoch 24/30
# 532/532 [==============================] - 0s 81us/step - loss: 0.6318 - acc: 0.6936 - val_loss: 0.7008 - val_acc: 0.5075
# Epoch 25/30
# 532/532 [==============================] - 0s 50us/step - loss: 0.6416 - acc: 0.6823 - val_loss: 0.7016 - val_acc: 0.5075
# Epoch 26/30
# 532/532 [==============================] - 0s 55us/step - loss: 0.6301 - acc: 0.6861 - val_loss: 0.7025 - val_acc: 0.5075
# Epoch 27/30
# 532/532 [==============================] - 0s 55us/step - loss: 0.6333 - acc: 0.6861 - val_loss: 0.7032 - val_acc: 0.5075
# Epoch 28/30
# 532/532 [==============================] - 0s 54us/step - loss: 0.6328 - acc: 0.6880 - val_loss: 0.7041 - val_acc: 0.5075
# Epoch 29/30
# 532/532 [==============================] - 0s 49us/step - loss: 0.6242 - acc: 0.7199 - val_loss: 0.7050 - val_acc: 0.5075
# Epoch 30/30
# 532/532 [==============================] - 0s 57us/step - loss: 0.6133 - acc: 0.7406 - val_loss: 0.7059 - val_acc: 0.5075
# 200/200 [==============================] - 0s 40us/step
# Train on 532 samples, validate on 266 samples
# Epoch 1/120
# 532/532 [==============================] - 2s 3ms/step - loss: 0.7132 - acc: 0.4549 - val_loss: 0.6951 - val_acc: 0.4925
# Epoch 2/120
# 532/532 [==============================] - 0s 55us/step - loss: 0.7105 - acc: 0.5169 - val_loss: 0.6948 - val_acc: 0.4925
# Epoch 3/120
# 532/532 [==============================] - 0s 51us/step - loss: 0.7061 - acc: 0.4925 - val_loss: 0.6946 - val_acc: 0.4023
# Epoch 4/120
# 532/532 [==============================] - 0s 59us/step - loss: 0.7135 - acc: 0.4774 - val_loss: 0.6945 - val_acc: 0.4023
# Epoch 5/120
# 532/532 [==============================] - 0s 51us/step - loss: 0.6990 - acc: 0.5075 - val_loss: 0.6944 - val_acc: 0.5113
# Epoch 6/120
# 532/532 [==============================] - 0s 61us/step - loss: 0.6922 - acc: 0.5263 - val_loss: 0.6944 - val_acc: 0.5075
# Epoch 7/120
# 532/532 [==============================] - 0s 64us/step - loss: 0.6945 - acc: 0.5357 - val_loss: 0.6945 - val_acc: 0.5075
# Epoch 8/120
# 532/532 [==============================] - 0s 56us/step - loss: 0.6838 - acc: 0.5545 - val_loss: 0.6946 - val_acc: 0.5075
# Epoch 9/120
# 532/532 [==============================] - 0s 64us/step - loss: 0.6873 - acc: 0.5414 - val_loss: 0.6947 - val_acc: 0.5075
# Epoch 10/120
# 532/532 [==============================] - 0s 49us/step - loss: 0.6908 - acc: 0.5602 - val_loss: 0.6949 - val_acc: 0.5075
# Epoch 11/120
# 532/532 [==============================] - 0s 50us/step - loss: 0.6779 - acc: 0.5827 - val_loss: 0.6952 - val_acc: 0.5075
# Epoch 12/120
# 532/532 [==============================] - 0s 49us/step - loss: 0.6713 - acc: 0.5865 - val_loss: 0.6955 - val_acc: 0.5075
# Epoch 13/120
# 532/532 [==============================] - 0s 54us/step - loss: 0.6735 - acc: 0.5883 - val_loss: 0.6958 - val_acc: 0.5075
# Epoch 14/120
# 532/532 [==============================] - 0s 60us/step - loss: 0.6701 - acc: 0.5959 - val_loss: 0.6961 - val_acc: 0.5075
# Epoch 15/120
# 532/532 [==============================] - 0s 51us/step - loss: 0.6596 - acc: 0.6560 - val_loss: 0.6966 - val_acc: 0.5075
# Epoch 16/120
# 532/532 [==============================] - 0s 52us/step - loss: 0.6695 - acc: 0.5827 - val_loss: 0.6971 - val_acc: 0.5075
# Epoch 17/120
# 532/532 [==============================] - 0s 50us/step - loss: 0.6683 - acc: 0.5996 - val_loss: 0.6976 - val_acc: 0.5075
# Epoch 18/120
# 532/532 [==============================] - 0s 54us/step - loss: 0.6450 - acc: 0.6523 - val_loss: 0.6981 - val_acc: 0.5075
# Epoch 19/120
# 532/532 [==============================] - 0s 61us/step - loss: 0.6600 - acc: 0.6203 - val_loss: 0.6987 - val_acc: 0.5075
# Epoch 20/120
# 532/532 [==============================] - 0s 53us/step - loss: 0.6487 - acc: 0.6598 - val_loss: 0.6993 - val_acc: 0.5075
# Epoch 21/120
# 532/532 [==============================] - 0s 49us/step - loss: 0.6501 - acc: 0.6654 - val_loss: 0.7000 - val_acc: 0.5075
# Epoch 22/120
# 532/532 [==============================] - 0s 69us/step - loss: 0.6462 - acc: 0.6692 - val_loss: 0.7007 - val_acc: 0.5075
# Epoch 23/120
# 532/532 [==============================] - 0s 62us/step - loss: 0.6384 - acc: 0.6898 - val_loss: 0.7014 - val_acc: 0.5075
# Epoch 24/120
# 532/532 [==============================] - 0s 51us/step - loss: 0.6355 - acc: 0.7162 - val_loss: 0.7021 - val_acc: 0.5075
# Epoch 25/120
# 532/532 [==============================] - 0s 53us/step - loss: 0.6284 - acc: 0.7256 - val_loss: 0.7028 - val_acc: 0.5075
# Epoch 26/120
# 532/532 [==============================] - 0s 51us/step - loss: 0.6367 - acc: 0.6880 - val_loss: 0.7036 - val_acc: 0.5075
# Epoch 27/120
# 532/532 [==============================] - 0s 51us/step - loss: 0.6239 - acc: 0.6992 - val_loss: 0.7043 - val_acc: 0.5075
# Epoch 28/120
# 532/532 [==============================] - 0s 51us/step - loss: 0.6279 - acc: 0.6936 - val_loss: 0.7051 - val_acc: 0.5075
# Epoch 29/120
# 532/532 [==============================] - 0s 47us/step - loss: 0.6296 - acc: 0.7256 - val_loss: 0.7060 - val_acc: 0.5075
# Epoch 30/120
# 532/532 [==============================] - 0s 59us/step - loss: 0.6179 - acc: 0.6955 - val_loss: 0.7068 - val_acc: 0.5075
# Epoch 31/120
# 532/532 [==============================] - 0s 54us/step - loss: 0.6214 - acc: 0.7068 - val_loss: 0.7077 - val_acc: 0.5075
# Epoch 32/120
# 532/532 [==============================] - 0s 44us/step - loss: 0.6245 - acc: 0.7368 - val_loss: 0.7086 - val_acc: 0.5075
# Epoch 33/120
# 532/532 [==============================] - 0s 44us/step - loss: 0.6151 - acc: 0.7368 - val_loss: 0.7096 - val_acc: 0.5075
# Epoch 34/120
# 532/532 [==============================] - 0s 53us/step - loss: 0.6187 - acc: 0.7143 - val_loss: 0.7106 - val_acc: 0.5075
# Epoch 35/120
# 532/532 [==============================] - 0s 55us/step - loss: 0.6087 - acc: 0.7368 - val_loss: 0.7114 - val_acc: 0.5075
# Epoch 36/120
# 532/532 [==============================] - 0s 56us/step - loss: 0.6136 - acc: 0.7237 - val_loss: 0.7125 - val_acc: 0.5075
# Epoch 37/120
# 532/532 [==============================] - 0s 63us/step - loss: 0.6087 - acc: 0.7124 - val_loss: 0.7134 - val_acc: 0.5075
# Epoch 38/120
# 532/532 [==============================] - 0s 46us/step - loss: 0.6011 - acc: 0.7556 - val_loss: 0.7144 - val_acc: 0.5075
# Epoch 39/120
# 532/532 [==============================] - 0s 53us/step - loss: 0.6020 - acc: 0.7406 - val_loss: 0.7155 - val_acc: 0.5075
# Epoch 40/120
# 532/532 [==============================] - 0s 58us/step - loss: 0.5995 - acc: 0.7650 - val_loss: 0.7165 - val_acc: 0.5075
# Epoch 41/120
# 532/532 [==============================] - 0s 48us/step - loss: 0.6033 - acc: 0.7519 - val_loss: 0.7175 - val_acc: 0.5075
# Epoch 42/120
# 532/532 [==============================] - 0s 47us/step - loss: 0.5950 - acc: 0.7406 - val_loss: 0.7186 - val_acc: 0.5075
# Epoch 43/120
# 532/532 [==============================] - 0s 52us/step - loss: 0.5932 - acc: 0.7613 - val_loss: 0.7197 - val_acc: 0.5075
# Epoch 44/120
# 532/532 [==============================] - 0s 50us/step - loss: 0.5978 - acc: 0.7519 - val_loss: 0.7208 - val_acc: 0.5075
# Epoch 45/120
# 532/532 [==============================] - 0s 52us/step - loss: 0.5954 - acc: 0.7500 - val_loss: 0.7219 - val_acc: 0.5075
# Epoch 46/120
# 532/532 [==============================] - 0s 59us/step - loss: 0.5878 - acc: 0.7632 - val_loss: 0.7228 - val_acc: 0.5075
# Epoch 47/120
# 532/532 [==============================] - 0s 53us/step - loss: 0.5995 - acc: 0.7500 - val_loss: 0.7238 - val_acc: 0.5075
# Epoch 48/120
# 532/532 [==============================] - 0s 63us/step - loss: 0.5887 - acc: 0.7519 - val_loss: 0.7250 - val_acc: 0.5075
# Epoch 49/120
# 532/532 [==============================] - 0s 52us/step - loss: 0.5867 - acc: 0.7650 - val_loss: 0.7260 - val_acc: 0.5075
# Epoch 50/120
# 532/532 [==============================] - 0s 50us/step - loss: 0.5963 - acc: 0.7556 - val_loss: 0.7270 - val_acc: 0.5075
# Epoch 51/120
# 532/532 [==============================] - 0s 56us/step - loss: 0.5946 - acc: 0.7556 - val_loss: 0.7282 - val_acc: 0.5075
# Epoch 52/120
# 532/532 [==============================] - 0s 44us/step - loss: 0.5939 - acc: 0.7538 - val_loss: 0.7293 - val_acc: 0.5075
# Epoch 53/120
# 532/532 [==============================] - 0s 48us/step - loss: 0.5869 - acc: 0.7744 - val_loss: 0.7305 - val_acc: 0.5075
# Epoch 54/120
# 532/532 [==============================] - 0s 52us/step - loss: 0.5888 - acc: 0.7650 - val_loss: 0.7317 - val_acc: 0.5075
# Epoch 55/120
# 532/532 [==============================] - 0s 51us/step - loss: 0.5818 - acc: 0.7744 - val_loss: 0.7328 - val_acc: 0.5075
# Epoch 56/120
# 532/532 [==============================] - 0s 51us/step - loss: 0.5926 - acc: 0.7462 - val_loss: 0.7340 - val_acc: 0.5075
# Epoch 57/120
# 532/532 [==============================] - 0s 60us/step - loss: 0.5815 - acc: 0.7575 - val_loss: 0.7351 - val_acc: 0.5075
# Epoch 58/120
# 532/532 [==============================] - 0s 50us/step - loss: 0.5894 - acc: 0.7688 - val_loss: 0.7362 - val_acc: 0.5075
# Epoch 59/120
# 532/532 [==============================] - 0s 59us/step - loss: 0.5768 - acc: 0.7632 - val_loss: 0.7374 - val_acc: 0.5075
# Epoch 60/120
# 532/532 [==============================] - 0s 53us/step - loss: 0.5659 - acc: 0.7688 - val_loss: 0.7386 - val_acc: 0.5075
# Epoch 61/120
# 532/532 [==============================] - 0s 67us/step - loss: 0.5696 - acc: 0.7688 - val_loss: 0.7398 - val_acc: 0.5075
# Epoch 62/120
# 532/532 [==============================] - 0s 49us/step - loss: 0.5817 - acc: 0.7669 - val_loss: 0.7408 - val_acc: 0.5075
# Epoch 63/120
# 532/532 [==============================] - 0s 55us/step - loss: 0.5651 - acc: 0.7726 - val_loss: 0.7420 - val_acc: 0.5075
# Epoch 64/120
# 532/532 [==============================] - 0s 52us/step - loss: 0.5725 - acc: 0.7726 - val_loss: 0.7431 - val_acc: 0.5075
# Epoch 65/120
# 532/532 [==============================] - 0s 51us/step - loss: 0.5759 - acc: 0.7726 - val_loss: 0.7444 - val_acc: 0.5075
# Epoch 66/120
# 532/532 [==============================] - 0s 51us/step - loss: 0.5748 - acc: 0.7688 - val_loss: 0.7456 - val_acc: 0.5075
# Epoch 67/120
# 532/532 [==============================] - 0s 56us/step - loss: 0.5714 - acc: 0.7707 - val_loss: 0.7468 - val_acc: 0.5075
# Epoch 68/120
# 532/532 [==============================] - 0s 65us/step - loss: 0.5638 - acc: 0.7688 - val_loss: 0.7479 - val_acc: 0.5075
# Epoch 69/120
# 532/532 [==============================] - 0s 68us/step - loss: 0.5708 - acc: 0.7744 - val_loss: 0.7490 - val_acc: 0.5075
# Epoch 70/120
# 532/532 [==============================] - 0s 72us/step - loss: 0.5624 - acc: 0.7688 - val_loss: 0.7502 - val_acc: 0.5075
# Epoch 71/120
# 532/532 [==============================] - 0s 58us/step - loss: 0.5670 - acc: 0.7688 - val_loss: 0.7513 - val_acc: 0.5075
# Epoch 72/120
# 532/532 [==============================] - 0s 51us/step - loss: 0.5732 - acc: 0.7688 - val_loss: 0.7526 - val_acc: 0.5075
# Epoch 73/120
# 532/532 [==============================] - 0s 67us/step - loss: 0.5616 - acc: 0.7726 - val_loss: 0.7537 - val_acc: 0.5075
# Epoch 74/120
# 532/532 [==============================] - 0s 54us/step - loss: 0.5601 - acc: 0.7744 - val_loss: 0.7548 - val_acc: 0.5075
# Epoch 75/120
# 532/532 [==============================] - 0s 61us/step - loss: 0.5623 - acc: 0.7744 - val_loss: 0.7559 - val_acc: 0.5075
# Epoch 76/120
# 532/532 [==============================] - 0s 61us/step - loss: 0.5636 - acc: 0.7744 - val_loss: 0.7568 - val_acc: 0.5075
# Epoch 77/120
# 532/532 [==============================] - 0s 64us/step - loss: 0.5649 - acc: 0.7782 - val_loss: 0.7580 - val_acc: 0.5075
# Epoch 78/120
# 532/532 [==============================] - 0s 54us/step - loss: 0.5625 - acc: 0.7782 - val_loss: 0.7590 - val_acc: 0.5075
# Epoch 79/120
# 532/532 [==============================] - 0s 54us/step - loss: 0.5701 - acc: 0.7688 - val_loss: 0.7601 - val_acc: 0.5075
# Epoch 80/120
# 532/532 [==============================] - 0s 52us/step - loss: 0.5647 - acc: 0.7763 - val_loss: 0.7612 - val_acc: 0.5075
# Epoch 81/120
# 532/532 [==============================] - 0s 56us/step - loss: 0.5665 - acc: 0.7782 - val_loss: 0.7622 - val_acc: 0.5075
# Epoch 82/120
# 532/532 [==============================] - 0s 55us/step - loss: 0.5671 - acc: 0.7707 - val_loss: 0.7634 - val_acc: 0.5075
# Epoch 83/120
# ...
# Epoch 34/60
# 532/532 [==============================] - 0s 60us/step - loss: 0.6307 - acc: 0.7086 - val_loss: 0.6876 - val_acc: 0.5602
# Epoch 35/60
# 532/532 [==============================] - 0s 69us/step - loss: 0.6248 - acc: 0.7180 - val_loss: 0.6878 - val_acc: 0.5602
# Epoch 36/60
# 532/532 [==============================] - 0s 64us/step - loss: 0.6278 - acc: 0.7049 - val_loss: 0.6880 - val_acc: 0.5602
# Epoch 37/60
# 532/532 [==============================] - 0s 63us/step - loss: 0.6264 - acc: 0.7030 - val_loss: 0.6882 - val_acc: 0.5602
# Epoch 38/60
# 532/532 [==============================] - 0s 65us/step - loss: 0.6309 - acc: 0.7086 - val_loss: 0.6884 - val_acc: 0.5602
# Epoch 39/60
# 532/532 [==============================] - 0s 64us/step - loss: 0.6272 - acc: 0.7011 - val_loss: 0.6887 - val_acc: 0.5602
# Epoch 40/60
# 532/532 [==============================] - 0s 67us/step - loss: 0.6237 - acc: 0.7124 - val_loss: 0.6889 - val_acc: 0.5602
# Epoch 41/60
# 532/532 [==============================] - 0s 63us/step - loss: 0.6269 - acc: 0.7049 - val_loss: 0.6892 - val_acc: 0.5602
# Epoch 42/60
# 532/532 [==============================] - 0s 59us/step - loss: 0.6119 - acc: 0.7180 - val_loss: 0.6895 - val_acc: 0.5602
# Epoch 43/60
# 532/532 [==============================] - 0s 61us/step - loss: 0.6177 - acc: 0.7199 - val_loss: 0.6897 - val_acc: 0.5602
# Epoch 44/60
# 532/532 [==============================] - 0s 58us/step - loss: 0.6200 - acc: 0.7162 - val_loss: 0.6900 - val_acc: 0.5602
# Epoch 45/60
# 532/532 [==============================] - 0s 57us/step - loss: 0.6151 - acc: 0.7331 - val_loss: 0.6904 - val_acc: 0.5602
# Epoch 46/60
# 532/532 [==============================] - 0s 55us/step - loss: 0.6190 - acc: 0.7256 - val_loss: 0.6906 - val_acc: 0.5602
# Epoch 47/60
# 532/532 [==============================] - 0s 64us/step - loss: 0.6089 - acc: 0.7387 - val_loss: 0.6910 - val_acc: 0.5602
# Epoch 48/60
# 532/532 [==============================] - 0s 56us/step - loss: 0.6193 - acc: 0.7331 - val_loss: 0.6914 - val_acc: 0.5602
# Epoch 49/60
# 532/532 [==============================] - 0s 54us/step - loss: 0.6132 - acc: 0.7274 - val_loss: 0.6917 - val_acc: 0.5602
# Epoch 50/60
# 532/532 [==============================] - 0s 59us/step - loss: 0.6013 - acc: 0.7406 - val_loss: 0.6921 - val_acc: 0.5602
# Epoch 51/60
# 532/532 [==============================] - 0s 70us/step - loss: 0.6134 - acc: 0.7462 - val_loss: 0.6925 - val_acc: 0.5602
# Epoch 52/60
# 532/532 [==============================] - 0s 58us/step - loss: 0.5995 - acc: 0.7350 - val_loss: 0.6928 - val_acc: 0.5602
# Epoch 53/60
# 532/532 [==============================] - 0s 48us/step - loss: 0.6143 - acc: 0.7462 - val_loss: 0.6932 - val_acc: 0.5602
# Epoch 54/60
# 532/532 [==============================] - 0s 56us/step - loss: 0.6083 - acc: 0.7406 - val_loss: 0.6936 - val_acc: 0.5602
# Epoch 55/60
# 532/532 [==============================] - 0s 65us/step - loss: 0.6079 - acc: 0.7425 - val_loss: 0.6940 - val_acc: 0.5602
# Epoch 56/60
# 532/532 [==============================] - 0s 62us/step - loss: 0.6092 - acc: 0.7387 - val_loss: 0.6943 - val_acc: 0.5602
# Epoch 57/60
# 532/532 [==============================] - 0s 55us/step - loss: 0.5996 - acc: 0.7425 - val_loss: 0.6948 - val_acc: 0.5602
# Epoch 58/60
# 532/532 [==============================] - 0s 59us/step - loss: 0.6051 - acc: 0.7293 - val_loss: 0.6952 - val_acc: 0.5602
# Epoch 59/60
# 532/532 [==============================] - 0s 63us/step - loss: 0.5979 - acc: 0.7500 - val_loss: 0.6956 - val_acc: 0.5602
# Epoch 60/60
# 532/532 [==============================] - 0s 60us/step - loss: 0.6140 - acc: 0.7331 - val_loss: 0.6961 - val_acc: 0.5602
# 200/200 [==============================] - 0s 74us/step
# Train on 532 samples, validate on 266 samples
# Epoch 1/60
# 532/532 [==============================] - 2s 4ms/step - loss: 0.7032 - acc: 0.4925 - val_loss: 0.6932 - val_acc: 0.4398
# Epoch 2/60
# 532/532 [==============================] - 0s 70us/step - loss: 0.7056 - acc: 0.4662 - val_loss: 0.6930 - val_acc: 0.5714
# Epoch 3/60
# 532/532 [==============================] - 0s 41us/step - loss: 0.6960 - acc: 0.5019 - val_loss: 0.6928 - val_acc: 0.5602
# Epoch 4/60
# 532/532 [==============================] - 0s 45us/step - loss: 0.7032 - acc: 0.4568 - val_loss: 0.6926 - val_acc: 0.5602
# Epoch 5/60
# 532/532 [==============================] - 0s 50us/step - loss: 0.6999 - acc: 0.4925 - val_loss: 0.6924 - val_acc: 0.5602
# Epoch 6/60
# 532/532 [==============================] - 0s 47us/step - loss: 0.7062 - acc: 0.4568 - val_loss: 0.6922 - val_acc: 0.5602
# Epoch 7/60
# 532/532 [==============================] - 0s 41us/step - loss: 0.6966 - acc: 0.5019 - val_loss: 0.6920 - val_acc: 0.5602
# Epoch 8/60
# 532/532 [==============================] - 0s 43us/step - loss: 0.6967 - acc: 0.4906 - val_loss: 0.6918 - val_acc: 0.5602
# Epoch 9/60
# 532/532 [==============================] - 0s 47us/step - loss: 0.6974 - acc: 0.5038 - val_loss: 0.6916 - val_acc: 0.5602
# Epoch 10/60
# 532/532 [==============================] - 0s 45us/step - loss: 0.6895 - acc: 0.5338 - val_loss: 0.6914 - val_acc: 0.5602
# Epoch 11/60
# 532/532 [==============================] - 0s 57us/step - loss: 0.6919 - acc: 0.5150 - val_loss: 0.6912 - val_acc: 0.5602
# Epoch 12/60
# 532/532 [==============================] - 0s 45us/step - loss: 0.6982 - acc: 0.4887 - val_loss: 0.6911 - val_acc: 0.5602
# Epoch 13/60
# 532/532 [==============================] - 0s 56us/step - loss: 0.6908 - acc: 0.5263 - val_loss: 0.6909 - val_acc: 0.5602
# Epoch 14/60
# 532/532 [==============================] - 0s 52us/step - loss: 0.6928 - acc: 0.4981 - val_loss: 0.6907 - val_acc: 0.5602
# Epoch 15/60
# 532/532 [==============================] - 0s 46us/step - loss: 0.6830 - acc: 0.5620 - val_loss: 0.6905 - val_acc: 0.5602
# Epoch 16/60
# 532/532 [==============================] - 0s 45us/step - loss: 0.6877 - acc: 0.5263 - val_loss: 0.6904 - val_acc: 0.5602
# Epoch 17/60
# 532/532 [==============================] - 0s 36us/step - loss: 0.6765 - acc: 0.5921 - val_loss: 0.6902 - val_acc: 0.5602
# Epoch 18/60
# 532/532 [==============================] - 0s 35us/step - loss: 0.6833 - acc: 0.5526 - val_loss: 0.6901 - val_acc: 0.5602
# Epoch 19/60
# 532/532 [==============================] - 0s 42us/step - loss: 0.6827 - acc: 0.5432 - val_loss: 0.6899 - val_acc: 0.5602
# Epoch 20/60
# 532/532 [==============================] - 0s 37us/step - loss: 0.6813 - acc: 0.5508 - val_loss: 0.6898 - val_acc: 0.5602
# Epoch 21/60
# 532/532 [==============================] - 0s 47us/step - loss: 0.6805 - acc: 0.5733 - val_loss: 0.6896 - val_acc: 0.5602
# Epoch 22/60
# 532/532 [==============================] - 0s 55us/step - loss: 0.6834 - acc: 0.5508 - val_loss: 0.6895 - val_acc: 0.5602
# Epoch 23/60
# 532/532 [==============================] - 0s 52us/step - loss: 0.6836 - acc: 0.5414 - val_loss: 0.6893 - val_acc: 0.5602
# Epoch 24/60
# 532/532 [==============================] - 0s 61us/step - loss: 0.6813 - acc: 0.5470 - val_loss: 0.6892 - val_acc: 0.5602
# Epoch 25/60
# 532/532 [==============================] - 0s 46us/step - loss: 0.6841 - acc: 0.5583 - val_loss: 0.6891 - val_acc: 0.5602
# Epoch 26/60
# 532/532 [==============================] - 0s 36us/step - loss: 0.6739 - acc: 0.6222 - val_loss: 0.6889 - val_acc: 0.5602
# Epoch 27/60
# 532/532 [==============================] - 0s 41us/step - loss: 0.6853 - acc: 0.5752 - val_loss: 0.6888 - val_acc: 0.5602
# Epoch 28/60
# 532/532 [==============================] - 0s 41us/step - loss: 0.6761 - acc: 0.5940 - val_loss: 0.6887 - val_acc: 0.5602
# Epoch 29/60
# 532/532 [==============================] - 0s 44us/step - loss: 0.6810 - acc: 0.5545 - val_loss: 0.6885 - val_acc: 0.5602
# Epoch 30/60
# 532/532 [==============================] - 0s 43us/step - loss: 0.6715 - acc: 0.5959 - val_loss: 0.6884 - val_acc: 0.5602
# Epoch 31/60
# 532/532 [==============================] - 0s 54us/step - loss: 0.6794 - acc: 0.5714 - val_loss: 0.6883 - val_acc: 0.5602
# Epoch 32/60
# 532/532 [==============================] - 0s 50us/step - loss: 0.6732 - acc: 0.5827 - val_loss: 0.6882 - val_acc: 0.5602
# Epoch 33/60
# 532/532 [==============================] - 0s 53us/step - loss: 0.6701 - acc: 0.6259 - val_loss: 0.6881 - val_acc: 0.5602
# Epoch 34/60
# 532/532 [==============================] - 0s 48us/step - loss: 0.6740 - acc: 0.6034 - val_loss: 0.6880 - val_acc: 0.5602
# Epoch 35/60
# 532/532 [==============================] - 0s 46us/step - loss: 0.6756 - acc: 0.5808 - val_loss: 0.6879 - val_acc: 0.5602
# Epoch 36/60
# 532/532 [==============================] - 0s 52us/step - loss: 0.6721 - acc: 0.5977 - val_loss: 0.6878 - val_acc: 0.5602
# Epoch 37/60
# 532/532 [==============================] - 0s 51us/step - loss: 0.6672 - acc: 0.6466 - val_loss: 0.6877 - val_acc: 0.5602
# Epoch 38/60
# 532/532 [==============================] - 0s 41us/step - loss: 0.6624 - acc: 0.6184 - val_loss: 0.6876 - val_acc: 0.5602
# Epoch 39/60
# 532/532 [==============================] - 0s 44us/step - loss: 0.6695 - acc: 0.6165 - val_loss: 0.6875 - val_acc: 0.5602
# Epoch 40/60
# 532/532 [==============================] - 0s 44us/step - loss: 0.6596 - acc: 0.6297 - val_loss: 0.6874 - val_acc: 0.5602
# Epoch 41/60
# 532/532 [==============================] - 0s 42us/step - loss: 0.6717 - acc: 0.5883 - val_loss: 0.6873 - val_acc: 0.5602
# Epoch 42/60
# 532/532 [==============================] - 0s 52us/step - loss: 0.6686 - acc: 0.6128 - val_loss: 0.6872 - val_acc: 0.5602
# Epoch 43/60
# 532/532 [==============================] - 0s 45us/step - loss: 0.6647 - acc: 0.6429 - val_loss: 0.6871 - val_acc: 0.5602
# Epoch 44/60
# 532/532 [==============================] - 0s 47us/step - loss: 0.6677 - acc: 0.6353 - val_loss: 0.6871 - val_acc: 0.5602
# Epoch 45/60
# 532/532 [==============================] - 0s 50us/step - loss: 0.6632 - acc: 0.6090 - val_loss: 0.6870 - val_acc: 0.5602
# Epoch 46/60
# 532/532 [==============================] - 0s 46us/step - loss: 0.6648 - acc: 0.6541 - val_loss: 0.6869 - val_acc: 0.5602
# Epoch 47/60
# 532/532 [==============================] - 0s 38us/step - loss: 0.6621 - acc: 0.6128 - val_loss: 0.6868 - val_acc: 0.5602
# Epoch 48/60
# 532/532 [==============================] - 0s 47us/step - loss: 0.6615 - acc: 0.6579 - val_loss: 0.6868 - val_acc: 0.5602
# Epoch 49/60
# 532/532 [==============================] - 0s 52us/step - loss: 0.6548 - acc: 0.6748 - val_loss: 0.6867 - val_acc: 0.5602
# Epoch 50/60
# 532/532 [==============================] - 0s 50us/step - loss: 0.6641 - acc: 0.6466 - val_loss: 0.6866 - val_acc: 0.5602
# Epoch 51/60
# 532/532 [==============================] - 0s 46us/step - loss: 0.6612 - acc: 0.6391 - val_loss: 0.6866 - val_acc: 0.5602
# Epoch 52/60
# 532/532 [==============================] - 0s 36us/step - loss: 0.6629 - acc: 0.6259 - val_loss: 0.6865 - val_acc: 0.5602
# Epoch 53/60
# 532/532 [==============================] - 0s 51us/step - loss: 0.6590 - acc: 0.6447 - val_loss: 0.6865 - val_acc: 0.5602
# Epoch 54/60
# 532/532 [==============================] - 0s 49us/step - loss: 0.6616 - acc: 0.6372 - val_loss: 0.6864 - val_acc: 0.5602
# Epoch 55/60
# 532/532 [==============================] - 0s 57us/step - loss: 0.6563 - acc: 0.6410 - val_loss: 0.6863 - val_acc: 0.5602
# Epoch 56/60
# 532/532 [==============================] - 0s 49us/step - loss: 0.6656 - acc: 0.6147 - val_loss: 0.6863 - val_acc: 0.5602
# Epoch 57/60
# 532/532 [==============================] - 0s 47us/step - loss: 0.6624 - acc: 0.6316 - val_loss: 0.6863 - val_acc: 0.5602
# Epoch 58/60
# 532/532 [==============================] - 0s 36us/step - loss: 0.6518 - acc: 0.6635 - val_loss: 0.6862 - val_acc: 0.5602
# Epoch 59/60
# 532/532 [==============================] - 0s 45us/step - loss: 0.6588 - acc: 0.6485 - val_loss: 0.6862 - val_acc: 0.5602
# Epoch 60/60
# 532/532 [==============================] - 0s 39us/step - loss: 0.6544 - acc: 0.6635 - val_loss: 0.6861 - val_acc: 0.5602
# 200/200 [==============================] - 0s 57us/step
# Train on 532 samples, validate on 266 samples
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-81524e2ec72c> in <module>()
# ----> 1 accScores_neurone_kfold = Neurone_KFold(Galaxies, 3)
#
# <ipython-input-20-195e82894670> in Neurone_KFold(array, k)
#     112         #perceptrons
#     113         y_true_perc1, y_pred_perc1 = GenerateModel(array_train, array_val, array_test, 4, 50, 60, 0.0005, 'kfold/k'+str(i)+'_perc1')
# --> 114         y_true_perc2, y_pred_perc2 = GenerateModel(array_train, array_val, array_test, 4, 300, 60, 0.0005, 'kfold/k'+str(i)+'_perc2')
#     115         y_true_perc3, y_pred_perc3 = GenerateModel(array_train, array_val, array_test, 4, 600, 60, 0.0005, 'kfold/k'+str(i)+'_perc3')
#     116
#
# <ipython-input-20-195e82894670> in GenerateModel(data_train, data_val, data_test, layers, perceptrons, epochs, learnRate, name)
#      38
#      39     #Train
# ---> 40     model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=epochs, batch_size=100, callbacks=[tb_callback])
#      41
#      42     model.evaluate(X_test, Y_test)
#
# C:\Anaconda3\envs\gti770\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1346           initial_epoch=initial_epoch,
#    1347           steps_per_epoch=steps_per_epoch,
# -> 1348           validation_steps=validation_steps)
#    1349
#    1350   def evaluate(self,
#
# C:\Anaconda3\envs\gti770\lib\site-packages\tensorflow\python\keras\engine\training_arrays.py in fit_loop(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     155     callback_model = model
#     156
# --> 157   callbacks.set_model(callback_model)
#     158
#     159   callbacks.set_params({
#
# C:\Anaconda3\envs\gti770\lib\site-packages\tensorflow\python\keras\callbacks.py in set_model(self, model)
#      68   def set_model(self, model):
#      69     for callback in self.callbacks:
# ---> 70       callback.set_model(model)
#      71
#      72   def on_epoch_begin(self, epoch, logs=None):
#
# C:\Anaconda3\envs\gti770\lib\site-packages\tensorflow\python\keras\callbacks.py in set_model(self, model)
#     764
#     765     if self.write_graph:
# --> 766       self.writer = tf_summary.FileWriter(self.log_dir, self.sess.graph)
#     767     else:
#     768       self.writer = tf_summary.FileWriter(self.log_dir)
#
# C:\Anaconda3\envs\gti770\lib\site-packages\tensorflow\python\summary\writer\writer.py in __init__(self, logdir, graph, max_queue, flush_secs, graph_def, filename_suffix, session)
#     365       event_writer = EventFileWriter(logdir, max_queue, flush_secs,
#     366                                      filename_suffix)
# --> 367     super(FileWriter, self).__init__(event_writer, graph, graph_def)
#     368
#     369   def __enter__(self):
#
# C:\Anaconda3\envs\gti770\lib\site-packages\tensorflow\python\summary\writer\writer.py in __init__(self, event_writer, graph, graph_def)
#      88       self.add_meta_graph(
#      89           meta_graph.create_meta_graph_def(graph_def=graph_def or
# ---> 90                                            maybe_graph_as_def))
#      91
#      92     # This set contains tags of Summary Values that have been encountered
#
# C:\Anaconda3\envs\gti770\lib\site-packages\tensorflow\python\framework\meta_graph.py in create_meta_graph_def(meta_info_def, graph_def, saver_def, collection_list, graph, export_scope, exclude_nodes, clear_extraneous_savers, strip_default_attrs)
#     581   # Fills in meta_info_def.stripped_op_list using the ops from graph_def.
#     582   # pylint: disable=g-explicit-length-test
# --> 583   if len(meta_graph_def.meta_info_def.stripped_op_list.op) == 0:
#     584     meta_graph_def.meta_info_def.stripped_op_list.MergeFrom(
#     585         stripped_op_list_for_graph(meta_graph_def.graph_def))
#
# KeyboardInterrupt:

# %%
def SVM_linear(X_train, Y_train, X_test, C):
    gamma_range = np.logspace(-9, 3, 13)
    param_grid = dict(gamma=gamma_range)
    cv = StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=42)
    grid = GridSearchCV(SVC(cache_size=2048), param_grid=param_grid, cv=cv, n_jobs=4)
    grid.fit(X_train, Y_train)

    print("The best parameters are %s with a score of %0.2f"
      % (grid.best_params_, grid.best_score_))

    clf = SVC(C=C, gamma=grid.best_params_['gamma'], class_weight='balanced', kernel='linear')
    clf.fit(X_train, Y_train)
    
    Y_pred = clf.predict(X_test)
    return Y_pred

def SVM_rbf(X_train, Y_train, X_test, C, gamma):

    clf = SVC(C=C, gamma=gamma, kernel='rbf')
    clf.fit(X_train, Y_train)
    
    Y_pred = clf.predict(X_test)
    return Y_pred

def SVM(array):
    array_train, array_val, array_test = SplitVectorData_Holdout(array, 0.6)
    X_train, Y_train, X_val, Y_val, X_test, Y_test = SplitLabelsFromPrimitives(array_train, array_val, array_test)
    
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)
    X_test = scaler.transform(X_test)
    
    Y_pred_lin03= SVM_linear(X_train, Y_train, X_test, 1e-03)
    Y_pred_lin01= SVM_linear(X_train, Y_train, X_test, 1e-01)
    Y_pred_lin1= SVM_linear(X_train, Y_train, X_test, 1.0)
    Y_pred_lin10= SVM_linear(X_train, Y_train, X_test, 10.0)
    Y_pred_rbf03_g03= SVM_rbf(X_train, Y_train, X_test, 1e-03, 1e-03)
    Y_pred_rbf01_g03= SVM_rbf(X_train, Y_train, X_test, 1e-01, 1e-03)
    Y_pred_rbf1_g03= SVM_rbf(X_train, Y_train, X_test, 1.0, 1e-03)
    Y_pred_rbf10_g03= SVM_rbf(X_train, Y_train, X_test, 10.0, 1e-03)
    Y_pred_rbf03_g01= SVM_rbf(X_train, Y_train, X_test, 1e-03, 1e-01)
    Y_pred_rbf01_g01= SVM_rbf(X_train, Y_train, X_test, 1e-01, 1e-01)
    Y_pred_rbf1_g01= SVM_rbf(X_train, Y_train, X_test, 1.0, 1e-01)
    Y_pred_rbf10_g01= SVM_rbf(X_train, Y_train, X_test, 10.0, 1e-01)
    Y_pred_rbf03_g1= SVM_rbf(X_train, Y_train, X_test, 1e-03, 1.0)
    Y_pred_rbf01_g1= SVM_rbf(X_train, Y_train, X_test, 1e-01, 1.0)
    Y_pred_rbf1_g1= SVM_rbf(X_train, Y_train, X_test, 1.0, 1.0)
    Y_pred_rbf10_g1= SVM_rbf(X_train, Y_train, X_test, 10.0, 1.0)
    Y_pred_rbf03_g10= SVM_rbf(X_train, Y_train, X_test, 1e-03, 10.0)
    Y_pred_rbf01_g10= SVM_rbf(X_train, Y_train, X_test, 1e-01, 10.0)
    Y_pred_rbf1_g10= SVM_rbf(X_train, Y_train, X_test, 1.0, 10.0)
    Y_pred_rbf10_g10= SVM_rbf(X_train, Y_train, X_test, 10.0, 10.0)
    
    validations = [[Y_test, Y_pred_lin03],
    [Y_test, Y_pred_lin01],
    [Y_test, Y_pred_lin1],
    [Y_test, Y_pred_lin10],             
    [Y_test, Y_pred_rbf03_g03],
    [Y_test, Y_pred_rbf01_g03],
    [Y_test, Y_pred_rbf1_g03],
    [Y_test, Y_pred_rbf10_g03],            
    [Y_test, Y_pred_rbf03_g01],
    [Y_test, Y_pred_rbf01_g01],
    [Y_test, Y_pred_rbf1_g01],
    [Y_test, Y_pred_rbf10_g01],              
    [Y_test, Y_pred_rbf03_g1],
    [Y_test, Y_pred_rbf01_g1],
    [Y_test, Y_pred_rbf1_g1],
    [Y_test, Y_pred_rbf10_g1],            
    [Y_test, Y_pred_rbf03_g10],
    [Y_test, Y_pred_rbf01_g10],
    [Y_test, Y_pred_rbf1_g10],
    [Y_test, Y_pred_rbf10_g10]]
    
    return GenerateAccScores(validations)

# %%
accScores_svm = SVM(Galaxies)
# Out:
# The best parameters are {'gamma': 0.1} with a score of 0.85
# The best parameters are {'gamma': 0.1} with a score of 0.85
# The best parameters are {'gamma': 0.1} with a score of 0.85
# The best parameters are {'gamma': 0.1} with a score of 0.85
