# %% [markdown]
# # GTI770 - TP2

# %%
# %matplotlib inline   
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
import graphviz
import decimal
import pandas as pd
from openpyxl import load_workbook
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import optimizers as opt

from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import GridSearchCV

# from sklearn import tree
# from sklearn.naive_bayes import GaussianNB
# from sklearn.naive_bayes import MultinomialNB
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.ensemble import RandomForestClassifier
# from mdlp.discretization import MDLP
# from sklearn.preprocessing import MinMaxScaler

# %%
#Utility methods
def SplitVectorData_Holdout(primitives_vector, train_portion):
    
    size = len(primitives_vector)
    subsize = len(primitives_vector[0])
    
    val_portion = (1 - train_portion) / 2
    test_portion = (1 - train_portion) / 2

    nbTrain = int(size * train_portion)
    nbVal = int(size * val_portion)
    nbTest = int(size * test_portion)

    array_train = np.zeros((nbTrain, subsize), dtype=np.float64)
    array_val = np.zeros((nbVal, subsize), dtype=np.float64)
    array_test = np.zeros((nbTest, subsize), dtype=np.float64)

    array_train = primitives_vector[:nbTrain]
    array_val = primitives_vector[nbTrain : nbTrain + nbVal]
    array_test = primitives_vector[-nbTest:]
    return array_train, array_val, array_test

def SplitVectorData_KFold(primitives_vector, k, test_portion):
    
    size = len(primitives_vector)
    subsize = len(primitives_vector[0])
    subsetNb = int(size * (1 - test_portion) / k)
    testNb = int(size * test_portion)
    
    array_kfold_train = np.zeros((k, subsetNb, subsize), dtype=np.float64)
    array_kfold_test = np.zeros((testNb, subsize), dtype=np.float64)
    
    for i in range(0, k):
        if i == 0 :
            array_kfold_train[i] = primitives_vector[i * subsetNb]
        else :
            array_kfold_train[i] = primitives_vector[(i-1) * subsetNb : i * subsetNb]
    
    array_kfold_test = primitives_vector[-testNb:]

    return array_kfold_train, array_kfold_test

def SplitVectorData_NoVal(primitives_vector, train_portion):
    
    size = len(primitives_vector)
    subsize = len(primitives_vector[0])
    
    test_portion = (1 - train_portion)

    nbTrain = int(size * train_portion)
    nbTest = int(size * test_portion)

    array_train = np.zeros((nbTrain, subsize), dtype=np.float64)
    array_test = np.zeros((nbTest, subsize), dtype=np.float64)

    array_train = primitives_vector[:nbTrain]
    array_test = primitives_vector[-nbTest:]
    return array_train, array_test

def concatenateWithoutTestPortion(full_array, index):
    result_array = []
    for i in range(0, len(full_array)):
        if len(result_array) == 0:
            result_array = full_array[i]
        elif i != index :
            result_array = np.concatenate((result_array, full_array[i]), axis=0)
    return result_array

def scores_mean(array_scores):
    
    size = len(array_scores)
    subsize = len(array_scores[0])
    array_mean = np.zeros(subsize, dtype=float)
    
    for i in range(0, size):
        for j in range(0, subsize):
            array_mean[j] += array_scores[i][j]
            
    for j in range(0, subsize):
            array_mean[j] = array_mean[j] / size
    
    return array_mean

def UseModelOnTestData(array, model, transformer=None):
    array_train, array_val, array_test = SplitVectorData_Holdout(array, 0.6)
    if transformer is not None:
        transform_train, transform_val, transform_test, Y_train, Y_val, Y_test = TransformData(array_train, array_val, array_test, len(array_train[0]), transformer)
    array_model_result, array_prediction_train_result, array_prediction_val_result, array_prediction_test_result, array_train_result, array_val_result, array_test_result = GenerateModelDataFromTransform(transform_train, transform_val, transform_test, Y_train, Y_val, Y_test, len(array[0]), model)
    result = [[array_test_result, array_prediction_test_result]]
    return GenerateScores(result) 

# ----- For debug -----
#Filter_train, Filter_val, Filter_test = SplitVectorDataTrainValTest(Filter, 0.6)
#print(len(Filter_train))
#print(len(Filter_val))
#print(len(Filter_test))
#print(len(Filter))
#----------------------

# %%
#Transforms and Models generation methods
def GenerateModelDataFromVector(array_train, array_val, array_test, num_features, chosen_model):
    
    num_features = num_features - 1
    
    data_train = array_train
    X_train  = data_train[:,0:num_features]
    Y_train  = data_train[:,num_features]
    
    data_val = array_val
    X_val = data_val[:,0:num_features]
    Y_val = data_val[:,num_features]
    
    data_test = array_test
    X_test = data_test[:,0:num_features]
    Y_test = data_test[:,num_features]
    
    
    model = chosen_model
    model = model.fit(X_train, Y_train)
    prediction_train = model.predict(X_train)
    prediction_val = model.predict(X_val)
    prediction_test = model.predict(X_test)
    return model, prediction_train, prediction_val, prediction_test, Y_train, Y_val, Y_test

def TransformData(array_train, array_val, array_test, num_features, chosen_transformer):
    
    num_features = num_features - 1
    
    data_train = array_train
    X_train  = data_train[:,0:num_features]
    Y_train  = data_train[:,num_features]
    
    data_val = array_val
    X_val  = data_val[:,0:num_features]
    Y_val  = data_val[:,num_features]
    
    data_test = array_test
    X_test  = data_test[:,0:num_features]
    Y_test  = data_test[:,num_features]
    
    transformer_train = chosen_transformer
    transformer_train = transformer_train.fit_transform(X_train, Y_train)
    
    transformer_val = chosen_transformer
    transformer_val = transformer_val.fit_transform(X_val, Y_val)
    
    transformer_test = chosen_transformer
    transformer_test = transformer_test.fit_transform(X_test, Y_test)
    return transformer_train, transformer_val, transformer_test, Y_train, Y_val, Y_test

def GenerateModelDataFromTransform(array_train, array_val, array_test, y_train, y_val, y_test, num_features, chosen_model):
    
    num_features = num_features - 1
    
    X_train  = array_train
    Y_train = y_train
    
    X_val = array_val
    Y_val = y_val
    
    X_test  = array_test
    Y_test = y_test
    
    model = chosen_model
    model = model.fit(X_train, Y_train)
    prediction_train = model.predict(X_train)
    prediction_val = model.predict(X_val)
    prediction_test = model.predict(X_test)
    return model, prediction_train, prediction_val, prediction_test, Y_train, Y_val, Y_test

# %%
#display methods
def ExportTree(model):
    dot_data = tree.export_graphviz(model, out_file=None, 
                         #feature_names = ['', '', ''],  
                         class_names = ['spam', 'mail'],
                         filled=True, rounded=True,  
                         special_characters=True)  
    graph = graphviz.Source(dot_data)
    graph.format = 'png'
    graph.render("Filter_data") 
    return graph

def GenerateScores(array):
    AccScores = np.zeros(len(array), dtype=float)
    F1Scores = np.zeros(len(array), dtype=float)

    for i in range(0, len(array)):
        AccScores[i] = accuracy_score(array[i][0], array[i][1])
        F1Scores[i] = f1_score(array[i][0], array[i][1], average='weighted', labels=np.unique(array[i][1]))
    
    return AccScores, F1Scores

def GenerateAccScores(array):
    AccScores = np.zeros(len(array), dtype=float)

    for i in range(0, len(array)):
        AccScores[i] = accuracy_score(array[i][0], array[i][1])
    
    return AccScores

#Extraction de primitive
def TracePlot(array_acc_X, array_acc_Y, array_f1_X, array_f1_Y, titre, titre_x, titre_y):        
    
    plt.plot(array_acc_X, array_acc_Y, 'ro')
    plt.plot(array_f1_X, array_f1_Y, 'g*')
    plt.xlabel(titre_x)
    plt.ylabel(titre_y)
    plt.legend(['Accuracy Score','F1 Score'])
    plt.title(titre)
    plt.grid(True)
    plt.show()

# %%
#model creations methods
def CreateDecisionTreeModel(depth):
    return tree.DecisionTreeClassifier(criterion='entropy', max_depth=depth, min_samples_leaf=1)

def CreateKNNModel(k, weight):
    return KNeighborsClassifier(n_neighbors=k, weights=weight)

def CreateRandomForestModel(depth):
    return RandomForestClassifier(criterion='entropy', max_depth=depth, random_state=0)

# %%
#Decision tree methods
def DecisionTree_Holdout(array):
    array_train, array_val, array_test = SplitVectorData_Holdout(array, 0.6)

    array_model_none, array_prediction_train_none, array_prediction_val_none, array_prediction_test_none, array_train_none, array_val_none, array_test_none = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateDecisionTreeModel(None))
    array_model_3, array_prediction_train_3, array_prediction_val_3, array_prediction_test_3, array_train_3, array_val_3, array_test_3 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateDecisionTreeModel(3))
    array_model_5, array_prediction_train_5, array_prediction_val_5, array_prediction_test_5, array_train_5, array_val_5, array_test_5 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateDecisionTreeModel(5))
    array_model_10, array_prediction_train_10, array_prediction_val_10, array_prediction_test_10, array_train_10, array_val_10, array_test_10 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateDecisionTreeModel(10))

    validations = [[array_val_none, array_prediction_val_none],
    [array_val_3, array_prediction_val_3],
    [array_val_5, array_prediction_val_5],
    [array_val_10, array_prediction_val_10]]

    return GenerateScores(validations)

def DecisionTree_KFold(array,k):

    array_kfold_train, array_kfold_test = SplitVectorData_KFold(array, k, 0.2)
    all_accScores = np.zeros((k, 4), dtype=float)
    all_f1Scores = np.zeros((k, 4), dtype=float)

    for i in range(1, k):

        array_train = concatenateWithoutTestPortion(array_kfold_train, i)
        array_val = array_kfold_train[i]
        array_test = array_kfold_test

        array_model_none, array_prediction_train_none, array_prediction_val_none, array_prediction_test_none, array_train_none, array_val_none, array_test_none = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateDecisionTreeModel(None))
        array_model_3, array_prediction_train_3, array_prediction_val_3, array_prediction_test_3, array_train_3, array_val_3, array_test_3 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateDecisionTreeModel(3))
        array_model_5, array_prediction_train_5, array_prediction_val_5, array_prediction_test_tree_5, array_train_5, array_val_5, array_test_5 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateDecisionTreeModel(5))
        array_model_10, array_prediction_train_10, array_prediction_val_10, array_prediction_test_tree_10, array_train_10, array_val_10, array_test_10 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateDecisionTreeModel(10))

        validations = [[array_val_none, array_prediction_val_none],
        [array_val_3, array_prediction_val_3],
        [array_val_5, array_prediction_val_5],
        [array_val_10, array_prediction_val_10]]

        Array_AccScores, Array_F1Scores = GenerateScores(validations)

        all_accScores[i] = Array_AccScores
        all_f1Scores[i] = Array_F1Scores

    accScores_mean = scores_mean(all_accScores)
    f1Scores_mean = scores_mean(all_f1Scores)
    
    return accScores_mean, f1Scores_mean

# %%
#Bayes Methods
def Bayes_Holdout(array, array_prob ,array_transform=None):
    array_train, array_val, array_test = SplitVectorData_Holdout(array, 0.6)
    if array_transform is not None:
        array_train_tr, array_val_tr, array_test_tr = SplitVectorData_Holdout(array_transform, 0.6)

    transform_train_mdlp, transform_val_mdlp, transform_test_mdlp, Y_train_mdlp, Y_val_mdlp, Y_test_mdlp = TransformData(array_train, array_val, array_test, len(array_train[0]), MDLP())
    transform_train_minmax, transform_val_minmax, transform_test_minmax, Y_train_minmax, Y_val_minmax, Y_test_minmax = TransformData(array_train, array_val, array_test, len(array_train[0]), MinMaxScaler())

    array_model_5, array_prediction_train_5, array_prediction_val_5, array_prediction_test_5, array_train_5, array_val_5, array_test_5 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), GaussianNB(priors=array_prob))
    if array_transform is not None:
        array_model_10, array_prediction_train_10, array_prediction_val_10, array_prediction_test_10, array_train_10, array_val_10, array_test_10 = GenerateModelDataFromVector(array_train_tr, array_val_tr, array_test_tr, len(array[0]), MultinomialNB(fit_prior=True, class_prior=array_prob))
    else:
        array_model_10, array_prediction_train_10, array_prediction_val_10, array_prediction_test_10, array_train_10, array_val_10, array_test_10 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), MultinomialNB(fit_prior=True, class_prior=array_prob))

    array_model_mdlp, array_prediction_train_mdlp, array_prediction_val_mdlp, array_prediction_test_mdlp, array_train_mdlp, array_val_mdlp, array_test_mdlp = GenerateModelDataFromTransform(transform_train_mdlp, transform_val_mdlp, transform_test_mdlp, Y_train_mdlp, Y_val_mdlp, Y_test_mdlp, len(array[0]), MultinomialNB())
    array_model_minmax, array_prediction_train_minmax, array_prediction_val_minmax, array_prediction_test_minmax, array_train_minmax, array_val_minmax, array_test_minmax = GenerateModelDataFromTransform(transform_train_minmax, transform_val_minmax, transform_test_minmax, Y_train_minmax, Y_val_minmax, Y_test_minmax, len(array[0]), MultinomialNB())


    validations = [[array_val_5, array_prediction_val_5],
    [array_val_10, array_prediction_val_10],
    [array_val_mdlp, array_prediction_val_mdlp],
    [array_val_minmax, array_prediction_val_minmax]]

    return GenerateScores(validations)  
    
def Bayes_KFold(array, array_prob, k, array_transform=None):
    
    array_kfold_train, array_kfold_test = SplitVectorData_KFold(array, k, 0.2)
    if array_transform is not None:
        array_kfold_train_tr, array_kfold_test_tr = SplitVectorData_KFold(array_transform, k, 0.2)
    all_accScores = np.zeros((k, 4), dtype=float)
    all_f1Scores = np.zeros((k, 4), dtype=float)

    for i in range(1, k):

        array_train = concatenateWithoutTestPortion(array_kfold_train, i)
        array_val = array_kfold_train[i]
        array_test = array_kfold_test
        
        if array_transform is not None:
            array_train_tr = concatenateWithoutTestPortion(array_kfold_train_tr, i)
            array_val_tr = array_kfold_train_tr[i]
            array_test_tr = array_kfold_test_tr

        transform_train_mdlp, transform_val_mdlp, transform_test_mdlp, Y_train_mdlp, Y_val_mdlp, Y_test_mdlp = TransformData(array_train, array_val, array_test, len(array_train[0]), MDLP())
        transform_train_minmax, transform_val_minmax, transform_test_minmax, Y_train_minmax, Y_val_minmax, Y_test_minmax = TransformData(array_train, array_val, array_test, len(array_train[0]), MinMaxScaler())

        array_model_5, array_prediction_train_5, array_prediction_val_5, array_prediction_test_5, array_train_5, array_val_5, array_test_5 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), GaussianNB(priors=array_prob))
        if array_transform is not None:
            array_model_10, array_prediction_train_10, array_prediction_val_10, array_prediction_test_10, array_train_10, array_val_10, array_test_10 = GenerateModelDataFromVector(array_train_tr, array_val_tr, array_test_tr, len(array[0]), MultinomialNB(fit_prior=True, class_prior=array_prob))
        else:
            array_model_10, array_prediction_train_10, array_prediction_val_10, array_prediction_test_10, array_train_10, array_val_10, array_test_10 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), MultinomialNB(fit_prior=True, class_prior=array_prob))
        array_model_mdlp, array_prediction_train_mdlp, array_prediction_val_mdlp, array_prediction_test_mdlp, array_train_mdlp, array_val_mdlp, array_test_mdlp = GenerateModelDataFromTransform(transform_train_mdlp, transform_val_mdlp, transform_test_mdlp, Y_train_mdlp, Y_val_mdlp, Y_test_mdlp, len(array[0]), MultinomialNB())
        array_model_minmax, array_prediction_train_minmax, array_prediction_val_minmax, array_prediction_test_minmax, array_train_minmax, array_val_minmax, array_test_minmax = GenerateModelDataFromTransform(transform_train_minmax, transform_val_minmax, transform_test_minmax, Y_train_minmax, Y_val_minmax, Y_test_minmax, len(array[0]), MultinomialNB())


        validations = [[array_val_5, array_prediction_val_5],
                     [array_val_10, array_prediction_val_10],
                     [array_val_mdlp, array_prediction_val_mdlp],
                     [array_val_minmax, array_prediction_val_minmax]]

        Array_AccScores, Array_F1Scores = GenerateScores(validations)

        all_accScores[i] = Array_AccScores
        all_f1Scores[i] = Array_F1Scores 
        
    accScores_mean = scores_mean(all_accScores)
    f1Scores_mean = scores_mean(all_f1Scores)

    return accScores_mean, f1Scores_mean

# %%
#KNN Methods
def KNN_Holdout(array):
    array_train, array_val, array_test = SplitVectorData_Holdout(array, 0.6)

    array_model_3u, array_prediction_train_3u, array_prediction_val_3u, array_prediction_test_3u, array_train_3u, array_val_3u, array_test_3u = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateKNNModel(3, 'uniform'))
    array_model_5u, array_prediction_train_5u, array_prediction_val_5u, array_prediction_test_5u, array_train_5u, array_val_5u, array_test_5u = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateKNNModel(5, 'uniform'))
    array_model_10u, array_prediction_train_10u, array_prediction_val_10u, array_prediction_test_10u, array_train_10u, array_val_10u, array_test_10u = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateKNNModel(10, 'uniform'))
    array_model_3d, array_prediction_train_3d, array_prediction_val_3d, array_prediction_test_3d, array_train_3d, array_val_3d, array_test_3d = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateKNNModel(3, 'distance'))
    array_model_5d, array_prediction_train_5d, array_prediction_val_5d, array_prediction_test_5d, array_train_5d, array_val_5d, array_test_5d = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateKNNModel(5, 'distance'))
    array_model_10d, array_prediction_train_10d, array_prediction_val_10d, array_prediction_test_10d, array_train_10d, array_val_10d, array_test_10d = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateKNNModel(10, 'distance'))

    validations_uniform = [[array_val_3u, array_prediction_val_3u],
                        [array_val_5u, array_prediction_val_5u],
                        [array_val_10u, array_prediction_val_10u]]

    validations_distance = [[array_val_3d, array_prediction_val_3d],
                        [array_val_5d, array_prediction_val_5d],
                        [array_val_10d, array_prediction_val_10d]]

    accScores_uniform, f1Scores_uniform = GenerateScores(validations_uniform)
    accScores_distance, f1Scores_dsitance = GenerateScores(validations_distance)

    return accScores_uniform, f1Scores_uniform, accScores_distance, f1Scores_dsitance
    
def KNN_KFold(array, k):

    array_kfold_train, array_kfold_test = SplitVectorData_KFold(array, k, 0.2)
    all_accScores_uniform = np.zeros((k, 3), dtype=float)
    all_f1Scores_uniform = np.zeros((k, 3), dtype=float)
    all_accScores_distance = np.zeros((k, 3), dtype=float)
    all_f1Scores_distance = np.zeros((k, 3), dtype=float)

    for i in range(1, k):

        array_train = concatenateWithoutTestPortion(array_kfold_train, i)
        array_val = array_kfold_train[i]
        array_test = array_kfold_test

        array_model_3u, array_prediction_train_3u, array_prediction_val_3u, array_prediction_test_3u, array_train_3u, array_val_3u, array_test_3u = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateKNNModel(3, 'uniform'))
        array_model_5u, array_prediction_train_5u, array_prediction_val_5u, array_prediction_test_5u, array_train_5u, array_val_5u, array_test_5u = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateKNNModel(5, 'uniform'))
        array_model_10u, array_prediction_train_10u, array_prediction_val_10u, array_prediction_test_10u, array_train_10u, array_val_10u, array_test_10u = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateKNNModel(10, 'uniform'))
        array_model_3d, array_prediction_train_3d, array_prediction_val_3d, array_prediction_test_3d, array_train_3d, array_val_3d, array_test_3d = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateKNNModel(3, 'distance'))
        array_model_5d, array_prediction_train_5d, array_prediction_val_5d, array_prediction_test_5d, array_train_5d, array_val_5d, array_test_5d = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateKNNModel(5, 'distance'))
        array_model_10d, array_prediction_train_10d, array_prediction_val_10d, array_prediction_test_10d, array_train_10d, array_val_10d, array_test_10d = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateKNNModel(10, 'distance'))

        validations_uniform = [[array_val_3u, array_prediction_val_3u],
        [array_val_5u, array_prediction_val_5u],
        [array_val_10u, array_prediction_val_10u]]

        validations_distance = [[array_val_3d, array_prediction_val_3d],
        [array_val_5d, array_prediction_val_5d],
        [array_val_10d, array_prediction_val_10d]]

        Array_AccScores_uniform, Array_F1Scores_uniform = GenerateScores(validations_uniform)
        Array_AccScores_distance, Array_F1Scores_distance = GenerateScores(validations_distance)

        all_accScores_uniform[i] = Array_AccScores_uniform
        all_f1Scores_uniform[i] = Array_F1Scores_uniform
        all_accScores_distance[i] = Array_AccScores_distance
        all_f1Scores_distance[i] = Array_F1Scores_distance

    accScores_mean_uniform = scores_mean(all_accScores_uniform)
    f1Scores_mean_uniform = scores_mean(all_f1Scores_uniform)
    accScores_mean_distance = scores_mean(all_accScores_distance)
    f1Scores_mean_distance = scores_mean(all_f1Scores_distance)

    return accScores_mean_uniform, f1Scores_mean_uniform, accScores_mean_distance, f1Scores_mean_distance

# %%
#Random forest methods
def RandomForest_Holdout(array):
    array_train, array_val, array_test = SplitVectorData_Holdout(array, 0.6)

    array_model_none, array_prediction_train_none, array_prediction_val_none, array_prediction_test_none, array_train_none, array_val_none, array_test_none = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateRandomForestModel(None))
    array_model_3, array_prediction_train_3, array_prediction_val_3, array_prediction_test_3, array_train_3, array_val_3, array_test_3 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateRandomForestModel(3))
    array_model_5, array_prediction_train_5, array_prediction_val_5, array_prediction_test_5, array_train_5, array_val_5, array_test_5 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateRandomForestModel(5))
    array_model_10, array_prediction_train_10, array_prediction_val_10, array_prediction_test_10, array_train_10, array_val_10, array_test_10 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateRandomForestModel(10))

    validations = [[array_val_none, array_prediction_val_none],
    [array_val_3, array_prediction_val_3],
    [array_val_5, array_prediction_val_5],
    [array_val_10, array_prediction_val_10]]

    return GenerateScores(validations)

def RandomForest_KFold(array,k):

    array_kfold_train, array_kfold_test = SplitVectorData_KFold(array, k, 0.2)
    all_accScores = np.zeros((k, 4), dtype=float)
    all_f1Scores = np.zeros((k, 4), dtype=float)

    for i in range(1, k):

        array_train = concatenateWithoutTestPortion(array_kfold_train, i)
        array_val = array_kfold_train[i]
        array_test = array_kfold_test

        array_model_none, array_prediction_train_none, array_prediction_val_none, array_prediction_test_none, array_train_none, array_val_none, array_test_none = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateRandomForestModel(None))
        array_model_3, array_prediction_train_3, array_prediction_val_3, array_prediction_test_3, array_train_3, array_val_3, array_test_3 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateRandomForestModel(3))
        array_model_5, array_prediction_train_5, array_prediction_val_5, array_prediction_test_tree_5, array_train_5, array_val_5, array_test_5 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateRandomForestModel(5))
        array_model_10, array_prediction_train_10, array_prediction_val_10, array_prediction_test_tree_10, array_train_10, array_val_10, array_test_10 = GenerateModelDataFromVector(array_train, array_val, array_test, len(array[0]), CreateRandomForestModel(10))

        validations = [[array_val_none, array_prediction_val_none],
        [array_val_3, array_prediction_val_3],
        [array_val_5, array_prediction_val_5],
        [array_val_10, array_prediction_val_10]]

        Array_AccScores, Array_F1Scores = GenerateScores(validations)

        all_accScores[i] = Array_AccScores
        all_f1Scores[i] = Array_F1Scores

    accScores_mean = scores_mean(all_accScores)
    f1Scores_mean = scores_mean(all_f1Scores)
    
    return accScores_mean, f1Scores_mean

# %%
# accScores_filter_tree_holdout, f1Scores_filter_tree_holdout = DecisionTree_Holdout(Filter)
# accScores_filter_tree_kfold, f1Scores_filter_tree_kfold = DecisionTree_KFold(Filter,10)
# accScores_filter_bayes_holdout, f1Scores_filter_bayes_holdout = Bayes_Holdout(Filter, [0.4003,0.5997])
# accScores_filter_bayes_kfold, f1Scores_filter_bayes_kfold = Bayes_KFold(Filter, [0.4003,0.5997], 10)
# accScores_filter_knn_holdout_uniform, f1Scores_filter_knn_holdout_uniform, accScores_filter_knn_holdout_distance, f1Scores_filter_knn_holdout_distance = KNN_Holdout(Filter)
# accScores_filter_knn_kfold_uniform, f1Scores_filter_knn_kfold_uniform, accScores_filter_knn_kfold_distance, f1Scores_filter_knn_kfold_distance = KNN_KFold(Filter, 10) 
# accScores_filter_test, f1Scores_filter_test = UseModelOnTestData(Filter, MultinomialNB(), MinMaxScaler())
# accScores_filter_forest_holdout, f1Scores_filter_forest_holdout = RandomForest_Holdout(Filter)
# accScores_filter_forest_kfold, f1Scores_filter_forest_kfold = RandomForest_KFold(Filter,10)

# %% [markdown]
# ### Galaxies

# %%
# Get some galaxies
fid = open('galaxy_feature_vectors.csv', 'r') 

NbGalaxy = 16000 #16000 total
Galaxies = np.zeros((NbGalaxy, 7), dtype=np.float64)

count = 0
count_smooth = 0
count_spiral = 0

for line in fid:
    element = line.rstrip('\n').split(',')
    
    label = float(element[75])
    
    if label == 0.0 and count_smooth < NbGalaxy/2:
        count_smooth += 1     
    elif label == 1.0 and count_spiral < NbGalaxy/2:
        count_spiral += 1
    else:
        continue

    Galaxies[count] = [element[4], element[5], element[6], element[17], element[23], element[24], element[75]]
        
    count += 1
    if count >= NbGalaxy:
        break

fid.close() 

# ----- For debug -----
#print(count_smooth)
#print(count_spiral)
#print(count)
#print(Galaxies)
#----------------------

# %%
def NormalizeData(data):
    transform = MinMaxScaler()
    return transform.fit_transform(data, data[:,len(Galaxies[0])-1])

def GetGalaxiesClassProbabilities():
    count_smooth = 0
    count_spiral = 0
    
    fid = open('galaxy_feature_vectors.csv', 'r') 
    for line in fid:
        element = line.rstrip('\n').split(',')

        label = float(element[75])

        if label == 0.0:
            count_smooth += 1     
        elif label == 1.0:
            count_spiral += 1
    return [count_smooth/(count_smooth+count_spiral), count_spiral/(count_smooth+count_spiral)]

# %%
def SplitLabelsFromPrimitives(data_train, data_val, data_test):
    num_features = len(data_train[0]) - 1
    
    X_train  = data_train[:,0:num_features]
    Y_train  = data_train[:,num_features]

    X_val  = data_val[:,0:num_features]
    Y_val  = data_val[:,num_features]

    X_test  = data_test[:,0:num_features]
    Y_test  = data_test[:,num_features]
    return X_train, Y_train, X_val, Y_val, X_test, Y_test

def GenerateModel(data_train, data_val, data_test, layers, perceptrons, epochs, learnRate, name):
    
    #Split labels from the primitives
    X_train, Y_train, X_val, Y_val, X_test, Y_test = SplitLabelsFromPrimitives(data_train, data_val, data_test)
    
    #Create model
    model = Sequential()

    #Add layers
    model.add(Dense(units=perceptrons, activation='sigmoid', input_shape=(len(X_train[0]),)))
    model.add(Dropout(0.2))
    for i in range(0, layers - 2):
        model.add(Dense(units=perceptrons, activation='sigmoid'))
        model.add(Dropout(0.2))
    model.add(Dense(units=2, activation='sigmoid'))
    
    #Set optimizers and compile
    sgd = opt.SGD(lr=learnRate, decay=0, momentum=0, nesterov=False)
    model.compile(loss='sparse_categorical_crossentropy', 
              optimizer= sgd,
              metrics=['accuracy'])
    
    #Use TensorBoard
    tb_callback = tf.keras.callbacks.TensorBoard(log_dir='./logs/'+name)
    
    #Train
    model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=epochs, batch_size=100, callbacks=[tb_callback])
    
    model.evaluate(X_test, Y_test)
    
    Y_probs = model.predict(X_test)
    
    Y_pred = Y_probs.argmax(axis=1)
    
    #plt.scatter(X_test[:, 0], X_test[:, 1], c=Y_pred)
    #plt.scatter(X_test[:, 0], X_test[:, 1], c=Y_test)

    return Y_test, Y_pred

def Neurone_Holdout(array):
    array_train, array_val, array_test = SplitVectorData_Holdout(array, 0.6)
    
    AccScores = np.zeros(13, dtype=float)
    
    #base
    y_true_base, y_pred_base = GenerateModel(array_train, array_val, array_test, 4, 100, 60, 0.0005, 'base')
    
    #perceptrons
    y_true_perc1, y_pred_perc1 = GenerateModel(array_train, array_val, array_test, 4, 50, 60, 0.0005, 'perc1')
    y_true_perc2, y_pred_perc2 = GenerateModel(array_train, array_val, array_test, 4, 300, 60, 0.0005, 'perc2')
    y_true_perc3, y_pred_perc3 = GenerateModel(array_train, array_val, array_test, 4, 600, 60, 0.0005, 'perc3')

    #epochs
    y_true_epoch1, y_pred_epoch1 = GenerateModel(array_train, array_val, array_test, 4, 100, 30, 0.0005, 'epoch1')
    y_true_epoch2, y_pred_epoch2 = GenerateModel(array_train, array_val, array_test, 4, 100, 120, 0.0005, 'epoch2')
    y_true_epoch3, y_pred_epoch3 = GenerateModel(array_train, array_val, array_test, 4, 100, 240, 0.0005, 'epoch3')
    
    #layers
    y_true_layer1, y_pred_layer1 = GenerateModel(array_train, array_val, array_test, 6, 100, 60, 0.0005, 'layer1')
    y_true_layer2, y_pred_layer2 = GenerateModel(array_train, array_val, array_test, 12, 100, 60, 0.0005, 'layer2')
    y_true_layer3, y_pred_layer3 = GenerateModel(array_train, array_val, array_test, 24, 100, 60, 0.0005, 'layer3')
    
    #learning rate
    y_true_lr1, y_pred_lr1 = GenerateModel(array_train, array_val, array_test, 4, 100, 60, 0.1, 'lr1')
    y_true_lr2, y_pred_lr2 = GenerateModel(array_train, array_val, array_test, 4, 100, 60, 0.5, 'lr2')
    y_true_lr3, y_pred_lr3 = GenerateModel(array_train, array_val, array_test, 4, 100, 60, 1, 'lr3')

    validations = [[y_true_base, y_pred_base],
    [y_true_perc1, y_pred_perc1],
    [y_true_perc2, y_pred_perc2],
    [y_true_perc3, y_pred_perc3],
    [y_true_epoch1, y_pred_epoch1],
    [y_true_epoch2, y_pred_epoch2],
    [y_true_epoch3, y_pred_epoch3],
    [y_true_layer1, y_pred_epoch1],
    [y_true_layer2, y_pred_layer2],
    [y_true_layer3, y_pred_layer3],
    [y_true_lr1, y_pred_lr1],
    [y_true_lr2, y_pred_lr2],
    [y_true_lr3, y_pred_lr3]]
    
    return GenerateScores(validations)
    
def Neurone_KFold(array,k):

    array_kfold_train, array_kfold_test = SplitVectorData_KFold(array, k, 0.2)
    all_accScores = np.zeros((k, 13), dtype=float)
    all_f1Scores = np.zeros((k, 13), dtype=float)

    for i in range(1, k):

        array_train = concatenateWithoutTestPortion(array_kfold_train, i)
        array_val = array_kfold_train[i]
        array_test = array_kfold_test
        
        #base
        y_true_base, y_pred_base = GenerateModel(array_train, array_val, array_test, 4, 100, 60, 0.0005, 'kfold/k'+str(i)+'_base')

        #perceptrons
        y_true_perc1, y_pred_perc1 = GenerateModel(array_train, array_val, array_test, 4, 50, 60, 0.0005, 'kfold/k'+str(i)+'_perc1')
        y_true_perc2, y_pred_perc2 = GenerateModel(array_train, array_val, array_test, 4, 300, 60, 0.0005, 'kfold/k'+str(i)+'_perc2')
        y_true_perc3, y_pred_perc3 = GenerateModel(array_train, array_val, array_test, 4, 600, 60, 0.0005, 'kfold/k'+str(i)+'_perc3')

        #epochs
        y_true_epoch1, y_pred_epoch1 = GenerateModel(array_train, array_val, array_test, 4, 100, 30, 0.0005, 'kfold/k'+str(i)+'_epoch1')
        y_true_epoch2, y_pred_epoch2 = GenerateModel(array_train, array_val, array_test, 4, 100, 120, 0.0005, 'kfold/k'+str(i)+'_epoch2')
        y_true_epoch3, y_pred_epoch3 = GenerateModel(array_train, array_val, array_test, 4, 100, 240, 0.0005, 'kfold/k'+str(i)+'_epoch3')

        #layers
        y_true_layer1, y_pred_layer1 = GenerateModel(array_train, array_val, array_test, 6, 100, 60, 0.0005, 'kfold/k'+str(i)+'_layer1')
        y_true_layer2, y_pred_layer2 = GenerateModel(array_train, array_val, array_test, 12, 100, 60, 0.0005, 'kfold/k'+str(i)+'_layer2')
        y_true_layer3, y_pred_layer3 = GenerateModel(array_train, array_val, array_test, 24, 100, 60, 0.0005, 'kfold/k'+str(i)+'_layer3')

        #learning rate
        y_true_lr1, y_pred_lr1 = GenerateModel(array_train, array_val, array_test, 4, 100, 60, 0.1, 'kfold/k'+str(i)+'_lr1')
        y_true_lr2, y_pred_lr2 = GenerateModel(array_train, array_val, array_test, 4, 100, 60, 0.5, 'kfold/k'+str(i)+'_lr2')
        y_true_lr3, y_pred_lr3 = GenerateModel(array_train, array_val, array_test, 4, 100, 60, 1, 'kfold/k'+str(i)+'_lr3')

        validations = [[y_true_base, y_pred_base],
        [y_true_perc1, y_pred_perc1],
        [y_true_perc2, y_pred_perc2],
        [y_true_perc3, y_pred_perc3],
        [y_true_epoch1, y_pred_epoch1],
        [y_true_epoch2, y_pred_epoch2],
        [y_true_epoch3, y_pred_epoch3],
        [y_true_layer1, y_pred_epoch1],
        [y_true_layer2, y_pred_layer2],
        [y_true_layer3, y_pred_layer3],
        [y_true_lr1, y_pred_lr1],
        [y_true_lr2, y_pred_lr2],
        [y_true_lr3, y_pred_lr3]]

        Array_AccScores, Array_F1Scores = GenerateScores(validations)

        all_accScores[i] = Array_AccScores
        all_f1Scores[i] = Array_F1Scores

    accScores_mean = scores_mean(all_accScores)
    f1Scores_mean = scores_mean(all_f1Scores)
    
    return accScores_mean, f1Scores_mean

# %%
acc_neurone_holdout, f1_neurone_holdout = Neurone_Holdout(Galaxies)
# Out:
# Train on 9600 samples, validate on 3200 samples
# Epoch 1/60
# 9600/9600 [==============================] - 1s 91us/step - loss: 0.7067 - acc: 0.4915 - val_loss: 0.6993 - val_acc: 0.4819
# Epoch 2/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.7083 - acc: 0.4830 - val_loss: 0.6978 - val_acc: 0.4819
# Epoch 3/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.7047 - acc: 0.4894 - val_loss: 0.6966 - val_acc: 0.4819
# Epoch 4/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.7032 - acc: 0.4889 - val_loss: 0.6958 - val_acc: 0.4819
# Epoch 5/60
# 9600/9600 [==============================] - ETA: 0s - loss: 0.7024 - acc: 0.490 - 0s 25us/step - loss: 0.7024 - acc: 0.4901 - val_loss: 0.6952 - val_acc: 0.4819
# Epoch 6/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.7010 - acc: 0.4970 - val_loss: 0.6946 - val_acc: 0.4819
# Epoch 7/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.7005 - acc: 0.4961 - val_loss: 0.6942 - val_acc: 0.4819
# Epoch 8/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.7007 - acc: 0.4937 - val_loss: 0.6939 - val_acc: 0.4819
# Epoch 9/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6975 - acc: 0.5049 - val_loss: 0.6937 - val_acc: 0.4819
# Epoch 10/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6987 - acc: 0.5028 - val_loss: 0.6934 - val_acc: 0.3769
# Epoch 11/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.7009 - acc: 0.4975 - val_loss: 0.6933 - val_acc: 0.5181
# Epoch 12/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6977 - acc: 0.5039 - val_loss: 0.6932 - val_acc: 0.5181
# Epoch 13/60
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.6997 - acc: 0.5004 - val_loss: 0.6931 - val_acc: 0.5181
# Epoch 14/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6994 - acc: 0.4942 - val_loss: 0.6930 - val_acc: 0.5181
# Epoch 15/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6994 - acc: 0.4955 - val_loss: 0.6929 - val_acc: 0.5181
# Epoch 16/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6984 - acc: 0.5029 - val_loss: 0.6929 - val_acc: 0.5181
# Epoch 17/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6973 - acc: 0.5058 - val_loss: 0.6929 - val_acc: 0.5181
# Epoch 18/60
# 9600/9600 [==============================] - ETA: 0s - loss: 0.6993 - acc: 0.497 - 0s 24us/step - loss: 0.6990 - acc: 0.4970 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 19/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6976 - acc: 0.5021 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 20/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6978 - acc: 0.5039 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 21/60
# 9600/9600 [==============================] - ETA: 0s - loss: 0.6996 - acc: 0.502 - 0s 25us/step - loss: 0.7000 - acc: 0.5006 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 22/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6990 - acc: 0.4998 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 23/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6970 - acc: 0.5081 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 24/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6968 - acc: 0.5069 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 25/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6984 - acc: 0.5007 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 26/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6979 - acc: 0.5040 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 27/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6981 - acc: 0.4996 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 28/60
# 9600/9600 [==============================] - 0s 28us/step - loss: 0.6980 - acc: 0.4986 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 29/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6995 - acc: 0.5004 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 30/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6997 - acc: 0.4978 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 31/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6982 - acc: 0.4991 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 32/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6978 - acc: 0.5033 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 33/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6980 - acc: 0.4996 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 34/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6974 - acc: 0.5011 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 35/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6953 - acc: 0.5101 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 36/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6980 - acc: 0.4993 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 37/60
# 9600/9600 [==============================] - ETA: 0s - loss: 0.6982 - acc: 0.506 - 0s 25us/step - loss: 0.6978 - acc: 0.5073 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 38/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6996 - acc: 0.4937 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 39/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6987 - acc: 0.4979 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 40/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6976 - acc: 0.5074 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 41/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6980 - acc: 0.5052 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 42/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6978 - acc: 0.5074 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 43/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6988 - acc: 0.5000 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 44/60
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.6980 - acc: 0.5022 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 45/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6974 - acc: 0.5081 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 46/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6949 - acc: 0.5174 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 47/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6979 - acc: 0.5037 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 48/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6963 - acc: 0.5096 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 49/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6958 - acc: 0.5058 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 50/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6956 - acc: 0.5107 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 51/60
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.6970 - acc: 0.5035 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 52/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6959 - acc: 0.5119 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 53/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6957 - acc: 0.5115 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 54/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6968 - acc: 0.5033 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 55/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6961 - acc: 0.5105 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 56/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6972 - acc: 0.5076 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 57/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6968 - acc: 0.4996 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 58/60
# 9600/9600 [==============================] - 0s 27us/step - loss: 0.6967 - acc: 0.5043 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 59/60
# 9600/9600 [==============================] - 0s 27us/step - loss: 0.6968 - acc: 0.5084 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 60/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6976 - acc: 0.5050 - val_loss: 0.6927 - val_acc: 0.5181
# 3200/3200 [==============================] - 0s 13us/step
# Train on 9600 samples, validate on 3200 samples
# Epoch 1/60
# 9600/9600 [==============================] - 1s 89us/step - loss: 0.7042 - acc: 0.4902 - val_loss: 0.6988 - val_acc: 0.4819
# Epoch 2/60
# 9600/9600 [==============================] - 0s 17us/step - loss: 0.7052 - acc: 0.4808 - val_loss: 0.6982 - val_acc: 0.4819
# Epoch 3/60
# 9600/9600 [==============================] - 0s 17us/step - loss: 0.7043 - acc: 0.4850 - val_loss: 0.6976 - val_acc: 0.4819
# Epoch 4/60
# 9600/9600 [==============================] - 0s 15us/step - loss: 0.7034 - acc: 0.4847 - val_loss: 0.6971 - val_acc: 0.4819
# Epoch 5/60
# 9600/9600 [==============================] - 0s 17us/step - loss: 0.6999 - acc: 0.4975 - val_loss: 0.6966 - val_acc: 0.4819
# Epoch 6/60
# 9600/9600 [==============================] - 0s 16us/step - loss: 0.7036 - acc: 0.4824 - val_loss: 0.6962 - val_acc: 0.4819
# Epoch 7/60
# 9600/9600 [==============================] - 0s 17us/step - loss: 0.7016 - acc: 0.4881 - val_loss: 0.6958 - val_acc: 0.4819
# Epoch 8/60
# 9600/9600 [==============================] - 0s 17us/step - loss: 0.6993 - acc: 0.4972 - val_loss: 0.6955 - val_acc: 0.4819
# Epoch 9/60
# 9600/9600 [==============================] - 0s 16us/step - loss: 0.7006 - acc: 0.4879 - val_loss: 0.6952 - val_acc: 0.4819
# Epoch 10/60
# 9600/9600 [==============================] - 0s 16us/step - loss: 0.6991 - acc: 0.4976 - val_loss: 0.6949 - val_acc: 0.4819
# Epoch 11/60
# 9600/9600 [==============================] - 0s 17us/step - loss: 0.6982 - acc: 0.4941 - val_loss: 0.6947 - val_acc: 0.4819
# Epoch 12/60
# 9600/9600 [==============================] - 0s 19us/step - loss: 0.6984 - acc: 0.4897 - val_loss: 0.6945 - val_acc: 0.4819
# Epoch 13/60
# 9600/9600 [==============================] - 0s 14us/step - loss: 0.6974 - acc: 0.5064 - val_loss: 0.6943 - val_acc: 0.4819
# Epoch 14/60
# 9600/9600 [==============================] - 0s 16us/step - loss: 0.6974 - acc: 0.4950 - val_loss: 0.6941 - val_acc: 0.4819
# Epoch 15/60
# 9600/9600 [==============================] - 0s 19us/step - loss: 0.6964 - acc: 0.5024 - val_loss: 0.6939 - val_acc: 0.4819
# Epoch 16/60
# 9600/9600 [==============================] - 0s 15us/step - loss: 0.6977 - acc: 0.4985 - val_loss: 0.6938 - val_acc: 0.4819
# Epoch 17/60
# 9600/9600 [==============================] - 0s 17us/step - loss: 0.6985 - acc: 0.4946 - val_loss: 0.6936 - val_acc: 0.4819
# Epoch 18/60
# 9600/9600 [==============================] - 0s 16us/step - loss: 0.6978 - acc: 0.5006 - val_loss: 0.6935 - val_acc: 0.4819
# Epoch 19/60
# 9600/9600 [==============================] - 0s 16us/step - loss: 0.6966 - acc: 0.5009 - val_loss: 0.6934 - val_acc: 0.4819
# Epoch 20/60
# 9600/9600 [==============================] - 0s 18us/step - loss: 0.6964 - acc: 0.5039 - val_loss: 0.6933 - val_acc: 0.4819
# Epoch 21/60
# 9600/9600 [==============================] - 0s 15us/step - loss: 0.6969 - acc: 0.5002 - val_loss: 0.6932 - val_acc: 0.4825
# Epoch 22/60
# 9600/9600 [==============================] - 0s 14us/step - loss: 0.6952 - acc: 0.5010 - val_loss: 0.6931 - val_acc: 0.4953
# Epoch 23/60
# 9600/9600 [==============================] - 0s 16us/step - loss: 0.6969 - acc: 0.5017 - val_loss: 0.6931 - val_acc: 0.5194
# Epoch 24/60
# 9600/9600 [==============================] - 0s 17us/step - loss: 0.6960 - acc: 0.5047 - val_loss: 0.6930 - val_acc: 0.5184
# Epoch 25/60
# 9600/9600 [==============================] - 0s 16us/step - loss: 0.6987 - acc: 0.4915 - val_loss: 0.6930 - val_acc: 0.5181
# Epoch 26/60
# 9600/9600 [==============================] - 0s 16us/step - loss: 0.6969 - acc: 0.5028 - val_loss: 0.6929 - val_acc: 0.5181
# Epoch 27/60
# 9600/9600 [==============================] - 0s 19us/step - loss: 0.6975 - acc: 0.4910 - val_loss: 0.6929 - val_acc: 0.5181
# Epoch 28/60
# 9600/9600 [==============================] - 0s 16us/step - loss: 0.6952 - acc: 0.5087 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 29/60
# 9600/9600 [==============================] - 0s 16us/step - loss: 0.6972 - acc: 0.4983 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 30/60
# 9600/9600 [==============================] - 0s 17us/step - loss: 0.6952 - acc: 0.5084 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 31/60
# 9600/9600 [==============================] - 0s 16us/step - loss: 0.6972 - acc: 0.5034 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 32/60
# 9600/9600 [==============================] - 0s 17us/step - loss: 0.6958 - acc: 0.5066 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 33/60
# 9600/9600 [==============================] - 0s 17us/step - loss: 0.6969 - acc: 0.4983 - val_loss: 0.6926 - val_acc: 0.5181
# Epoch 34/60
# 9600/9600 [==============================] - 0s 16us/step - loss: 0.6965 - acc: 0.5009 - val_loss: 0.6926 - val_acc: 0.5181
# Epoch 35/60
# 9600/9600 [==============================] - 0s 16us/step - loss: 0.6968 - acc: 0.4983 - val_loss: 0.6926 - val_acc: 0.5181
# Epoch 36/60
# 9600/9600 [==============================] - 0s 16us/step - loss: 0.6965 - acc: 0.5004 - val_loss: 0.6926 - val_acc: 0.5181
# Epoch 37/60
# 9600/9600 [==============================] - ETA: 0s - loss: 0.6943 - acc: 0.513 - 0s 17us/step - loss: 0.6951 - acc: 0.5126 - val_loss: 0.6926 - val_acc: 0.5181
# Epoch 38/60
# 9600/9600 [==============================] - 0s 16us/step - loss: 0.6971 - acc: 0.5002 - val_loss: 0.6925 - val_acc: 0.5181
# Epoch 39/60
# 9600/9600 [==============================] - 0s 16us/step - loss: 0.6957 - acc: 0.5080 - val_loss: 0.6925 - val_acc: 0.5181
# Epoch 40/60
# 9600/9600 [==============================] - 0s 17us/step - loss: 0.6960 - acc: 0.5062 - val_loss: 0.6925 - val_acc: 0.5181
# Epoch 41/60
# 9600/9600 [==============================] - 0s 15us/step - loss: 0.6963 - acc: 0.5068 - val_loss: 0.6925 - val_acc: 0.5181
# Epoch 42/60
# 9600/9600 [==============================] - 0s 16us/step - loss: 0.6955 - acc: 0.5043 - val_loss: 0.6925 - val_acc: 0.5181
# Epoch 43/60
# 9600/9600 [==============================] - 0s 16us/step - loss: 0.6959 - acc: 0.5056 - val_loss: 0.6925 - val_acc: 0.5181
# Epoch 44/60
# 9600/9600 [==============================] - 0s 17us/step - loss: 0.6964 - acc: 0.5086 - val_loss: 0.6925 - val_acc: 0.5181
# Epoch 45/60
# 9600/9600 [==============================] - 0s 17us/step - loss: 0.6968 - acc: 0.4965 - val_loss: 0.6925 - val_acc: 0.5181
# Epoch 46/60
# 9600/9600 [==============================] - 0s 17us/step - loss: 0.6970 - acc: 0.5069 - val_loss: 0.6925 - val_acc: 0.5181
# Epoch 47/60
# 9600/9600 [==============================] - 0s 16us/step - loss: 0.6964 - acc: 0.4989 - val_loss: 0.6925 - val_acc: 0.5181
# Epoch 48/60
# 9600/9600 [==============================] - 0s 17us/step - loss: 0.6957 - acc: 0.4999 - val_loss: 0.6925 - val_acc: 0.5181
# Epoch 49/60
# 9600/9600 [==============================] - 0s 16us/step - loss: 0.6965 - acc: 0.5111 - val_loss: 0.6925 - val_acc: 0.5181
# Epoch 50/60
# 9600/9600 [==============================] - 0s 17us/step - loss: 0.6963 - acc: 0.5042 - val_loss: 0.6925 - val_acc: 0.5181
# Epoch 51/60
# 9600/9600 [==============================] - 0s 16us/step - loss: 0.6975 - acc: 0.5010 - val_loss: 0.6924 - val_acc: 0.5181
# Epoch 52/60
# 9600/9600 [==============================] - ETA: 0s - loss: 0.6955 - acc: 0.507 - 0s 17us/step - loss: 0.6948 - acc: 0.5095 - val_loss: 0.6924 - val_acc: 0.5181
# Epoch 53/60
# 9600/9600 [==============================] - 0s 18us/step - loss: 0.6958 - acc: 0.5085 - val_loss: 0.6924 - val_acc: 0.5181
# Epoch 54/60
# 9600/9600 [==============================] - 0s 16us/step - loss: 0.6946 - acc: 0.5128 - val_loss: 0.6924 - val_acc: 0.5181
# Epoch 55/60
# 9600/9600 [==============================] - 0s 17us/step - loss: 0.6950 - acc: 0.5053 - val_loss: 0.6924 - val_acc: 0.5181
# Epoch 56/60
# 9600/9600 [==============================] - 0s 16us/step - loss: 0.6961 - acc: 0.5050 - val_loss: 0.6924 - val_acc: 0.5181
# Epoch 57/60
# 9600/9600 [==============================] - 0s 16us/step - loss: 0.6958 - acc: 0.5035 - val_loss: 0.6924 - val_acc: 0.5181
# Epoch 58/60
# 9600/9600 [==============================] - 0s 16us/step - loss: 0.6957 - acc: 0.5048 - val_loss: 0.6924 - val_acc: 0.5181
# Epoch 59/60
# 9600/9600 [==============================] - 0s 17us/step - loss: 0.6961 - acc: 0.5044 - val_loss: 0.6924 - val_acc: 0.5181
# Epoch 60/60
# 9600/9600 [==============================] - 0s 17us/step - loss: 0.6953 - acc: 0.5075 - val_loss: 0.6924 - val_acc: 0.5181
# 3200/3200 [==============================] - 0s 11us/step
# Train on 9600 samples, validate on 3200 samples
# Epoch 1/60
# 9600/9600 [==============================] - 1s 112us/step - loss: 0.7044 - acc: 0.4959 - val_loss: 0.6940 - val_acc: 0.4822
# Epoch 2/60
# 9600/9600 [==============================] - ETA: 0s - loss: 0.7030 - acc: 0.490 - 0s 43us/step - loss: 0.7025 - acc: 0.4919 - val_loss: 0.6932 - val_acc: 0.5181
# Epoch 3/60
# 9600/9600 [==============================] - 0s 40us/step - loss: 0.7014 - acc: 0.4968 - val_loss: 0.6930 - val_acc: 0.5181
# Epoch 4/60
# 9600/9600 [==============================] - 0s 40us/step - loss: 0.7003 - acc: 0.5010 - val_loss: 0.6929 - val_acc: 0.5181
# Epoch 5/60
# 9600/9600 [==============================] - 0s 40us/step - loss: 0.7000 - acc: 0.4991 - val_loss: 0.6929 - val_acc: 0.5181
# Epoch 6/60
# 9600/9600 [==============================] - 0s 40us/step - loss: 0.7004 - acc: 0.5037 - val_loss: 0.6929 - val_acc: 0.5181
# Epoch 7/60
# 9600/9600 [==============================] - 0s 42us/step - loss: 0.7012 - acc: 0.5037 - val_loss: 0.6929 - val_acc: 0.5181
# Epoch 8/60
# 9600/9600 [==============================] - 0s 41us/step - loss: 0.7003 - acc: 0.5072 - val_loss: 0.6929 - val_acc: 0.5181
# Epoch 9/60
# 9600/9600 [==============================] - 0s 40us/step - loss: 0.6997 - acc: 0.5091 - val_loss: 0.6929 - val_acc: 0.5181
# Epoch 10/60
# 9600/9600 [==============================] - 0s 40us/step - loss: 0.7021 - acc: 0.4975 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 11/60
# 9600/9600 [==============================] - 0s 42us/step - loss: 0.7000 - acc: 0.5081 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 12/60
# 9600/9600 [==============================] - 0s 41us/step - loss: 0.6982 - acc: 0.5076 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 13/60
# 9600/9600 [==============================] - 0s 42us/step - loss: 0.6978 - acc: 0.5101 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 14/60
# 9600/9600 [==============================] - 0s 40us/step - loss: 0.7002 - acc: 0.5052 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 15/60
# 9600/9600 [==============================] - 0s 40us/step - loss: 0.6985 - acc: 0.5053 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 16/60
# 9600/9600 [==============================] - 0s 40us/step - loss: 0.6982 - acc: 0.5085 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 17/60
# 9600/9600 [==============================] - 0s 42us/step - loss: 0.6988 - acc: 0.5002 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 18/60
# 9600/9600 [==============================] - 0s 40us/step - loss: 0.7002 - acc: 0.5002 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 19/60
# 9600/9600 [==============================] - 0s 40us/step - loss: 0.6995 - acc: 0.5012 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 20/60
# 9600/9600 [==============================] - 0s 40us/step - loss: 0.6966 - acc: 0.5108 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 21/60
# 9600/9600 [==============================] - 0s 42us/step - loss: 0.6981 - acc: 0.5060 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 22/60
# 9600/9600 [==============================] - 0s 40us/step - loss: 0.6989 - acc: 0.5049 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 23/60
# 9600/9600 [==============================] - 0s 42us/step - loss: 0.6990 - acc: 0.4996 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 24/60
# 9600/9600 [==============================] - 0s 40us/step - loss: 0.6974 - acc: 0.5030 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 25/60
# 9600/9600 [==============================] - 0s 43us/step - loss: 0.6974 - acc: 0.5032 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 26/60
# 9600/9600 [==============================] - 0s 40us/step - loss: 0.6974 - acc: 0.5047 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 27/60
# 9600/9600 [==============================] - 0s 40us/step - loss: 0.6965 - acc: 0.5159 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 28/60
# 9600/9600 [==============================] - 0s 42us/step - loss: 0.6996 - acc: 0.4981 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 29/60
# 9600/9600 [==============================] - 0s 41us/step - loss: 0.6970 - acc: 0.5073 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 30/60
# 9600/9600 [==============================] - 0s 46us/step - loss: 0.6986 - acc: 0.5012 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 31/60
# 9600/9600 [==============================] - 0s 43us/step - loss: 0.6968 - acc: 0.5075 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 32/60
# 9600/9600 [==============================] - 0s 41us/step - loss: 0.6960 - acc: 0.5097 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 33/60
# 9600/9600 [==============================] - 0s 42us/step - loss: 0.6979 - acc: 0.5053 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 34/60
# 9600/9600 [==============================] - 0s 41us/step - loss: 0.6981 - acc: 0.5016 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 35/60
# 9600/9600 [==============================] - 0s 41us/step - loss: 0.6960 - acc: 0.5062 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 36/60
# 9600/9600 [==============================] - 0s 42us/step - loss: 0.6952 - acc: 0.5125 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 37/60
# 9600/9600 [==============================] - 0s 41us/step - loss: 0.6971 - acc: 0.5085 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 38/60
# 9600/9600 [==============================] - 0s 41us/step - loss: 0.6969 - acc: 0.5069 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 39/60
# 9600/9600 [==============================] - 0s 44us/step - loss: 0.6981 - acc: 0.4967 - val_loss: 0.6926 - val_acc: 0.5181
# Epoch 40/60
# 9600/9600 [==============================] - 0s 39us/step - loss: 0.6963 - acc: 0.5109 - val_loss: 0.6926 - val_acc: 0.5181
# Epoch 41/60
# 9600/9600 [==============================] - 0s 40us/step - loss: 0.6963 - acc: 0.5127 - val_loss: 0.6926 - val_acc: 0.5181
# Epoch 42/60
# 9600/9600 [==============================] - 0s 40us/step - loss: 0.6962 - acc: 0.5099 - val_loss: 0.6926 - val_acc: 0.5181
# Epoch 43/60
# 9600/9600 [==============================] - 0s 44us/step - loss: 0.6972 - acc: 0.5011 - val_loss: 0.6926 - val_acc: 0.5181
# Epoch 44/60
# 9600/9600 [==============================] - 0s 39us/step - loss: 0.6964 - acc: 0.5083 - val_loss: 0.6926 - val_acc: 0.5181
# Epoch 45/60
# 9600/9600 [==============================] - 0s 40us/step - loss: 0.6957 - acc: 0.5121 - val_loss: 0.6926 - val_acc: 0.5181
# Epoch 46/60
# 9600/9600 [==============================] - 0s 42us/step - loss: 0.6967 - acc: 0.5050 - val_loss: 0.6926 - val_acc: 0.5181
# Epoch 47/60
# 9600/9600 [==============================] - 0s 40us/step - loss: 0.6971 - acc: 0.5064 - val_loss: 0.6926 - val_acc: 0.5181
# Epoch 48/60
# 9600/9600 [==============================] - 0s 40us/step - loss: 0.6964 - acc: 0.5052 - val_loss: 0.6926 - val_acc: 0.5181
# Epoch 49/60
# 9600/9600 [==============================] - 0s 41us/step - loss: 0.6975 - acc: 0.5019 - val_loss: 0.6926 - val_acc: 0.5181
# Epoch 50/60
# 9600/9600 [==============================] - 0s 43us/step - loss: 0.6961 - acc: 0.5071 - val_loss: 0.6926 - val_acc: 0.5181
# Epoch 51/60
# 9600/9600 [==============================] - 0s 44us/step - loss: 0.6963 - acc: 0.5023 - val_loss: 0.6926 - val_acc: 0.5181
# Epoch 52/60
# 9600/9600 [==============================] - 0s 43us/step - loss: 0.6971 - acc: 0.4995 - val_loss: 0.6926 - val_acc: 0.5181
# Epoch 53/60
# 9600/9600 [==============================] - 0s 41us/step - loss: 0.6952 - acc: 0.5100 - val_loss: 0.6926 - val_acc: 0.5181
# Epoch 54/60
# 9600/9600 [==============================] - 0s 41us/step - loss: 0.6963 - acc: 0.5039 - val_loss: 0.6926 - val_acc: 0.5181
# Epoch 55/60
# 9600/9600 [==============================] - 0s 41us/step - loss: 0.6958 - acc: 0.5119 - val_loss: 0.6926 - val_acc: 0.5181
# Epoch 56/60
# 9600/9600 [==============================] - 0s 41us/step - loss: 0.6956 - acc: 0.5071 - val_loss: 0.6926 - val_acc: 0.5181
# Epoch 57/60
# 9600/9600 [==============================] - 0s 45us/step - loss: 0.6952 - acc: 0.5064 - val_loss: 0.6926 - val_acc: 0.5181
# Epoch 58/60
# 9600/9600 [==============================] - 0s 41us/step - loss: 0.6948 - acc: 0.5108 - val_loss: 0.6926 - val_acc: 0.5181
# Epoch 59/60
# 9600/9600 [==============================] - 0s 39us/step - loss: 0.6962 - acc: 0.5096 - val_loss: 0.6926 - val_acc: 0.5181
# Epoch 60/60
# 9600/9600 [==============================] - 0s 39us/step - loss: 0.6965 - acc: 0.5030 - val_loss: 0.6926 - val_acc: 0.5181
# 3200/3200 [==============================] - 0s 25us/step
# Train on 9600 samples, validate on 3200 samples
# Epoch 1/60
# 9600/9600 [==============================] - 2s 171us/step - loss: 0.6972 - acc: 0.5056 - val_loss: 0.6924 - val_acc: 0.5181
# Epoch 2/60
# 9600/9600 [==============================] - 1s 122us/step - loss: 0.6985 - acc: 0.5017 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 3/60
# 9600/9600 [==============================] - 1s 100us/step - loss: 0.6964 - acc: 0.5073 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 4/60
# 9600/9600 [==============================] - 1s 101us/step - loss: 0.6971 - acc: 0.5047 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 5/60
# 9600/9600 [==============================] - 1s 100us/step - loss: 0.6948 - acc: 0.5192 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 6/60
# 9600/9600 [==============================] - 1s 101us/step - loss: 0.6972 - acc: 0.5005 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 7/60
# 9600/9600 [==============================] - 1s 99us/step - loss: 0.6976 - acc: 0.5053 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 8/60
# 9600/9600 [==============================] - 1s 100us/step - loss: 0.6989 - acc: 0.4946 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 9/60
# 9600/9600 [==============================] - 1s 106us/step - loss: 0.6945 - acc: 0.5109 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 10/60
# 9600/9600 [==============================] - 1s 99us/step - loss: 0.6983 - acc: 0.5049 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 11/60
# 9600/9600 [==============================] - 1s 100us/step - loss: 0.6966 - acc: 0.5101 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 12/60
# 9600/9600 [==============================] - 1s 102us/step - loss: 0.6961 - acc: 0.5030 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 13/60
# 9600/9600 [==============================] - 1s 100us/step - loss: 0.6956 - acc: 0.5101 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 14/60
# 9600/9600 [==============================] - 1s 98us/step - loss: 0.6982 - acc: 0.4929 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 15/60
# 9600/9600 [==============================] - 1s 105us/step - loss: 0.6966 - acc: 0.4985 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 16/60
# 9600/9600 [==============================] - 1s 103us/step - loss: 0.6964 - acc: 0.4990 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 17/60
# 9600/9600 [==============================] - 1s 99us/step - loss: 0.6963 - acc: 0.5005 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 18/60
# 9600/9600 [==============================] - 1s 99us/step - loss: 0.6957 - acc: 0.5051 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 19/60
# 9600/9600 [==============================] - 1s 98us/step - loss: 0.6967 - acc: 0.4974 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 20/60
# 9600/9600 [==============================] - 1s 100us/step - loss: 0.6947 - acc: 0.5117 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 21/60
# 9600/9600 [==============================] - 1s 105us/step - loss: 0.6949 - acc: 0.5137 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 22/60
# 9600/9600 [==============================] - 1s 106us/step - loss: 0.6947 - acc: 0.5072 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 23/60
# 9600/9600 [==============================] - 1s 99us/step - loss: 0.6954 - acc: 0.5062 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 24/60
# 9600/9600 [==============================] - 1s 99us/step - loss: 0.6966 - acc: 0.5046 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 25/60
# 9600/9600 [==============================] - 1s 98us/step - loss: 0.6966 - acc: 0.5024 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 26/60
# 9600/9600 [==============================] - 1s 98us/step - loss: 0.6948 - acc: 0.5128 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 27/60
# 9600/9600 [==============================] - 1s 99us/step - loss: 0.6966 - acc: 0.4955 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 28/60
# 9600/9600 [==============================] - 1s 97us/step - loss: 0.6948 - acc: 0.5111 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 29/60
# 9600/9600 [==============================] - 1s 99us/step - loss: 0.6937 - acc: 0.5141 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 30/60
# 9600/9600 [==============================] - 1s 99us/step - loss: 0.6943 - acc: 0.5094 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 31/60
# 9600/9600 [==============================] - 1s 103us/step - loss: 0.6951 - acc: 0.5070 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 32/60
# 9600/9600 [==============================] - 1s 104us/step - loss: 0.6943 - acc: 0.5098 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 33/60
# 9600/9600 [==============================] - 1s 99us/step - loss: 0.6940 - acc: 0.5166 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 34/60
# 9600/9600 [==============================] - 1s 101us/step - loss: 0.6941 - acc: 0.5080 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 35/60
# 9600/9600 [==============================] - 1s 102us/step - loss: 0.6944 - acc: 0.5130 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 36/60
# 9600/9600 [==============================] - 1s 98us/step - loss: 0.6938 - acc: 0.5157 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 37/60
# 9600/9600 [==============================] - 1s 99us/step - loss: 0.6950 - acc: 0.5037 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 38/60
# 9600/9600 [==============================] - 1s 101us/step - loss: 0.6946 - acc: 0.5039 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 39/60
# 9600/9600 [==============================] - 1s 104us/step - loss: 0.6945 - acc: 0.5034 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 40/60
# 9600/9600 [==============================] - 1s 100us/step - loss: 0.6942 - acc: 0.5137 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 41/60
# 9600/9600 [==============================] - 1s 97us/step - loss: 0.6949 - acc: 0.5092 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 42/60
# 9600/9600 [==============================] - 1s 105us/step - loss: 0.6930 - acc: 0.5125 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 43/60
# 9600/9600 [==============================] - 1s 106us/step - loss: 0.6941 - acc: 0.5166 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 44/60
# 9600/9600 [==============================] - 1s 98us/step - loss: 0.6944 - acc: 0.5168 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 45/60
# 9600/9600 [==============================] - 1s 100us/step - loss: 0.6943 - acc: 0.5093 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 46/60
# 9600/9600 [==============================] - 1s 97us/step - loss: 0.6938 - acc: 0.5160 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 47/60
# 9600/9600 [==============================] - 1s 101us/step - loss: 0.6950 - acc: 0.5069 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 48/60
# 9600/9600 [==============================] - 1s 105us/step - loss: 0.6943 - acc: 0.5036 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 49/60
# 9600/9600 [==============================] - 1s 99us/step - loss: 0.6929 - acc: 0.5159 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 50/60
# 9600/9600 [==============================] - 1s 100us/step - loss: 0.6933 - acc: 0.5170 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 51/60
# 9600/9600 [==============================] - 1s 99us/step - loss: 0.6942 - acc: 0.5039 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 52/60
# 9600/9600 [==============================] - 1s 99us/step - loss: 0.6939 - acc: 0.5141 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 53/60
# 9600/9600 [==============================] - 1s 99us/step - loss: 0.6929 - acc: 0.5139 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 54/60
# 9600/9600 [==============================] - 1s 100us/step - loss: 0.6948 - acc: 0.5018 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 55/60
# 9600/9600 [==============================] - 1s 99us/step - loss: 0.6942 - acc: 0.5112 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 56/60
# 9600/9600 [==============================] - 1s 98us/step - loss: 0.6924 - acc: 0.5190 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 57/60
# 9600/9600 [==============================] - 1s 99us/step - loss: 0.6928 - acc: 0.5169 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 58/60
# 9600/9600 [==============================] - 1s 99us/step - loss: 0.6936 - acc: 0.5094 - val_loss: 0.6922 - val_acc: 0.5181
# Epoch 59/60
# 9600/9600 [==============================] - 1s 99us/step - loss: 0.6935 - acc: 0.5103 - val_loss: 0.6922 - val_acc: 0.5181
# Epoch 60/60
# 9600/9600 [==============================] - 1s 99us/step - loss: 0.6938 - acc: 0.5154 - val_loss: 0.6922 - val_acc: 0.5181
# 3200/3200 [==============================] - 0s 50us/step
# Train on 9600 samples, validate on 3200 samples
# Epoch 1/30
# 9600/9600 [==============================] - 1s 96us/step - loss: 0.7102 - acc: 0.4910 - val_loss: 0.6979 - val_acc: 0.4819
# Epoch 2/30
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.7049 - acc: 0.5030 - val_loss: 0.6958 - val_acc: 0.4819
# Epoch 3/30
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.7087 - acc: 0.4877 - val_loss: 0.6944 - val_acc: 0.4819
# Epoch 4/30
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.7020 - acc: 0.4996 - val_loss: 0.6937 - val_acc: 0.4819
# Epoch 5/30
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.7021 - acc: 0.4996 - val_loss: 0.6931 - val_acc: 0.4819
# Epoch 6/30
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.7053 - acc: 0.4894 - val_loss: 0.6928 - val_acc: 0.5241
# Epoch 7/30
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.7035 - acc: 0.4987 - val_loss: 0.6926 - val_acc: 0.5184
# Epoch 8/30
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.7021 - acc: 0.4979 - val_loss: 0.6925 - val_acc: 0.5181
# Epoch 9/30
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.7039 - acc: 0.4935 - val_loss: 0.6924 - val_acc: 0.5181
# Epoch 10/30
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.7006 - acc: 0.5067 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 11/30
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.7026 - acc: 0.4981 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 12/30
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.7012 - acc: 0.5044 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 13/30
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.7008 - acc: 0.5079 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 14/30
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.7032 - acc: 0.5042 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 15/30
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.7002 - acc: 0.5132 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 16/30
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.6991 - acc: 0.5072 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 17/30
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.7022 - acc: 0.5036 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 18/30
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.7003 - acc: 0.5098 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 19/30
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.7014 - acc: 0.5108 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 20/30
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.7014 - acc: 0.5020 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 21/30
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6997 - acc: 0.5133 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 22/30
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.7038 - acc: 0.5015 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 23/30
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.7027 - acc: 0.5001 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 24/30
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.7018 - acc: 0.4989 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 25/30
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.6996 - acc: 0.5085 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 26/30
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.7007 - acc: 0.5069 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 27/30
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.7011 - acc: 0.5046 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 28/30
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.7004 - acc: 0.5028 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 29/30
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.7007 - acc: 0.5071 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 30/30
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.7023 - acc: 0.4956 - val_loss: 0.6923 - val_acc: 0.5181
# 3200/3200 [==============================] - 0s 15us/step
# Train on 9600 samples, validate on 3200 samples
# Epoch 1/120
# 9600/9600 [==============================] - 1s 96us/step - loss: 0.7144 - acc: 0.4836 - val_loss: 0.7069 - val_acc: 0.4819
# Epoch 2/120
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.7106 - acc: 0.4819 - val_loss: 0.7051 - val_acc: 0.4819
# Epoch 3/120
# 9600/9600 [==============================] - 0s 28us/step - loss: 0.7072 - acc: 0.4836 - val_loss: 0.7036 - val_acc: 0.4819
# Epoch 4/120
# 9600/9600 [==============================] - 0s 28us/step - loss: 0.7076 - acc: 0.4810 - val_loss: 0.7022 - val_acc: 0.4819
# Epoch 5/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.7058 - acc: 0.4822 - val_loss: 0.7010 - val_acc: 0.4819
# Epoch 6/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.7036 - acc: 0.4852 - val_loss: 0.7001 - val_acc: 0.4819
# Epoch 7/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.7029 - acc: 0.4859 - val_loss: 0.6992 - val_acc: 0.4819
# Epoch 8/120
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.7012 - acc: 0.4841 - val_loss: 0.6985 - val_acc: 0.4819
# Epoch 9/120
# 9600/9600 [==============================] - 0s 27us/step - loss: 0.7012 - acc: 0.4797 - val_loss: 0.6978 - val_acc: 0.4819
# Epoch 10/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6995 - acc: 0.4862 - val_loss: 0.6973 - val_acc: 0.4819
# Epoch 11/120
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6997 - acc: 0.4882 - val_loss: 0.6968 - val_acc: 0.4819
# Epoch 12/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6994 - acc: 0.4817 - val_loss: 0.6963 - val_acc: 0.4819
# Epoch 13/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6995 - acc: 0.4839 - val_loss: 0.6959 - val_acc: 0.4819
# Epoch 14/120
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.6972 - acc: 0.4945 - val_loss: 0.6956 - val_acc: 0.4819
# Epoch 15/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6990 - acc: 0.4885 - val_loss: 0.6953 - val_acc: 0.4819
# Epoch 16/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6979 - acc: 0.4898 - val_loss: 0.6950 - val_acc: 0.4819
# Epoch 17/120
# 9600/9600 [==============================] - 0s 28us/step - loss: 0.6973 - acc: 0.4918 - val_loss: 0.6948 - val_acc: 0.4819
# Epoch 18/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6982 - acc: 0.4867 - val_loss: 0.6945 - val_acc: 0.4819
# Epoch 19/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6971 - acc: 0.4958 - val_loss: 0.6943 - val_acc: 0.4819
# Epoch 20/120
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.6982 - acc: 0.4901 - val_loss: 0.6942 - val_acc: 0.4819
# Epoch 21/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6967 - acc: 0.4902 - val_loss: 0.6940 - val_acc: 0.4819
# Epoch 22/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6966 - acc: 0.4971 - val_loss: 0.6939 - val_acc: 0.4819
# Epoch 23/120
# 9600/9600 [==============================] - 0s 27us/step - loss: 0.6964 - acc: 0.4966 - val_loss: 0.6937 - val_acc: 0.4819
# Epoch 24/120
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.6968 - acc: 0.4931 - val_loss: 0.6936 - val_acc: 0.4822
# Epoch 25/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6950 - acc: 0.4964 - val_loss: 0.6935 - val_acc: 0.4822
# Epoch 26/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6954 - acc: 0.4948 - val_loss: 0.6935 - val_acc: 0.4725
# Epoch 27/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6954 - acc: 0.4950 - val_loss: 0.6934 - val_acc: 0.3722
# Epoch 28/120
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.6946 - acc: 0.4996 - val_loss: 0.6933 - val_acc: 0.5181
# Epoch 29/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6949 - acc: 0.5015 - val_loss: 0.6932 - val_acc: 0.5181
# Epoch 30/120
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.6947 - acc: 0.5042 - val_loss: 0.6932 - val_acc: 0.5181
# Epoch 31/120
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6962 - acc: 0.4951 - val_loss: 0.6931 - val_acc: 0.5181
# Epoch 32/120
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.6945 - acc: 0.5020 - val_loss: 0.6931 - val_acc: 0.5181
# Epoch 33/120
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.6963 - acc: 0.4923 - val_loss: 0.6930 - val_acc: 0.5181
# Epoch 34/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6958 - acc: 0.4918 - val_loss: 0.6930 - val_acc: 0.5181
# Epoch 35/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6945 - acc: 0.5040 - val_loss: 0.6930 - val_acc: 0.5181
# Epoch 36/120
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.6945 - acc: 0.5039 - val_loss: 0.6929 - val_acc: 0.5181
# Epoch 37/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6958 - acc: 0.4950 - val_loss: 0.6929 - val_acc: 0.5181
# Epoch 38/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6952 - acc: 0.5012 - val_loss: 0.6929 - val_acc: 0.5181
# Epoch 39/120
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.6942 - acc: 0.5092 - val_loss: 0.6929 - val_acc: 0.5181
# Epoch 40/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6936 - acc: 0.5144 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 41/120
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.6943 - acc: 0.5053 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 42/120
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.6939 - acc: 0.5054 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 43/120
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6938 - acc: 0.5062 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 44/120
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.6943 - acc: 0.5064 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 45/120
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.6942 - acc: 0.5092 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 46/120
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.6942 - acc: 0.5090 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 47/120
# 9600/9600 [==============================] - 0s 27us/step - loss: 0.6950 - acc: 0.5072 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 48/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6943 - acc: 0.4987 - val_loss: 0.6928 - val_acc: 0.5181
# Epoch 49/120
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.6954 - acc: 0.4996 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 50/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6941 - acc: 0.5030 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 51/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6938 - acc: 0.5123 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 52/120
# 9600/9600 [==============================] - 0s 22us/step - loss: 0.6948 - acc: 0.5028 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 53/120
# 9600/9600 [==============================] - 0s 27us/step - loss: 0.6953 - acc: 0.5019 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 54/120
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.6949 - acc: 0.5092 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 55/120
# 9600/9600 [==============================] - 0s 27us/step - loss: 0.6948 - acc: 0.5036 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 56/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6943 - acc: 0.5050 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 57/120
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.6952 - acc: 0.5057 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 58/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6950 - acc: 0.5014 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 59/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6936 - acc: 0.5122 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 60/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6937 - acc: 0.5171 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 61/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6943 - acc: 0.5097 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 62/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6934 - acc: 0.5152 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 63/120
# 9600/9600 [==============================] - ETA: 0s - loss: 0.6952 - acc: 0.505 - 0s 24us/step - loss: 0.6952 - acc: 0.5070 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 64/120
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.6943 - acc: 0.5068 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 65/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6948 - acc: 0.5069 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 66/120
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.6935 - acc: 0.5147 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 67/120
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.6955 - acc: 0.4978 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 68/120
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.6946 - acc: 0.5047 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 69/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6944 - acc: 0.5091 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 70/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6942 - acc: 0.5127 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 71/120
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6953 - acc: 0.5024 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 72/120
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6949 - acc: 0.5066 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 73/120
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.6941 - acc: 0.5124 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 74/120
# 9600/9600 [==============================] - 0s 23us/step - loss: 0.6938 - acc: 0.5105 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 75/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6941 - acc: 0.5092 - val_loss: 0.6927 - val_acc: 0.5181
# Epoch 76/120
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6946 - acc: 0.5075 - val_loss: 0.6927 - val_acc: 0.5181
# ...
# Epoch 8/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6920 - acc: 0.5167 - val_loss: 0.6914 - val_acc: 0.5181
# Epoch 9/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.6913 - acc: 0.5241 - val_loss: 0.6912 - val_acc: 0.5181
# Epoch 10/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6920 - acc: 0.5200 - val_loss: 0.6907 - val_acc: 0.5181
# Epoch 11/60
# 9600/9600 [==============================] - 0s 29us/step - loss: 0.6910 - acc: 0.5226 - val_loss: 0.6899 - val_acc: 0.5181
# Epoch 12/60
# 9600/9600 [==============================] - 0s 27us/step - loss: 0.6891 - acc: 0.5347 - val_loss: 0.6902 - val_acc: 0.4819
# Epoch 13/60
# 9600/9600 [==============================] - 0s 28us/step - loss: 0.6861 - acc: 0.5488 - val_loss: 0.6856 - val_acc: 0.4825
# Epoch 14/60
# 9600/9600 [==============================] - ETA: 0s - loss: 0.6757 - acc: 0.580 - 0s 25us/step - loss: 0.6755 - acc: 0.5815 - val_loss: 0.6446 - val_acc: 0.6819
# Epoch 15/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.6548 - acc: 0.6267 - val_loss: 0.6001 - val_acc: 0.6831
# Epoch 16/60
# 9600/9600 [==============================] - ETA: 0s - loss: 0.6332 - acc: 0.654 - 0s 26us/step - loss: 0.6321 - acc: 0.6567 - val_loss: 0.6036 - val_acc: 0.7350
# Epoch 17/60
# 9600/9600 [==============================] - 0s 27us/step - loss: 0.6038 - acc: 0.6908 - val_loss: 0.7128 - val_acc: 0.5975
# Epoch 18/60
# 9600/9600 [==============================] - 0s 28us/step - loss: 0.5925 - acc: 0.7047 - val_loss: 0.5515 - val_acc: 0.7344
# Epoch 19/60
# 9600/9600 [==============================] - 0s 28us/step - loss: 0.5724 - acc: 0.7234 - val_loss: 0.5275 - val_acc: 0.7609
# Epoch 20/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.5608 - acc: 0.7253 - val_loss: 0.5575 - val_acc: 0.7666
# Epoch 21/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.5568 - acc: 0.7336 - val_loss: 0.5187 - val_acc: 0.7750
# Epoch 22/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.5490 - acc: 0.7427 - val_loss: 0.5348 - val_acc: 0.7484
# Epoch 23/60
# 9600/9600 [==============================] - 0s 27us/step - loss: 0.5402 - acc: 0.7450 - val_loss: 0.5216 - val_acc: 0.7597
# Epoch 24/60
# 9600/9600 [==============================] - 0s 28us/step - loss: 0.5279 - acc: 0.7581 - val_loss: 0.4954 - val_acc: 0.7809
# Epoch 25/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.5261 - acc: 0.7550 - val_loss: 0.4948 - val_acc: 0.7812
# Epoch 26/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.5314 - acc: 0.7560 - val_loss: 0.5360 - val_acc: 0.7334
# Epoch 27/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.5190 - acc: 0.7603 - val_loss: 0.5139 - val_acc: 0.7528
# Epoch 28/60
# 9600/9600 [==============================] - 0s 27us/step - loss: 0.5193 - acc: 0.7597 - val_loss: 0.5110 - val_acc: 0.7700
# Epoch 29/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.5203 - acc: 0.7553 - val_loss: 0.5121 - val_acc: 0.7569
# Epoch 30/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.5116 - acc: 0.7664 - val_loss: 0.4855 - val_acc: 0.7831
# Epoch 31/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.5107 - acc: 0.7683 - val_loss: 0.5146 - val_acc: 0.7625
# Epoch 32/60
# 9600/9600 [==============================] - 0s 28us/step - loss: 0.5070 - acc: 0.7688 - val_loss: 0.4968 - val_acc: 0.7691
# Epoch 33/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.5107 - acc: 0.7669 - val_loss: 0.5003 - val_acc: 0.7653
# Epoch 34/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.5038 - acc: 0.7681 - val_loss: 0.4844 - val_acc: 0.7800
# Epoch 35/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.4998 - acc: 0.7740 - val_loss: 0.4962 - val_acc: 0.7791
# Epoch 36/60
# 9600/9600 [==============================] - 0s 29us/step - loss: 0.4991 - acc: 0.7753 - val_loss: 0.4793 - val_acc: 0.7856
# Epoch 37/60
# 9600/9600 [==============================] - 0s 27us/step - loss: 0.4996 - acc: 0.7741 - val_loss: 0.4801 - val_acc: 0.7884
# Epoch 38/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.4988 - acc: 0.7774 - val_loss: 0.4800 - val_acc: 0.7825
# Epoch 39/60
# 9600/9600 [==============================] - 0s 28us/step - loss: 0.4982 - acc: 0.7743 - val_loss: 0.4782 - val_acc: 0.7847
# Epoch 40/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.4992 - acc: 0.7731 - val_loss: 0.5183 - val_acc: 0.7500
# Epoch 41/60
# 9600/9600 [==============================] - ETA: 0s - loss: 0.4964 - acc: 0.773 - 0s 27us/step - loss: 0.4965 - acc: 0.7741 - val_loss: 0.4817 - val_acc: 0.7812
# Epoch 42/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.4920 - acc: 0.7776 - val_loss: 0.4779 - val_acc: 0.7916
# Epoch 43/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.4938 - acc: 0.7774 - val_loss: 0.4757 - val_acc: 0.7844
# Epoch 44/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.4887 - acc: 0.7804 - val_loss: 0.4734 - val_acc: 0.7903
# Epoch 45/60
# 9600/9600 [==============================] - 0s 28us/step - loss: 0.4957 - acc: 0.7737 - val_loss: 0.4954 - val_acc: 0.7791
# Epoch 46/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.4900 - acc: 0.7759 - val_loss: 0.4791 - val_acc: 0.7906
# Epoch 47/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.4927 - acc: 0.7776 - val_loss: 0.4750 - val_acc: 0.7931
# Epoch 48/60
# 9600/9600 [==============================] - 0s 27us/step - loss: 0.4911 - acc: 0.7760 - val_loss: 0.4775 - val_acc: 0.7831
# Epoch 49/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.4937 - acc: 0.7775 - val_loss: 0.4736 - val_acc: 0.7922
# Epoch 50/60
# 9600/9600 [==============================] - 0s 27us/step - loss: 0.4914 - acc: 0.7782 - val_loss: 0.4744 - val_acc: 0.7884
# Epoch 51/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.4877 - acc: 0.7797 - val_loss: 0.4796 - val_acc: 0.7869
# Epoch 52/60
# 9600/9600 [==============================] - 0s 27us/step - loss: 0.4808 - acc: 0.7889 - val_loss: 0.4838 - val_acc: 0.7828
# Epoch 53/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.4868 - acc: 0.7797 - val_loss: 0.4786 - val_acc: 0.7900
# Epoch 54/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.4871 - acc: 0.7798 - val_loss: 0.4711 - val_acc: 0.7928
# Epoch 55/60
# 9600/9600 [==============================] - 0s 27us/step - loss: 0.4887 - acc: 0.7785 - val_loss: 0.4786 - val_acc: 0.7828
# Epoch 56/60
# 9600/9600 [==============================] - 0s 27us/step - loss: 0.4843 - acc: 0.7837 - val_loss: 0.4753 - val_acc: 0.7909
# Epoch 57/60
# 9600/9600 [==============================] - 0s 27us/step - loss: 0.4845 - acc: 0.7780 - val_loss: 0.4848 - val_acc: 0.7759
# Epoch 58/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.4849 - acc: 0.7792 - val_loss: 0.4711 - val_acc: 0.7919
# Epoch 59/60
# 9600/9600 [==============================] - ETA: 0s - loss: 0.4805 - acc: 0.785 - ETA: 0s - loss: 0.4822 - acc: 0.785 - 0s 25us/step - loss: 0.4883 - acc: 0.7797 - val_loss: 0.4733 - val_acc: 0.7919
# Epoch 60/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.4861 - acc: 0.7801 - val_loss: 0.4700 - val_acc: 0.7931
# 3200/3200 [==============================] - 0s 15us/step
# Train on 9600 samples, validate on 3200 samples
# Epoch 1/60
# 9600/9600 [==============================] - 1s 121us/step - loss: 0.6946 - acc: 0.5195 - val_loss: 0.6925 - val_acc: 0.5181
# Epoch 2/60
# 9600/9600 [==============================] - 0s 27us/step - loss: 0.6925 - acc: 0.5204 - val_loss: 0.6925 - val_acc: 0.5181
# Epoch 3/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6924 - acc: 0.5204 - val_loss: 0.6924 - val_acc: 0.5181
# Epoch 4/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.6924 - acc: 0.5204 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 5/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.6922 - acc: 0.5204 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 6/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6920 - acc: 0.5204 - val_loss: 0.6921 - val_acc: 0.5181
# Epoch 7/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6922 - acc: 0.5203 - val_loss: 0.6922 - val_acc: 0.5181
# Epoch 8/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6924 - acc: 0.5204 - val_loss: 0.6919 - val_acc: 0.5181
# Epoch 9/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.6922 - acc: 0.5204 - val_loss: 0.6920 - val_acc: 0.5181
# Epoch 10/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6918 - acc: 0.5204 - val_loss: 0.6914 - val_acc: 0.5181
# Epoch 11/60
# 9600/9600 [==============================] - 0s 28us/step - loss: 0.6913 - acc: 0.5204 - val_loss: 0.6917 - val_acc: 0.5181
# Epoch 12/60
# 9600/9600 [==============================] - 0s 27us/step - loss: 0.6911 - acc: 0.5204 - val_loss: 0.6901 - val_acc: 0.5181
# Epoch 13/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6901 - acc: 0.5204 - val_loss: 0.6903 - val_acc: 0.5181
# Epoch 14/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6871 - acc: 0.5228 - val_loss: 0.6844 - val_acc: 0.5200
# Epoch 15/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.6940 - acc: 0.5131 - val_loss: 0.6934 - val_acc: 0.4819
# Epoch 16/60
# 9600/9600 [==============================] - 0s 28us/step - loss: 0.6934 - acc: 0.4796 - val_loss: 0.6933 - val_acc: 0.4819
# Epoch 17/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.6933 - acc: 0.4796 - val_loss: 0.6932 - val_acc: 0.4819
# Epoch 18/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.6932 - acc: 0.4796 - val_loss: 0.6932 - val_acc: 0.4819
# Epoch 19/60
# 9600/9600 [==============================] - 0s 27us/step - loss: 0.6932 - acc: 0.4796 - val_loss: 0.6932 - val_acc: 0.4819
# Epoch 20/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.6932 - acc: 0.4797 - val_loss: 0.6932 - val_acc: 0.4819
# Epoch 21/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6932 - acc: 0.4797 - val_loss: 0.6932 - val_acc: 0.4819
# Epoch 22/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6932 - acc: 0.4796 - val_loss: 0.6932 - val_acc: 0.4819
# Epoch 23/60
# 9600/9600 [==============================] - 0s 27us/step - loss: 0.6932 - acc: 0.4799 - val_loss: 0.6932 - val_acc: 0.4819
# Epoch 24/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6932 - acc: 0.4800 - val_loss: 0.6932 - val_acc: 0.4819
# Epoch 25/60
# 9600/9600 [==============================] - ETA: 0s - loss: 0.6932 - acc: 0.481 - 0s 25us/step - loss: 0.6932 - acc: 0.4810 - val_loss: 0.6932 - val_acc: 0.4819
# Epoch 26/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6932 - acc: 0.4808 - val_loss: 0.6932 - val_acc: 0.4819
# Epoch 27/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.6932 - acc: 0.4821 - val_loss: 0.6932 - val_acc: 0.4819
# Epoch 28/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.6932 - acc: 0.4850 - val_loss: 0.6931 - val_acc: 0.4819
# Epoch 29/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6931 - acc: 0.4867 - val_loss: 0.6931 - val_acc: 0.4819
# Epoch 30/60
# 9600/9600 [==============================] - ETA: 0s - loss: 0.6932 - acc: 0.490 - 0s 26us/step - loss: 0.6931 - acc: 0.4912 - val_loss: 0.6931 - val_acc: 0.4819
# Epoch 31/60
# 9600/9600 [==============================] - ETA: 0s - loss: 0.6931 - acc: 0.497 - 0s 25us/step - loss: 0.6931 - acc: 0.4973 - val_loss: 0.6931 - val_acc: 0.4819
# Epoch 32/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.6931 - acc: 0.5016 - val_loss: 0.6931 - val_acc: 0.4825
# Epoch 33/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6931 - acc: 0.5106 - val_loss: 0.6931 - val_acc: 0.4844
# Epoch 34/60
# 9600/9600 [==============================] - ETA: 0s - loss: 0.6931 - acc: 0.515 - 0s 26us/step - loss: 0.6931 - acc: 0.5152 - val_loss: 0.6931 - val_acc: 0.4906
# Epoch 35/60
# 9600/9600 [==============================] - ETA: 0s - loss: 0.6931 - acc: 0.522 - 0s 26us/step - loss: 0.6931 - acc: 0.5242 - val_loss: 0.6931 - val_acc: 0.5216
# Epoch 36/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6931 - acc: 0.5470 - val_loss: 0.6931 - val_acc: 0.5775
# Epoch 37/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.6931 - acc: 0.5643 - val_loss: 0.6931 - val_acc: 0.6578
# Epoch 38/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6931 - acc: 0.5530 - val_loss: 0.6931 - val_acc: 0.5950
# Epoch 39/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6930 - acc: 0.5436 - val_loss: 0.6930 - val_acc: 0.5181
# Epoch 40/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6930 - acc: 0.5453 - val_loss: 0.6929 - val_acc: 0.5181
# Epoch 41/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6927 - acc: 0.5221 - val_loss: 0.6923 - val_acc: 0.5181
# Epoch 42/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.6810 - acc: 0.5204 - val_loss: 0.6836 - val_acc: 0.5181
# Epoch 43/60
# 9600/9600 [==============================] - 0s 27us/step - loss: 0.6667 - acc: 0.5253 - val_loss: 0.7609 - val_acc: 0.5181
# Epoch 44/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6896 - acc: 0.5800 - val_loss: 0.6410 - val_acc: 0.5181
# Epoch 45/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.6616 - acc: 0.5614 - val_loss: 0.6774 - val_acc: 0.6888
# Epoch 46/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.6537 - acc: 0.6017 - val_loss: 0.5906 - val_acc: 0.7303
# Epoch 47/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.6300 - acc: 0.6719 - val_loss: 0.5653 - val_acc: 0.7231
# Epoch 48/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.5992 - acc: 0.7027 - val_loss: 0.5884 - val_acc: 0.6903
# Epoch 49/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.5773 - acc: 0.7184 - val_loss: 0.5386 - val_acc: 0.7481
# Epoch 50/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.5672 - acc: 0.7276 - val_loss: 0.6210 - val_acc: 0.6372
# Epoch 51/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.5550 - acc: 0.7326 - val_loss: 0.5268 - val_acc: 0.7634
# Epoch 52/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.5443 - acc: 0.7425 - val_loss: 0.5087 - val_acc: 0.7687
# Epoch 53/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.5379 - acc: 0.7452 - val_loss: 0.5071 - val_acc: 0.7800
# Epoch 54/60
# 9600/9600 [==============================] - 0s 28us/step - loss: 0.5310 - acc: 0.7542 - val_loss: 0.5899 - val_acc: 0.6906
# Epoch 55/60
# 9600/9600 [==============================] - 0s 28us/step - loss: 0.5238 - acc: 0.7583 - val_loss: 0.5555 - val_acc: 0.7200
# Epoch 56/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.5303 - acc: 0.7508 - val_loss: 0.4925 - val_acc: 0.7819
# Epoch 57/60
# 9600/9600 [==============================] - 0s 29us/step - loss: 0.5231 - acc: 0.7578 - val_loss: 0.5205 - val_acc: 0.7662
# Epoch 58/60
# 9600/9600 [==============================] - 0s 26us/step - loss: 0.5210 - acc: 0.7572 - val_loss: 0.4972 - val_acc: 0.7622
# Epoch 59/60
# 9600/9600 [==============================] - 0s 24us/step - loss: 0.5123 - acc: 0.7628 - val_loss: 0.5114 - val_acc: 0.7563
# Epoch 60/60
# 9600/9600 [==============================] - 0s 25us/step - loss: 0.5120 - acc: 0.7656 - val_loss: 0.4816 - val_acc: 0.7850
# 3200/3200 [==============================] - 0s 17us/step

# %%
acc_neurone_kfold, f1_neurone_kfold = Neurone_KFold(Galaxies, 3)
# Out:
# Train on 8532 samples, validate on 4266 samples
# Epoch 1/60
# 8532/8532 [==============================] - 1s 136us/step - loss: 0.6532 - acc: 0.6455 - val_loss: 0.6984 - val_acc: 0.5178
# Epoch 2/60
# 8532/8532 [==============================] - 0s 29us/step - loss: 0.6276 - acc: 0.7077 - val_loss: 0.7062 - val_acc: 0.5178
# Epoch 3/60
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.6096 - acc: 0.7335 - val_loss: 0.7157 - val_acc: 0.5178
# Epoch 4/60
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5964 - acc: 0.7462 - val_loss: 0.7259 - val_acc: 0.5178
# Epoch 5/60
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5871 - acc: 0.7534 - val_loss: 0.7367 - val_acc: 0.5178
# Epoch 6/60
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5794 - acc: 0.7568 - val_loss: 0.7471 - val_acc: 0.5178
# Epoch 7/60
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5746 - acc: 0.7580 - val_loss: 0.7570 - val_acc: 0.5178
# Epoch 8/60
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5697 - acc: 0.7597 - val_loss: 0.7661 - val_acc: 0.5178
# Epoch 9/60
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5687 - acc: 0.7608 - val_loss: 0.7742 - val_acc: 0.5178
# Epoch 10/60
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5628 - acc: 0.7605 - val_loss: 0.7818 - val_acc: 0.5178
# Epoch 11/60
# 8532/8532 [==============================] - 0s 28us/step - loss: 0.5633 - acc: 0.7598 - val_loss: 0.7887 - val_acc: 0.5178
# Epoch 12/60
# 8532/8532 [==============================] - 0s 28us/step - loss: 0.5621 - acc: 0.7607 - val_loss: 0.7948 - val_acc: 0.5178
# Epoch 13/60
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5598 - acc: 0.7608 - val_loss: 0.8002 - val_acc: 0.5178
# Epoch 14/60
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5611 - acc: 0.7610 - val_loss: 0.8047 - val_acc: 0.5178
# Epoch 15/60
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5617 - acc: 0.7608 - val_loss: 0.8088 - val_acc: 0.5178
# Epoch 16/60
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5625 - acc: 0.7610 - val_loss: 0.8122 - val_acc: 0.5178
# Epoch 17/60
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5599 - acc: 0.7611 - val_loss: 0.8154 - val_acc: 0.5178
# Epoch 18/60
# 8532/8532 [==============================] - 0s 30us/step - loss: 0.5598 - acc: 0.7610 - val_loss: 0.8178 - val_acc: 0.5178
# Epoch 19/60
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5610 - acc: 0.7610 - val_loss: 0.8201 - val_acc: 0.5178
# Epoch 20/60
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5629 - acc: 0.7611 - val_loss: 0.8222 - val_acc: 0.5178
# Epoch 21/60
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5579 - acc: 0.7611 - val_loss: 0.8240 - val_acc: 0.5178
# Epoch 22/60
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5590 - acc: 0.7610 - val_loss: 0.8255 - val_acc: 0.5178
# Epoch 23/60
# 8532/8532 [==============================] - 0s 28us/step - loss: 0.5565 - acc: 0.7613 - val_loss: 0.8269 - val_acc: 0.5178
# Epoch 24/60
# 8532/8532 [==============================] - 0s 28us/step - loss: 0.5581 - acc: 0.7611 - val_loss: 0.8277 - val_acc: 0.5178
# Epoch 25/60
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5601 - acc: 0.7611 - val_loss: 0.8284 - val_acc: 0.5178
# Epoch 26/60
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5604 - acc: 0.7608 - val_loss: 0.8293 - val_acc: 0.5178
# Epoch 27/60
# 8532/8532 [==============================] - 0s 30us/step - loss: 0.5608 - acc: 0.7611 - val_loss: 0.8299 - val_acc: 0.5178
# Epoch 28/60
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5607 - acc: 0.7610 - val_loss: 0.8303 - val_acc: 0.5178
# Epoch 29/60
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5585 - acc: 0.7613 - val_loss: 0.8308 - val_acc: 0.5178
# Epoch 30/60
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5581 - acc: 0.7611 - val_loss: 0.8316 - val_acc: 0.5178
# Epoch 31/60
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5591 - acc: 0.7611 - val_loss: 0.8322 - val_acc: 0.5178
# Epoch 32/60
# 8532/8532 [==============================] - 0s 28us/step - loss: 0.5581 - acc: 0.7610 - val_loss: 0.8323 - val_acc: 0.5178
# Epoch 33/60
# 8532/8532 [==============================] - 0s 29us/step - loss: 0.5571 - acc: 0.7611 - val_loss: 0.8325 - val_acc: 0.5178
# Epoch 34/60
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5577 - acc: 0.7610 - val_loss: 0.8326 - val_acc: 0.5178
# Epoch 35/60
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5576 - acc: 0.7611 - val_loss: 0.8324 - val_acc: 0.5178
# Epoch 36/60
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5573 - acc: 0.7611 - val_loss: 0.8326 - val_acc: 0.5178
# Epoch 37/60
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5629 - acc: 0.7610 - val_loss: 0.8329 - val_acc: 0.5178
# Epoch 38/60
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5567 - acc: 0.7613 - val_loss: 0.8329 - val_acc: 0.5178
# Epoch 39/60
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5581 - acc: 0.7611 - val_loss: 0.8331 - val_acc: 0.5178
# Epoch 40/60
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5602 - acc: 0.7613 - val_loss: 0.8330 - val_acc: 0.5178
# Epoch 41/60
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5591 - acc: 0.7611 - val_loss: 0.8334 - val_acc: 0.5178
# Epoch 42/60
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5588 - acc: 0.7610 - val_loss: 0.8335 - val_acc: 0.5178
# Epoch 43/60
# 8532/8532 [==============================] - 0s 31us/step - loss: 0.5576 - acc: 0.7611 - val_loss: 0.8335 - val_acc: 0.5178
# Epoch 44/60
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5603 - acc: 0.7611 - val_loss: 0.8335 - val_acc: 0.5178
# Epoch 45/60
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5606 - acc: 0.7611 - val_loss: 0.8338 - val_acc: 0.5178
# Epoch 46/60
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5557 - acc: 0.7611 - val_loss: 0.8336 - val_acc: 0.5178
# Epoch 47/60
# 8532/8532 [==============================] - 0s 25us/step - loss: 0.5582 - acc: 0.7611 - val_loss: 0.8337 - val_acc: 0.5178
# Epoch 48/60
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5594 - acc: 0.7611 - val_loss: 0.8332 - val_acc: 0.5178
# Epoch 49/60
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5582 - acc: 0.7611 - val_loss: 0.8335 - val_acc: 0.5178
# Epoch 50/60
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5566 - acc: 0.7611 - val_loss: 0.8336 - val_acc: 0.5178
# Epoch 51/60
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5570 - acc: 0.7611 - val_loss: 0.8337 - val_acc: 0.5178
# Epoch 52/60
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5607 - acc: 0.7611 - val_loss: 0.8336 - val_acc: 0.5178
# Epoch 53/60
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5565 - acc: 0.7610 - val_loss: 0.8337 - val_acc: 0.5178
# Epoch 54/60
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5577 - acc: 0.7613 - val_loss: 0.8339 - val_acc: 0.5178
# Epoch 55/60
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5612 - acc: 0.7611 - val_loss: 0.8336 - val_acc: 0.5178
# Epoch 56/60
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5557 - acc: 0.7611 - val_loss: 0.8337 - val_acc: 0.5178
# Epoch 57/60
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5577 - acc: 0.7611 - val_loss: 0.8333 - val_acc: 0.5178
# Epoch 58/60
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5568 - acc: 0.7611 - val_loss: 0.8334 - val_acc: 0.5178
# Epoch 59/60
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5578 - acc: 0.7611 - val_loss: 0.8334 - val_acc: 0.5178
# Epoch 60/60
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5597 - acc: 0.7611 - val_loss: 0.8335 - val_acc: 0.5178
# 3200/3200 [==============================] - 0s 20us/step
# Train on 8532 samples, validate on 4266 samples
# Epoch 1/60
# 8532/8532 [==============================] - 1s 126us/step - loss: 1.0321 - acc: 0.2405 - val_loss: 0.7861 - val_acc: 0.4822
# Epoch 2/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.9472 - acc: 0.2477 - val_loss: 0.7516 - val_acc: 0.4822
# Epoch 3/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.8781 - acc: 0.2589 - val_loss: 0.7285 - val_acc: 0.4822
# Epoch 4/60
# 8532/8532 [==============================] - 0s 19us/step - loss: 0.8260 - acc: 0.2819 - val_loss: 0.7132 - val_acc: 0.4822
# Epoch 5/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.7812 - acc: 0.3200 - val_loss: 0.7033 - val_acc: 0.4822
# Epoch 6/60
# 8532/8532 [==============================] - 0s 17us/step - loss: 0.7489 - acc: 0.3805 - val_loss: 0.6972 - val_acc: 0.4822
# Epoch 7/60
# 8532/8532 [==============================] - 0s 22us/step - loss: 0.7218 - acc: 0.4422 - val_loss: 0.6938 - val_acc: 0.4822
# Epoch 8/60
# 8532/8532 [==============================] - 0s 22us/step - loss: 0.6973 - acc: 0.5104 - val_loss: 0.6926 - val_acc: 0.5178
# Epoch 9/60
# 8532/8532 [==============================] - 0s 17us/step - loss: 0.6783 - acc: 0.5749 - val_loss: 0.6930 - val_acc: 0.5178
# Epoch 10/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.6615 - acc: 0.6200 - val_loss: 0.6946 - val_acc: 0.5178
# Epoch 11/60
# 8532/8532 [==============================] - 0s 19us/step - loss: 0.6431 - acc: 0.6737 - val_loss: 0.6973 - val_acc: 0.5178
# Epoch 12/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.6342 - acc: 0.6935 - val_loss: 0.7008 - val_acc: 0.5178
# Epoch 13/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.6224 - acc: 0.7185 - val_loss: 0.7050 - val_acc: 0.5178
# Epoch 14/60
# 8532/8532 [==============================] - 0s 16us/step - loss: 0.6153 - acc: 0.7264 - val_loss: 0.7096 - val_acc: 0.5178
# Epoch 15/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.6056 - acc: 0.7395 - val_loss: 0.7146 - val_acc: 0.5178
# Epoch 16/60
# 8532/8532 [==============================] - 0s 21us/step - loss: 0.5983 - acc: 0.7454 - val_loss: 0.7200 - val_acc: 0.5178
# Epoch 17/60
# 8532/8532 [==============================] - 0s 19us/step - loss: 0.5951 - acc: 0.7489 - val_loss: 0.7254 - val_acc: 0.5178
# Epoch 18/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.5870 - acc: 0.7536 - val_loss: 0.7308 - val_acc: 0.5178
# Epoch 19/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.5846 - acc: 0.7541 - val_loss: 0.7364 - val_acc: 0.5178
# Epoch 20/60
# 8532/8532 [==============================] - 0s 17us/step - loss: 0.5794 - acc: 0.7577 - val_loss: 0.7418 - val_acc: 0.5178
# Epoch 21/60
# 8532/8532 [==============================] - ETA: 0s - loss: 0.5764 - acc: 0.755 - 0s 18us/step - loss: 0.5751 - acc: 0.7564 - val_loss: 0.7473 - val_acc: 0.5178
# Epoch 22/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.5714 - acc: 0.7576 - val_loss: 0.7526 - val_acc: 0.5178
# Epoch 23/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.5720 - acc: 0.7589 - val_loss: 0.7577 - val_acc: 0.5178
# Epoch 24/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.5718 - acc: 0.7596 - val_loss: 0.7625 - val_acc: 0.5178
# Epoch 25/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.5698 - acc: 0.7602 - val_loss: 0.7672 - val_acc: 0.5178
# Epoch 26/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.5658 - acc: 0.7607 - val_loss: 0.7716 - val_acc: 0.5178
# Epoch 27/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.5659 - acc: 0.7605 - val_loss: 0.7758 - val_acc: 0.5178
# Epoch 28/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.5636 - acc: 0.7603 - val_loss: 0.7798 - val_acc: 0.5178
# Epoch 29/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.5674 - acc: 0.7604 - val_loss: 0.7837 - val_acc: 0.5178
# Epoch 30/60
# 8532/8532 [==============================] - ETA: 0s - loss: 0.5628 - acc: 0.760 - 0s 18us/step - loss: 0.5629 - acc: 0.7603 - val_loss: 0.7871 - val_acc: 0.5178
# Epoch 31/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.5639 - acc: 0.7605 - val_loss: 0.7904 - val_acc: 0.5178
# Epoch 32/60
# 8532/8532 [==============================] - 0s 17us/step - loss: 0.5629 - acc: 0.7610 - val_loss: 0.7932 - val_acc: 0.5178
# Epoch 33/60
# 8532/8532 [==============================] - 0s 23us/step - loss: 0.5638 - acc: 0.7604 - val_loss: 0.7961 - val_acc: 0.5178
# Epoch 34/60
# 8532/8532 [==============================] - 0s 16us/step - loss: 0.5616 - acc: 0.7613 - val_loss: 0.7987 - val_acc: 0.5178
# Epoch 35/60
# 8532/8532 [==============================] - 0s 16us/step - loss: 0.5610 - acc: 0.7614 - val_loss: 0.8013 - val_acc: 0.5178
# Epoch 36/60
# 8532/8532 [==============================] - 0s 16us/step - loss: 0.5615 - acc: 0.7610 - val_loss: 0.8037 - val_acc: 0.5178
# Epoch 37/60
# 8532/8532 [==============================] - ETA: 0s - loss: 0.5590 - acc: 0.764 - 0s 21us/step - loss: 0.5607 - acc: 0.7611 - val_loss: 0.8058 - val_acc: 0.5178
# Epoch 38/60
# 8532/8532 [==============================] - 0s 19us/step - loss: 0.5610 - acc: 0.7610 - val_loss: 0.8079 - val_acc: 0.5178
# Epoch 39/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.5616 - acc: 0.7613 - val_loss: 0.8098 - val_acc: 0.5178
# Epoch 40/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.5595 - acc: 0.7608 - val_loss: 0.8115 - val_acc: 0.5178
# Epoch 41/60
# 8532/8532 [==============================] - 0s 16us/step - loss: 0.5575 - acc: 0.7611 - val_loss: 0.8129 - val_acc: 0.5178
# Epoch 42/60
# 8532/8532 [==============================] - 0s 19us/step - loss: 0.5588 - acc: 0.7611 - val_loss: 0.8145 - val_acc: 0.5178
# Epoch 43/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.5626 - acc: 0.7608 - val_loss: 0.8158 - val_acc: 0.5178
# Epoch 44/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.5596 - acc: 0.7608 - val_loss: 0.8172 - val_acc: 0.5178
# Epoch 45/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.5614 - acc: 0.7611 - val_loss: 0.8184 - val_acc: 0.5178
# Epoch 46/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.5598 - acc: 0.7610 - val_loss: 0.8194 - val_acc: 0.5178
# Epoch 47/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.5623 - acc: 0.7609 - val_loss: 0.8204 - val_acc: 0.5178
# Epoch 48/60
# 8532/8532 [==============================] - 0s 17us/step - loss: 0.5598 - acc: 0.7611 - val_loss: 0.8212 - val_acc: 0.5178
# Epoch 49/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.5591 - acc: 0.7610 - val_loss: 0.8221 - val_acc: 0.5178
# Epoch 50/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.5607 - acc: 0.7610 - val_loss: 0.8229 - val_acc: 0.5178
# Epoch 51/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.5620 - acc: 0.7610 - val_loss: 0.8236 - val_acc: 0.5178
# Epoch 52/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.5601 - acc: 0.7609 - val_loss: 0.8242 - val_acc: 0.5178
# Epoch 53/60
# 8532/8532 [==============================] - 0s 17us/step - loss: 0.5609 - acc: 0.7610 - val_loss: 0.8246 - val_acc: 0.5178
# Epoch 54/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.5595 - acc: 0.7605 - val_loss: 0.8251 - val_acc: 0.5178
# Epoch 55/60
# 8532/8532 [==============================] - 0s 17us/step - loss: 0.5581 - acc: 0.7608 - val_loss: 0.8256 - val_acc: 0.5178
# Epoch 56/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.5578 - acc: 0.7610 - val_loss: 0.8260 - val_acc: 0.5178
# Epoch 57/60
# 8532/8532 [==============================] - 0s 22us/step - loss: 0.5586 - acc: 0.7610 - val_loss: 0.8264 - val_acc: 0.5178
# Epoch 58/60
# 8532/8532 [==============================] - 0s 19us/step - loss: 0.5567 - acc: 0.7609 - val_loss: 0.8269 - val_acc: 0.5178
# Epoch 59/60
# 8532/8532 [==============================] - ETA: 0s - loss: 0.5604 - acc: 0.760 - 0s 16us/step - loss: 0.5596 - acc: 0.7609 - val_loss: 0.8273 - val_acc: 0.5178
# Epoch 60/60
# 8532/8532 [==============================] - 0s 18us/step - loss: 0.5578 - acc: 0.7610 - val_loss: 0.8276 - val_acc: 0.5178
# 3200/3200 [==============================] - 0s 15us/step
# Train on 8532 samples, validate on 4266 samples
# Epoch 1/60
# 8532/8532 [==============================] - 1s 166us/step - loss: 0.8564 - acc: 0.2835 - val_loss: 0.6976 - val_acc: 0.4822
# Epoch 2/60
# 8532/8532 [==============================] - 0s 58us/step - loss: 0.6791 - acc: 0.5643 - val_loss: 0.6990 - val_acc: 0.5178
# Epoch 3/60
# 8532/8532 [==============================] - 0s 51us/step - loss: 0.6115 - acc: 0.7343 - val_loss: 0.7251 - val_acc: 0.5178
# Epoch 4/60
# 8532/8532 [==============================] - 1s 62us/step - loss: 0.5819 - acc: 0.7569 - val_loss: 0.7547 - val_acc: 0.5178
# Epoch 5/60
# 8532/8532 [==============================] - 0s 54us/step - loss: 0.5687 - acc: 0.7613 - val_loss: 0.7804 - val_acc: 0.5178
# Epoch 6/60
# 8532/8532 [==============================] - 0s 50us/step - loss: 0.5635 - acc: 0.7609 - val_loss: 0.7985 - val_acc: 0.5178
# Epoch 7/60
# 8532/8532 [==============================] - 0s 51us/step - loss: 0.5612 - acc: 0.7610 - val_loss: 0.8113 - val_acc: 0.5178
# Epoch 8/60
# 8532/8532 [==============================] - 0s 51us/step - loss: 0.5588 - acc: 0.7611 - val_loss: 0.8195 - val_acc: 0.5178
# Epoch 9/60
# 8532/8532 [==============================] - 0s 51us/step - loss: 0.5602 - acc: 0.7611 - val_loss: 0.8243 - val_acc: 0.5178
# Epoch 10/60
# 8532/8532 [==============================] - 0s 52us/step - loss: 0.5595 - acc: 0.7611 - val_loss: 0.8279 - val_acc: 0.5178
# Epoch 11/60
# 8532/8532 [==============================] - 0s 52us/step - loss: 0.5591 - acc: 0.7610 - val_loss: 0.8310 - val_acc: 0.5178
# Epoch 12/60
# 8532/8532 [==============================] - 0s 56us/step - loss: 0.5621 - acc: 0.7611 - val_loss: 0.8330 - val_acc: 0.5178
# Epoch 13/60
# 8532/8532 [==============================] - 0s 53us/step - loss: 0.5572 - acc: 0.7610 - val_loss: 0.8344 - val_acc: 0.5178
# Epoch 14/60
# 8532/8532 [==============================] - 0s 53us/step - loss: 0.5574 - acc: 0.7611 - val_loss: 0.8349 - val_acc: 0.5178
# Epoch 15/60
# 8532/8532 [==============================] - 0s 52us/step - loss: 0.5588 - acc: 0.7610 - val_loss: 0.8350 - val_acc: 0.5178
# Epoch 16/60
# 8532/8532 [==============================] - 0s 51us/step - loss: 0.5570 - acc: 0.7611 - val_loss: 0.8358 - val_acc: 0.5178
# Epoch 17/60
# 8532/8532 [==============================] - 0s 56us/step - loss: 0.5606 - acc: 0.7611 - val_loss: 0.8349 - val_acc: 0.5178
# Epoch 18/60
# 8532/8532 [==============================] - 0s 51us/step - loss: 0.5599 - acc: 0.7613 - val_loss: 0.8346 - val_acc: 0.5178
# Epoch 19/60
# 8532/8532 [==============================] - 0s 52us/step - loss: 0.5565 - acc: 0.7610 - val_loss: 0.8345 - val_acc: 0.5178
# Epoch 20/60
# 8532/8532 [==============================] - 0s 52us/step - loss: 0.5591 - acc: 0.7611 - val_loss: 0.8352 - val_acc: 0.5178
# Epoch 21/60
# 8532/8532 [==============================] - 0s 54us/step - loss: 0.5587 - acc: 0.7611 - val_loss: 0.8338 - val_acc: 0.5178
# Epoch 22/60
# 8532/8532 [==============================] - 0s 53us/step - loss: 0.5600 - acc: 0.7611 - val_loss: 0.8345 - val_acc: 0.5178
# Epoch 23/60
# 8532/8532 [==============================] - 0s 51us/step - loss: 0.5586 - acc: 0.7610 - val_loss: 0.8337 - val_acc: 0.5178
# Epoch 24/60
# 8532/8532 [==============================] - 0s 51us/step - loss: 0.5582 - acc: 0.7611 - val_loss: 0.8345 - val_acc: 0.5178
# Epoch 25/60
# 8532/8532 [==============================] - 0s 53us/step - loss: 0.5581 - acc: 0.7611 - val_loss: 0.8344 - val_acc: 0.5178
# Epoch 26/60
# 8532/8532 [==============================] - 0s 51us/step - loss: 0.5597 - acc: 0.7611 - val_loss: 0.8342 - val_acc: 0.5178
# Epoch 27/60
# 8532/8532 [==============================] - 0s 53us/step - loss: 0.5599 - acc: 0.7611 - val_loss: 0.8347 - val_acc: 0.5178
# Epoch 28/60
# 8532/8532 [==============================] - 0s 51us/step - loss: 0.5571 - acc: 0.7611 - val_loss: 0.8344 - val_acc: 0.5178
# Epoch 29/60
# 8532/8532 [==============================] - 0s 53us/step - loss: 0.5571 - acc: 0.7611 - val_loss: 0.8351 - val_acc: 0.5178
# Epoch 30/60
# 8532/8532 [==============================] - 0s 53us/step - loss: 0.5584 - acc: 0.7611 - val_loss: 0.8350 - val_acc: 0.5178
# Epoch 31/60
# 8532/8532 [==============================] - 0s 54us/step - loss: 0.5587 - acc: 0.7611 - val_loss: 0.8340 - val_acc: 0.5178
# Epoch 32/60
# 8532/8532 [==============================] - 0s 51us/step - loss: 0.5564 - acc: 0.7611 - val_loss: 0.8330 - val_acc: 0.5178
# Epoch 33/60
# 8532/8532 [==============================] - 0s 57us/step - loss: 0.5582 - acc: 0.7611 - val_loss: 0.8337 - val_acc: 0.5178
# Epoch 34/60
# 8532/8532 [==============================] - 0s 50us/step - loss: 0.5576 - acc: 0.7611 - val_loss: 0.8332 - val_acc: 0.5178
# Epoch 35/60
# 8532/8532 [==============================] - 0s 51us/step - loss: 0.5582 - acc: 0.7611 - val_loss: 0.8329 - val_acc: 0.5178
# Epoch 36/60
# 8532/8532 [==============================] - 0s 54us/step - loss: 0.5577 - acc: 0.7611 - val_loss: 0.8334 - val_acc: 0.5178
# Epoch 37/60
# 8532/8532 [==============================] - 0s 53us/step - loss: 0.5568 - acc: 0.7611 - val_loss: 0.8332 - val_acc: 0.5178
# Epoch 38/60
# 8532/8532 [==============================] - 0s 55us/step - loss: 0.5574 - acc: 0.7611 - val_loss: 0.8331 - val_acc: 0.5178
# Epoch 39/60
# 8532/8532 [==============================] - 0s 55us/step - loss: 0.5593 - acc: 0.7611 - val_loss: 0.8332 - val_acc: 0.5178
# Epoch 40/60
# 8532/8532 [==============================] - 0s 49us/step - loss: 0.5571 - acc: 0.7611 - val_loss: 0.8330 - val_acc: 0.5178
# Epoch 41/60
# 8532/8532 [==============================] - 0s 55us/step - loss: 0.5610 - acc: 0.7611 - val_loss: 0.8317 - val_acc: 0.5178
# Epoch 42/60
# 8532/8532 [==============================] - 0s 52us/step - loss: 0.5586 - acc: 0.7611 - val_loss: 0.8331 - val_acc: 0.5178
# Epoch 43/60
# 8532/8532 [==============================] - 0s 52us/step - loss: 0.5586 - acc: 0.7611 - val_loss: 0.8335 - val_acc: 0.5178
# Epoch 44/60
# 8532/8532 [==============================] - 0s 55us/step - loss: 0.5600 - acc: 0.7611 - val_loss: 0.8338 - val_acc: 0.5178
# Epoch 45/60
# 8532/8532 [==============================] - 0s 50us/step - loss: 0.5589 - acc: 0.7611 - val_loss: 0.8336 - val_acc: 0.5178
# Epoch 46/60
# 8532/8532 [==============================] - 0s 50us/step - loss: 0.5559 - acc: 0.7611 - val_loss: 0.8333 - val_acc: 0.5178
# Epoch 47/60
# 8532/8532 [==============================] - 0s 50us/step - loss: 0.5548 - acc: 0.7611 - val_loss: 0.8344 - val_acc: 0.5178
# Epoch 48/60
# 8532/8532 [==============================] - 0s 51us/step - loss: 0.5570 - acc: 0.7611 - val_loss: 0.8346 - val_acc: 0.5178
# Epoch 49/60
# 8532/8532 [==============================] - 0s 53us/step - loss: 0.5588 - acc: 0.7611 - val_loss: 0.8341 - val_acc: 0.5178
# Epoch 50/60
# 8532/8532 [==============================] - 0s 51us/step - loss: 0.5582 - acc: 0.7611 - val_loss: 0.8345 - val_acc: 0.5178
# Epoch 51/60
# 8532/8532 [==============================] - 0s 50us/step - loss: 0.5591 - acc: 0.7611 - val_loss: 0.8335 - val_acc: 0.5178
# Epoch 52/60
# 8532/8532 [==============================] - 0s 54us/step - loss: 0.5580 - acc: 0.7611 - val_loss: 0.8330 - val_acc: 0.5178
# Epoch 53/60
# 8532/8532 [==============================] - 0s 53us/step - loss: 0.5572 - acc: 0.7611 - val_loss: 0.8331 - val_acc: 0.5178
# Epoch 54/60
# 8532/8532 [==============================] - 0s 55us/step - loss: 0.5572 - acc: 0.7611 - val_loss: 0.8334 - val_acc: 0.5178
# Epoch 55/60
# 8532/8532 [==============================] - 0s 55us/step - loss: 0.5579 - acc: 0.7611 - val_loss: 0.8326 - val_acc: 0.5178
# Epoch 56/60
# 8532/8532 [==============================] - 0s 53us/step - loss: 0.5580 - acc: 0.7611 - val_loss: 0.8327 - val_acc: 0.5178
# Epoch 57/60
# 8532/8532 [==============================] - 0s 50us/step - loss: 0.5575 - acc: 0.7611 - val_loss: 0.8333 - val_acc: 0.5178
# Epoch 58/60
# 8532/8532 [==============================] - 0s 53us/step - loss: 0.5572 - acc: 0.7611 - val_loss: 0.8334 - val_acc: 0.5178
# Epoch 59/60
# 8532/8532 [==============================] - 0s 52us/step - loss: 0.5573 - acc: 0.7611 - val_loss: 0.8338 - val_acc: 0.5178
# Epoch 60/60
# 8532/8532 [==============================] - 0s 50us/step - loss: 0.5571 - acc: 0.7611 - val_loss: 0.8332 - val_acc: 0.5178
# 3200/3200 [==============================] - 0s 34us/step
# Train on 8532 samples, validate on 4266 samples
# Epoch 1/60
# 8532/8532 [==============================] - 2s 235us/step - loss: 0.6229 - acc: 0.7030 - val_loss: 0.7360 - val_acc: 0.5178
# Epoch 2/60
# 8532/8532 [==============================] - 1s 113us/step - loss: 0.5713 - acc: 0.7597 - val_loss: 0.7843 - val_acc: 0.5178
# Epoch 3/60
# 8532/8532 [==============================] - 1s 112us/step - loss: 0.5582 - acc: 0.7608 - val_loss: 0.8121 - val_acc: 0.5178
# Epoch 4/60
# 8532/8532 [==============================] - 1s 113us/step - loss: 0.5580 - acc: 0.7611 - val_loss: 0.8249 - val_acc: 0.5178
# Epoch 5/60
# 8532/8532 [==============================] - 1s 112us/step - loss: 0.5592 - acc: 0.7610 - val_loss: 0.8282 - val_acc: 0.5178
# Epoch 6/60
# 8532/8532 [==============================] - 1s 112us/step - loss: 0.5593 - acc: 0.7611 - val_loss: 0.8306 - val_acc: 0.5178
# Epoch 7/60
# 8532/8532 [==============================] - 1s 110us/step - loss: 0.5565 - acc: 0.7610 - val_loss: 0.8333 - val_acc: 0.5178
# Epoch 8/60
# 8532/8532 [==============================] - 1s 112us/step - loss: 0.5559 - acc: 0.7611 - val_loss: 0.8337 - val_acc: 0.5178
# Epoch 9/60
# 8532/8532 [==============================] - 1s 110us/step - loss: 0.5570 - acc: 0.7611 - val_loss: 0.8337 - val_acc: 0.5178
# Epoch 10/60
# 8532/8532 [==============================] - 1s 110us/step - loss: 0.5583 - acc: 0.7610 - val_loss: 0.8341 - val_acc: 0.5178
# Epoch 11/60
# 8532/8532 [==============================] - 1s 112us/step - loss: 0.5570 - acc: 0.7613 - val_loss: 0.8340 - val_acc: 0.5178
# Epoch 12/60
# 8532/8532 [==============================] - 1s 112us/step - loss: 0.5581 - acc: 0.7611 - val_loss: 0.8320 - val_acc: 0.5178
# Epoch 13/60
# 8532/8532 [==============================] - 1s 111us/step - loss: 0.5603 - acc: 0.7611 - val_loss: 0.8310 - val_acc: 0.5178
# Epoch 14/60
# 8532/8532 [==============================] - 1s 110us/step - loss: 0.5567 - acc: 0.7611 - val_loss: 0.8327 - val_acc: 0.5178
# Epoch 15/60
# 8532/8532 [==============================] - 1s 111us/step - loss: 0.5585 - acc: 0.7611 - val_loss: 0.8303 - val_acc: 0.5178
# Epoch 16/60
# 8532/8532 [==============================] - 1s 119us/step - loss: 0.5602 - acc: 0.7611 - val_loss: 0.8300 - val_acc: 0.5178
# Epoch 17/60
# 8532/8532 [==============================] - 1s 112us/step - loss: 0.5603 - acc: 0.7611 - val_loss: 0.8328 - val_acc: 0.5178
# Epoch 18/60
# 8532/8532 [==============================] - 1s 110us/step - loss: 0.5579 - acc: 0.7611 - val_loss: 0.8294 - val_acc: 0.5178
# Epoch 19/60
# 8532/8532 [==============================] - 1s 111us/step - loss: 0.5575 - acc: 0.7611 - val_loss: 0.8313 - val_acc: 0.5178
# Epoch 20/60
# 8532/8532 [==============================] - 1s 111us/step - loss: 0.5583 - acc: 0.7611 - val_loss: 0.8297 - val_acc: 0.5178
# Epoch 21/60
# 8532/8532 [==============================] - 1s 111us/step - loss: 0.5567 - acc: 0.7611 - val_loss: 0.8329 - val_acc: 0.5178
# Epoch 22/60
# 8532/8532 [==============================] - 1s 111us/step - loss: 0.5574 - acc: 0.7611 - val_loss: 0.8321 - val_acc: 0.5178
# Epoch 23/60
# 8532/8532 [==============================] - 1s 111us/step - loss: 0.5579 - acc: 0.7611 - val_loss: 0.8316 - val_acc: 0.5178
# Epoch 24/60
# 8532/8532 [==============================] - 1s 111us/step - loss: 0.5587 - acc: 0.7611 - val_loss: 0.8322 - val_acc: 0.5178
# Epoch 25/60
# 8532/8532 [==============================] - 1s 112us/step - loss: 0.5580 - acc: 0.7611 - val_loss: 0.8329 - val_acc: 0.5178
# Epoch 26/60
# 8532/8532 [==============================] - 1s 111us/step - loss: 0.5582 - acc: 0.7611 - val_loss: 0.8329 - val_acc: 0.5178
# Epoch 27/60
# 8532/8532 [==============================] - 1s 112us/step - loss: 0.5576 - acc: 0.7610 - val_loss: 0.8331 - val_acc: 0.5178
# Epoch 28/60
# 8532/8532 [==============================] - 1s 111us/step - loss: 0.5577 - acc: 0.7611 - val_loss: 0.8315 - val_acc: 0.5178
# Epoch 29/60
# 8532/8532 [==============================] - 1s 112us/step - loss: 0.5564 - acc: 0.7611 - val_loss: 0.8302 - val_acc: 0.5178
# Epoch 30/60
# 8532/8532 [==============================] - 1s 112us/step - loss: 0.5585 - acc: 0.7611 - val_loss: 0.8311 - val_acc: 0.5178
# Epoch 31/60
# 8532/8532 [==============================] - 1s 110us/step - loss: 0.5606 - acc: 0.7611 - val_loss: 0.8302 - val_acc: 0.5178
# Epoch 32/60
# 8532/8532 [==============================] - 1s 114us/step - loss: 0.5594 - acc: 0.7611 - val_loss: 0.8286 - val_acc: 0.5178
# Epoch 33/60
# 8532/8532 [==============================] - 1s 116us/step - loss: 0.5582 - acc: 0.7611 - val_loss: 0.8283 - val_acc: 0.5178
# Epoch 34/60
# 8532/8532 [==============================] - 1s 111us/step - loss: 0.5589 - acc: 0.7611 - val_loss: 0.8289 - val_acc: 0.5178
# Epoch 35/60
# 8532/8532 [==============================] - 1s 110us/step - loss: 0.5572 - acc: 0.7611 - val_loss: 0.8310 - val_acc: 0.5178
# Epoch 36/60
# 8532/8532 [==============================] - 1s 111us/step - loss: 0.5564 - acc: 0.7611 - val_loss: 0.8308 - val_acc: 0.5178
# Epoch 37/60
# 8532/8532 [==============================] - 1s 110us/step - loss: 0.5572 - acc: 0.7611 - val_loss: 0.8306 - val_acc: 0.5178
# Epoch 38/60
# 8532/8532 [==============================] - 1s 112us/step - loss: 0.5573 - acc: 0.7611 - val_loss: 0.8298 - val_acc: 0.5178
# Epoch 39/60
# 8532/8532 [==============================] - 1s 111us/step - loss: 0.5576 - acc: 0.7611 - val_loss: 0.8311 - val_acc: 0.5178
# Epoch 40/60
# 8532/8532 [==============================] - 1s 111us/step - loss: 0.5572 - acc: 0.7611 - val_loss: 0.8319 - val_acc: 0.5178
# Epoch 41/60
# 8532/8532 [==============================] - 1s 110us/step - loss: 0.5576 - acc: 0.7611 - val_loss: 0.8286 - val_acc: 0.5178
# Epoch 42/60
# 8532/8532 [==============================] - 1s 111us/step - loss: 0.5580 - acc: 0.7611 - val_loss: 0.8295 - val_acc: 0.5178
# Epoch 43/60
# 8532/8532 [==============================] - 1s 112us/step - loss: 0.5564 - acc: 0.7611 - val_loss: 0.8319 - val_acc: 0.5178
# Epoch 44/60
# 8532/8532 [==============================] - 1s 110us/step - loss: 0.5554 - acc: 0.7611 - val_loss: 0.8309 - val_acc: 0.5178
# Epoch 45/60
# 8532/8532 [==============================] - 1s 110us/step - loss: 0.5574 - acc: 0.7611 - val_loss: 0.8313 - val_acc: 0.5178
# Epoch 46/60
# 8532/8532 [==============================] - 1s 111us/step - loss: 0.5558 - acc: 0.7611 - val_loss: 0.8295 - val_acc: 0.5178
# Epoch 47/60
# 8532/8532 [==============================] - 1s 112us/step - loss: 0.5582 - acc: 0.7611 - val_loss: 0.8294 - val_acc: 0.5178
# Epoch 48/60
# 8532/8532 [==============================] - 1s 112us/step - loss: 0.5572 - acc: 0.7611 - val_loss: 0.8308 - val_acc: 0.5178
# Epoch 49/60
# 8532/8532 [==============================] - 1s 120us/step - loss: 0.5561 - acc: 0.7611 - val_loss: 0.8290 - val_acc: 0.5178
# Epoch 50/60
# 8532/8532 [==============================] - 1s 113us/step - loss: 0.5554 - acc: 0.7611 - val_loss: 0.8315 - val_acc: 0.5178
# Epoch 51/60
# 8532/8532 [==============================] - 1s 111us/step - loss: 0.5557 - acc: 0.7611 - val_loss: 0.8304 - val_acc: 0.5178
# Epoch 52/60
# 8532/8532 [==============================] - 1s 110us/step - loss: 0.5572 - acc: 0.7611 - val_loss: 0.8310 - val_acc: 0.5178
# Epoch 53/60
# 8532/8532 [==============================] - 1s 112us/step - loss: 0.5574 - acc: 0.7611 - val_loss: 0.8290 - val_acc: 0.5178
# Epoch 54/60
# 8532/8532 [==============================] - 1s 112us/step - loss: 0.5577 - acc: 0.7611 - val_loss: 0.8302 - val_acc: 0.5178
# Epoch 55/60
# 8532/8532 [==============================] - 1s 112us/step - loss: 0.5578 - acc: 0.7611 - val_loss: 0.8304 - val_acc: 0.5178
# Epoch 56/60
# 8532/8532 [==============================] - 1s 111us/step - loss: 0.5556 - acc: 0.7611 - val_loss: 0.8320 - val_acc: 0.5178
# Epoch 57/60
# 8532/8532 [==============================] - 1s 112us/step - loss: 0.5555 - acc: 0.7611 - val_loss: 0.8317 - val_acc: 0.5178
# Epoch 58/60
# 8532/8532 [==============================] - 1s 112us/step - loss: 0.5586 - acc: 0.7611 - val_loss: 0.8323 - val_acc: 0.5178
# Epoch 59/60
# 8532/8532 [==============================] - 1s 111us/step - loss: 0.5570 - acc: 0.7611 - val_loss: 0.8306 - val_acc: 0.5178
# Epoch 60/60
# 8532/8532 [==============================] - 1s 112us/step - loss: 0.5579 - acc: 0.7611 - val_loss: 0.8278 - val_acc: 0.5178
# 3200/3200 [==============================] - 0s 61us/step
# Train on 8532 samples, validate on 4266 samples
# Epoch 1/30
# 8532/8532 [==============================] - 1s 142us/step - loss: 0.6296 - acc: 0.7008 - val_loss: 0.7064 - val_acc: 0.5178
# Epoch 2/30
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.6091 - acc: 0.7317 - val_loss: 0.7161 - val_acc: 0.5178
# Epoch 3/30
# 8532/8532 [==============================] - 0s 25us/step - loss: 0.5972 - acc: 0.7473 - val_loss: 0.7266 - val_acc: 0.5178
# Epoch 4/30
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5896 - acc: 0.7504 - val_loss: 0.7374 - val_acc: 0.5178
# Epoch 5/30
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5810 - acc: 0.7567 - val_loss: 0.7478 - val_acc: 0.5178
# Epoch 6/30
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5755 - acc: 0.7590 - val_loss: 0.7575 - val_acc: 0.5178
# Epoch 7/30
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5713 - acc: 0.7587 - val_loss: 0.7664 - val_acc: 0.5178
# Epoch 8/30
# 8532/8532 [==============================] - 0s 28us/step - loss: 0.5682 - acc: 0.7597 - val_loss: 0.7751 - val_acc: 0.5178
# Epoch 9/30
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5653 - acc: 0.7601 - val_loss: 0.7825 - val_acc: 0.5178
# Epoch 10/30
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5647 - acc: 0.7610 - val_loss: 0.7893 - val_acc: 0.5178
# Epoch 11/30
# 8532/8532 [==============================] - 0s 31us/step - loss: 0.5629 - acc: 0.7603 - val_loss: 0.7955 - val_acc: 0.5178
# Epoch 12/30
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5634 - acc: 0.7604 - val_loss: 0.8006 - val_acc: 0.5178
# Epoch 13/30
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5605 - acc: 0.7610 - val_loss: 0.8050 - val_acc: 0.5178
# Epoch 14/30
# 8532/8532 [==============================] - 0s 25us/step - loss: 0.5595 - acc: 0.7608 - val_loss: 0.8092 - val_acc: 0.5178
# Epoch 15/30
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5602 - acc: 0.7610 - val_loss: 0.8130 - val_acc: 0.5178
# Epoch 16/30
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5597 - acc: 0.7611 - val_loss: 0.8158 - val_acc: 0.5178
# Epoch 17/30
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5593 - acc: 0.7611 - val_loss: 0.8185 - val_acc: 0.5178
# Epoch 18/30
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5567 - acc: 0.7610 - val_loss: 0.8211 - val_acc: 0.5178
# Epoch 19/30
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5610 - acc: 0.7610 - val_loss: 0.8232 - val_acc: 0.5178
# Epoch 20/30
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5612 - acc: 0.7613 - val_loss: 0.8250 - val_acc: 0.5178
# Epoch 21/30
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5611 - acc: 0.7610 - val_loss: 0.8264 - val_acc: 0.5178
# Epoch 22/30
# 8532/8532 [==============================] - 0s 25us/step - loss: 0.5579 - acc: 0.7611 - val_loss: 0.8280 - val_acc: 0.5178
# Epoch 23/30
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5592 - acc: 0.7609 - val_loss: 0.8292 - val_acc: 0.5178
# Epoch 24/30
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5585 - acc: 0.7611 - val_loss: 0.8302 - val_acc: 0.5178
# Epoch 25/30
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5579 - acc: 0.7610 - val_loss: 0.8306 - val_acc: 0.5178
# Epoch 26/30
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5599 - acc: 0.7610 - val_loss: 0.8314 - val_acc: 0.5178
# Epoch 27/30
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5609 - acc: 0.7613 - val_loss: 0.8319 - val_acc: 0.5178
# Epoch 28/30
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5598 - acc: 0.7611 - val_loss: 0.8321 - val_acc: 0.5178
# Epoch 29/30
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5555 - acc: 0.7610 - val_loss: 0.8325 - val_acc: 0.5178
# Epoch 30/30
# 8532/8532 [==============================] - 0s 28us/step - loss: 0.5562 - acc: 0.7609 - val_loss: 0.8326 - val_acc: 0.5178
# 3200/3200 [==============================] - 0s 15us/step
# Train on 8532 samples, validate on 4266 samples
# Epoch 1/120
# 8532/8532 [==============================] - 1s 145us/step - loss: 0.8152 - acc: 0.2963 - val_loss: 0.7053 - val_acc: 0.4822
# Epoch 2/120
# 8532/8532 [==============================] - 0s 30us/step - loss: 0.7471 - acc: 0.3903 - val_loss: 0.6947 - val_acc: 0.4822
# Epoch 3/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.6988 - acc: 0.5177 - val_loss: 0.6926 - val_acc: 0.5178
# Epoch 4/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.6647 - acc: 0.6101 - val_loss: 0.6957 - val_acc: 0.5178
# Epoch 5/120
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.6389 - acc: 0.6741 - val_loss: 0.7023 - val_acc: 0.5178
# Epoch 6/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.6185 - acc: 0.7162 - val_loss: 0.7110 - val_acc: 0.5178
# Epoch 7/120
# 8532/8532 [==============================] - 0s 28us/step - loss: 0.6062 - acc: 0.7361 - val_loss: 0.7210 - val_acc: 0.5178
# Epoch 8/120
# 8532/8532 [==============================] - ETA: 0s - loss: 0.5931 - acc: 0.7484- ETA: 0s - loss: 0.5954 - acc: 0.7 - 0s 28us/step - loss: 0.5908 - acc: 0.7508 - val_loss: 0.7314 - val_acc: 0.5178
# Epoch 9/120
# 8532/8532 [==============================] - 0s 29us/step - loss: 0.5833 - acc: 0.7540 - val_loss: 0.7418 - val_acc: 0.5178
# Epoch 10/120
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5765 - acc: 0.7561 - val_loss: 0.7522 - val_acc: 0.5178
# Epoch 11/120
# 8532/8532 [==============================] - 0s 28us/step - loss: 0.5747 - acc: 0.7582 - val_loss: 0.7616 - val_acc: 0.5178
# Epoch 12/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5699 - acc: 0.7591 - val_loss: 0.7703 - val_acc: 0.5178
# Epoch 13/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5679 - acc: 0.7607 - val_loss: 0.7786 - val_acc: 0.5178
# Epoch 14/120
# 8532/8532 [==============================] - 0s 30us/step - loss: 0.5664 - acc: 0.7610 - val_loss: 0.7858 - val_acc: 0.5178
# Epoch 15/120
# 8532/8532 [==============================] - 0s 28us/step - loss: 0.5598 - acc: 0.7609 - val_loss: 0.7921 - val_acc: 0.5178
# Epoch 16/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5639 - acc: 0.7605 - val_loss: 0.7976 - val_acc: 0.5178
# Epoch 17/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5613 - acc: 0.7608 - val_loss: 0.8030 - val_acc: 0.5178
# Epoch 18/120
# 8532/8532 [==============================] - 0s 29us/step - loss: 0.5626 - acc: 0.7609 - val_loss: 0.8072 - val_acc: 0.5178
# Epoch 19/120
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5613 - acc: 0.7614 - val_loss: 0.8107 - val_acc: 0.5178
# Epoch 20/120
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5614 - acc: 0.7609 - val_loss: 0.8142 - val_acc: 0.5178
# Epoch 21/120
# 8532/8532 [==============================] - 0s 29us/step - loss: 0.5629 - acc: 0.7605 - val_loss: 0.8165 - val_acc: 0.5178
# Epoch 22/120
# 8532/8532 [==============================] - 0s 25us/step - loss: 0.5605 - acc: 0.7609 - val_loss: 0.8189 - val_acc: 0.5178
# Epoch 23/120
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5624 - acc: 0.7610 - val_loss: 0.8211 - val_acc: 0.5178
# Epoch 24/120
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5589 - acc: 0.7611 - val_loss: 0.8232 - val_acc: 0.5178
# Epoch 25/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5604 - acc: 0.7613 - val_loss: 0.8247 - val_acc: 0.5178
# Epoch 26/120
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5593 - acc: 0.7613 - val_loss: 0.8261 - val_acc: 0.5178
# Epoch 27/120
# 8532/8532 [==============================] - 0s 31us/step - loss: 0.5617 - acc: 0.7610 - val_loss: 0.8268 - val_acc: 0.5178
# Epoch 28/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5635 - acc: 0.7608 - val_loss: 0.8273 - val_acc: 0.5178
# Epoch 29/120
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5580 - acc: 0.7609 - val_loss: 0.8285 - val_acc: 0.5178
# Epoch 30/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5651 - acc: 0.7610 - val_loss: 0.8286 - val_acc: 0.5178
# Epoch 31/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5611 - acc: 0.7611 - val_loss: 0.8294 - val_acc: 0.5178
# Epoch 32/120
# 8532/8532 [==============================] - 0s 25us/step - loss: 0.5617 - acc: 0.7610 - val_loss: 0.8299 - val_acc: 0.5178
# Epoch 33/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5611 - acc: 0.7609 - val_loss: 0.8306 - val_acc: 0.5178
# Epoch 34/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5597 - acc: 0.7610 - val_loss: 0.8311 - val_acc: 0.5178
# Epoch 35/120
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5608 - acc: 0.7610 - val_loss: 0.8310 - val_acc: 0.5178
# Epoch 36/120
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5585 - acc: 0.7610 - val_loss: 0.8313 - val_acc: 0.5178
# Epoch 37/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5593 - acc: 0.7611 - val_loss: 0.8319 - val_acc: 0.5178
# Epoch 38/120
# 8532/8532 [==============================] - 0s 28us/step - loss: 0.5613 - acc: 0.7607 - val_loss: 0.8316 - val_acc: 0.5178
# Epoch 39/120
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5599 - acc: 0.7611 - val_loss: 0.8319 - val_acc: 0.5178
# Epoch 40/120
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5627 - acc: 0.7615 - val_loss: 0.8318 - val_acc: 0.5178
# Epoch 41/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5588 - acc: 0.7608 - val_loss: 0.8317 - val_acc: 0.5178
# Epoch 42/120
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5625 - acc: 0.7610 - val_loss: 0.8320 - val_acc: 0.5178
# Epoch 43/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5605 - acc: 0.7610 - val_loss: 0.8317 - val_acc: 0.5178
# Epoch 44/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5616 - acc: 0.7608 - val_loss: 0.8321 - val_acc: 0.5178
# Epoch 45/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5584 - acc: 0.7609 - val_loss: 0.8324 - val_acc: 0.5178
# Epoch 46/120
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5589 - acc: 0.7611 - val_loss: 0.8325 - val_acc: 0.5178
# Epoch 47/120
# 8532/8532 [==============================] - ETA: 0s - loss: 0.5593 - acc: 0.760 - 0s 28us/step - loss: 0.5583 - acc: 0.7611 - val_loss: 0.8326 - val_acc: 0.5178
# Epoch 48/120
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5584 - acc: 0.7614 - val_loss: 0.8330 - val_acc: 0.5178
# Epoch 49/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5600 - acc: 0.7611 - val_loss: 0.8330 - val_acc: 0.5178
# Epoch 50/120
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5571 - acc: 0.7608 - val_loss: 0.8334 - val_acc: 0.5178
# Epoch 51/120
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5607 - acc: 0.7611 - val_loss: 0.8333 - val_acc: 0.5178
# Epoch 52/120
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5609 - acc: 0.7607 - val_loss: 0.8328 - val_acc: 0.5178
# Epoch 53/120
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5615 - acc: 0.7610 - val_loss: 0.8325 - val_acc: 0.5178
# Epoch 54/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5629 - acc: 0.7613 - val_loss: 0.8325 - val_acc: 0.5178
# Epoch 55/120
# 8532/8532 [==============================] - 0s 25us/step - loss: 0.5589 - acc: 0.7614 - val_loss: 0.8323 - val_acc: 0.5178
# Epoch 56/120
# 8532/8532 [==============================] - ETA: 0s - loss: 0.5540 - acc: 0.763 - 0s 28us/step - loss: 0.5567 - acc: 0.7611 - val_loss: 0.8324 - val_acc: 0.5178
# Epoch 57/120
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5620 - acc: 0.7611 - val_loss: 0.8321 - val_acc: 0.5178
# Epoch 58/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5585 - acc: 0.7611 - val_loss: 0.8319 - val_acc: 0.5178
# Epoch 59/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5608 - acc: 0.7610 - val_loss: 0.8321 - val_acc: 0.5178
# Epoch 60/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5639 - acc: 0.7610 - val_loss: 0.8320 - val_acc: 0.5178
# Epoch 61/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5594 - acc: 0.7610 - val_loss: 0.8325 - val_acc: 0.5178
# Epoch 62/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5579 - acc: 0.7613 - val_loss: 0.8325 - val_acc: 0.5178
# Epoch 63/120
# 8532/8532 [==============================] - 0s 25us/step - loss: 0.5633 - acc: 0.7609 - val_loss: 0.8321 - val_acc: 0.5178
# Epoch 64/120
# 8532/8532 [==============================] - 0s 29us/step - loss: 0.5614 - acc: 0.7611 - val_loss: 0.8317 - val_acc: 0.5178
# Epoch 65/120
# 8532/8532 [==============================] - 0s 31us/step - loss: 0.5607 - acc: 0.7611 - val_loss: 0.8318 - val_acc: 0.5178
# Epoch 66/120
# 8532/8532 [==============================] - 0s 28us/step - loss: 0.5606 - acc: 0.7610 - val_loss: 0.8320 - val_acc: 0.5178
# Epoch 67/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5617 - acc: 0.7613 - val_loss: 0.8319 - val_acc: 0.5178
# Epoch 68/120
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5578 - acc: 0.7611 - val_loss: 0.8324 - val_acc: 0.5178
# Epoch 69/120
# 8532/8532 [==============================] - ETA: 0s - loss: 0.5542 - acc: 0.762 - 0s 29us/step - loss: 0.5577 - acc: 0.7610 - val_loss: 0.8324 - val_acc: 0.5178
# Epoch 70/120
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5597 - acc: 0.7610 - val_loss: 0.8325 - val_acc: 0.5178
# Epoch 71/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5609 - acc: 0.7609 - val_loss: 0.8322 - val_acc: 0.5178
# Epoch 72/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5580 - acc: 0.7611 - val_loss: 0.8320 - val_acc: 0.5178
# Epoch 73/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5597 - acc: 0.7609 - val_loss: 0.8318 - val_acc: 0.5178
# Epoch 74/120
# 8532/8532 [==============================] - 0s 27us/step - loss: 0.5585 - acc: 0.7611 - val_loss: 0.8319 - val_acc: 0.5178
# Epoch 75/120
# 8532/8532 [==============================] - 0s 26us/step - loss: 0.5591 - acc: 0.7610 - val_loss: 0.8320 - val_acc: 0.5178
# Epoch 76/120
# ...
# Epoch 7/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.4597 - acc: 0.7736 - val_loss: 0.6892 - val_acc: 0.5673
# Epoch 8/60
# 8532/8532 [==============================] - 0s 36us/step - loss: 0.4295 - acc: 0.8098 - val_loss: 0.6634 - val_acc: 0.7075
# Epoch 9/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.4036 - acc: 0.8329 - val_loss: 0.9262 - val_acc: 0.6193
# Epoch 10/60
# 8532/8532 [==============================] - 0s 36us/step - loss: 0.3632 - acc: 0.8545 - val_loss: 0.7867 - val_acc: 0.6814
# Epoch 11/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.3430 - acc: 0.8618 - val_loss: 0.6905 - val_acc: 0.7271
# Epoch 12/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.3357 - acc: 0.8680 - val_loss: 0.6133 - val_acc: 0.7421
# Epoch 13/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.3356 - acc: 0.8671 - val_loss: 0.6016 - val_acc: 0.7421
# Epoch 14/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.3295 - acc: 0.8672 - val_loss: 0.5990 - val_acc: 0.7058
# Epoch 15/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.3204 - acc: 0.8724 - val_loss: 0.8846 - val_acc: 0.6439
# Epoch 16/60
# 8532/8532 [==============================] - 0s 37us/step - loss: 0.3236 - acc: 0.8754 - val_loss: 0.6760 - val_acc: 0.7337
# Epoch 17/60
# 8532/8532 [==============================] - ETA: 0s - loss: 0.3165 - acc: 0.879 - 0s 37us/step - loss: 0.3164 - acc: 0.8800 - val_loss: 0.6013 - val_acc: 0.7541
# Epoch 18/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.3149 - acc: 0.8779 - val_loss: 0.5960 - val_acc: 0.7562
# Epoch 19/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.3138 - acc: 0.8792 - val_loss: 0.6175 - val_acc: 0.7579
# Epoch 20/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.3112 - acc: 0.8816 - val_loss: 0.5999 - val_acc: 0.7586
# Epoch 21/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.3053 - acc: 0.8809 - val_loss: 0.5655 - val_acc: 0.7468
# Epoch 22/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.3083 - acc: 0.8809 - val_loss: 0.5634 - val_acc: 0.7560
# Epoch 23/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.3063 - acc: 0.8805 - val_loss: 0.6467 - val_acc: 0.7555
# Epoch 24/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.3058 - acc: 0.8829 - val_loss: 0.6213 - val_acc: 0.7562
# Epoch 25/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.3039 - acc: 0.8828 - val_loss: 0.5587 - val_acc: 0.7677
# Epoch 26/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.3037 - acc: 0.8827 - val_loss: 0.5471 - val_acc: 0.7696
# Epoch 27/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.3001 - acc: 0.8809 - val_loss: 0.5646 - val_acc: 0.7543
# Epoch 28/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.3010 - acc: 0.8834 - val_loss: 0.5520 - val_acc: 0.7710
# Epoch 29/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.2991 - acc: 0.8844 - val_loss: 0.5585 - val_acc: 0.7522
# Epoch 30/60
# 8532/8532 [==============================] - 0s 35us/step - loss: 0.2960 - acc: 0.8872 - val_loss: 0.6052 - val_acc: 0.7642
# Epoch 31/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.3012 - acc: 0.8851 - val_loss: 0.5744 - val_acc: 0.7286
# Epoch 32/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.2988 - acc: 0.8820 - val_loss: 0.5521 - val_acc: 0.7719
# Epoch 33/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.2968 - acc: 0.8843 - val_loss: 0.5748 - val_acc: 0.7743
# Epoch 34/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.2974 - acc: 0.8842 - val_loss: 0.5633 - val_acc: 0.7672
# Epoch 35/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.2918 - acc: 0.8861 - val_loss: 0.5591 - val_acc: 0.7722
# Epoch 36/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.2954 - acc: 0.8875 - val_loss: 0.5543 - val_acc: 0.7759
# Epoch 37/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.2922 - acc: 0.8862 - val_loss: 0.5864 - val_acc: 0.7740
# Epoch 38/60
# 8532/8532 [==============================] - 0s 39us/step - loss: 0.2922 - acc: 0.8884 - val_loss: 0.5828 - val_acc: 0.7757
# Epoch 39/60
# 8532/8532 [==============================] - 0s 35us/step - loss: 0.2964 - acc: 0.8817 - val_loss: 0.5976 - val_acc: 0.7658
# Epoch 40/60
# 8532/8532 [==============================] - 0s 32us/step - loss: 0.2985 - acc: 0.8864 - val_loss: 0.5857 - val_acc: 0.7689
# Epoch 41/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.2954 - acc: 0.8865 - val_loss: 0.5743 - val_acc: 0.7386
# Epoch 42/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.2912 - acc: 0.8843 - val_loss: 0.5856 - val_acc: 0.7166
# Epoch 43/60
# 8532/8532 [==============================] - ETA: 0s - loss: 0.2947 - acc: 0.886 - 0s 34us/step - loss: 0.2941 - acc: 0.8882 - val_loss: 0.5572 - val_acc: 0.7518
# Epoch 44/60
# 8532/8532 [==============================] - 0s 32us/step - loss: 0.2921 - acc: 0.8875 - val_loss: 0.5603 - val_acc: 0.7407
# Epoch 45/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.2900 - acc: 0.8881 - val_loss: 0.5377 - val_acc: 0.7778
# Epoch 46/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.2879 - acc: 0.8876 - val_loss: 0.5670 - val_acc: 0.7372
# Epoch 47/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.2904 - acc: 0.8882 - val_loss: 0.5406 - val_acc: 0.7588
# Epoch 48/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.2899 - acc: 0.8892 - val_loss: 0.5321 - val_acc: 0.7780
# Epoch 49/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.2880 - acc: 0.8868 - val_loss: 0.5624 - val_acc: 0.7794
# Epoch 50/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.2908 - acc: 0.8863 - val_loss: 0.6091 - val_acc: 0.7529
# Epoch 51/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.2891 - acc: 0.8894 - val_loss: 0.5326 - val_acc: 0.7733
# Epoch 52/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.2884 - acc: 0.8861 - val_loss: 0.5509 - val_acc: 0.7804
# Epoch 53/60
# 8532/8532 [==============================] - ETA: 0s - loss: 0.2875 - acc: 0.888 - 0s 34us/step - loss: 0.2891 - acc: 0.8870 - val_loss: 0.5340 - val_acc: 0.7642
# Epoch 54/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.2857 - acc: 0.8902 - val_loss: 0.5393 - val_acc: 0.7722
# Epoch 55/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.2887 - acc: 0.8867 - val_loss: 0.5341 - val_acc: 0.7586
# Epoch 56/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.2918 - acc: 0.8848 - val_loss: 0.5558 - val_acc: 0.7799
# Epoch 57/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.2841 - acc: 0.8864 - val_loss: 0.5569 - val_acc: 0.7801
# Epoch 58/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.2864 - acc: 0.8890 - val_loss: 0.6247 - val_acc: 0.7588
# Epoch 59/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.2870 - acc: 0.8870 - val_loss: 0.5298 - val_acc: 0.7771
# Epoch 60/60
# 8532/8532 [==============================] - ETA: 0s - loss: 0.2831 - acc: 0.886 - 0s 34us/step - loss: 0.2852 - acc: 0.8869 - val_loss: 0.5667 - val_acc: 0.7750
# 3200/3200 [==============================] - 0s 22us/step
# Train on 8532 samples, validate on 4266 samples
# Epoch 1/60
# 8532/8532 [==============================] - 2s 242us/step - loss: 0.5827 - acc: 0.7587 - val_loss: 0.7661 - val_acc: 0.5223
# Epoch 2/60
# 8532/8532 [==============================] - 0s 35us/step - loss: 0.5600 - acc: 0.7589 - val_loss: 0.7364 - val_acc: 0.5223
# Epoch 3/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.5568 - acc: 0.7589 - val_loss: 0.7538 - val_acc: 0.5223
# Epoch 4/60
# 8532/8532 [==============================] - 0s 37us/step - loss: 0.5429 - acc: 0.7589 - val_loss: 0.6923 - val_acc: 0.5223
# Epoch 5/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.5058 - acc: 0.7611 - val_loss: 0.6632 - val_acc: 0.5258
# Epoch 6/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.4726 - acc: 0.7800 - val_loss: 1.0446 - val_acc: 0.5258
# Epoch 7/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.4394 - acc: 0.8071 - val_loss: 0.7618 - val_acc: 0.5741
# Epoch 8/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.3909 - acc: 0.8411 - val_loss: 0.6042 - val_acc: 0.7264
# Epoch 9/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.3561 - acc: 0.8584 - val_loss: 0.6146 - val_acc: 0.7309
# Epoch 10/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.3436 - acc: 0.8645 - val_loss: 0.6050 - val_acc: 0.7150
# Epoch 11/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.3305 - acc: 0.8683 - val_loss: 0.6152 - val_acc: 0.7421
# Epoch 12/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.3473 - acc: 0.8635 - val_loss: 0.5988 - val_acc: 0.7065
# Epoch 13/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.3415 - acc: 0.8658 - val_loss: 0.6587 - val_acc: 0.7248
# Epoch 14/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.3361 - acc: 0.8684 - val_loss: 0.6102 - val_acc: 0.7325
# Epoch 15/60
# 8532/8532 [==============================] - 0s 35us/step - loss: 0.3190 - acc: 0.8739 - val_loss: 0.5761 - val_acc: 0.7407
# Epoch 16/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.3196 - acc: 0.8755 - val_loss: 0.5925 - val_acc: 0.7290
# Epoch 17/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.3191 - acc: 0.8744 - val_loss: 0.5725 - val_acc: 0.7541
# Epoch 18/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.3101 - acc: 0.8796 - val_loss: 0.5805 - val_acc: 0.7536
# Epoch 19/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.3082 - acc: 0.8795 - val_loss: 0.5802 - val_acc: 0.7588
# Epoch 20/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.3088 - acc: 0.8781 - val_loss: 0.5643 - val_acc: 0.7618
# Epoch 21/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.3070 - acc: 0.8792 - val_loss: 0.6938 - val_acc: 0.7194
# Epoch 22/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.2964 - acc: 0.8865 - val_loss: 0.5534 - val_acc: 0.7672
# Epoch 23/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.2994 - acc: 0.8860 - val_loss: 0.6131 - val_acc: 0.7250
# Epoch 24/60
# 8532/8532 [==============================] - 0s 35us/step - loss: 0.3016 - acc: 0.8827 - val_loss: 0.5647 - val_acc: 0.7344
# Epoch 25/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.3051 - acc: 0.8821 - val_loss: 0.6465 - val_acc: 0.7246
# Epoch 26/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.3080 - acc: 0.8806 - val_loss: 0.5590 - val_acc: 0.7522
# Epoch 27/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.2938 - acc: 0.8880 - val_loss: 0.5628 - val_acc: 0.7405
# Epoch 28/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.2994 - acc: 0.8829 - val_loss: 0.5478 - val_acc: 0.7609
# Epoch 29/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.2978 - acc: 0.8830 - val_loss: 0.5798 - val_acc: 0.7700
# Epoch 30/60
# 8532/8532 [==============================] - ETA: 0s - loss: 0.2976 - acc: 0.885 - 0s 34us/step - loss: 0.2955 - acc: 0.8863 - val_loss: 0.5462 - val_acc: 0.7707
# Epoch 31/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.2905 - acc: 0.8861 - val_loss: 0.5556 - val_acc: 0.7792
# Epoch 32/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.2944 - acc: 0.8831 - val_loss: 0.8316 - val_acc: 0.6899
# Epoch 33/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.2980 - acc: 0.8850 - val_loss: 0.5909 - val_acc: 0.7145
# Epoch 34/60
# 8532/8532 [==============================] - ETA: 0s - loss: 0.2940 - acc: 0.881 - 0s 34us/step - loss: 0.2917 - acc: 0.8844 - val_loss: 0.5440 - val_acc: 0.7766
# Epoch 35/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.2907 - acc: 0.8884 - val_loss: 0.5350 - val_acc: 0.7623
# Epoch 36/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.2870 - acc: 0.8898 - val_loss: 0.6131 - val_acc: 0.7070
# Epoch 37/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.2962 - acc: 0.8851 - val_loss: 0.6200 - val_acc: 0.7607
# Epoch 38/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.2911 - acc: 0.8863 - val_loss: 0.5388 - val_acc: 0.7675
# Epoch 39/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.2853 - acc: 0.8882 - val_loss: 0.6071 - val_acc: 0.7438
# Epoch 40/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.2883 - acc: 0.8880 - val_loss: 0.5502 - val_acc: 0.7623
# Epoch 41/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.2881 - acc: 0.8871 - val_loss: 0.5384 - val_acc: 0.7787
# Epoch 42/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.2889 - acc: 0.8865 - val_loss: 0.5497 - val_acc: 0.7775
# Epoch 43/60
# 8532/8532 [==============================] - 0s 35us/step - loss: 0.2822 - acc: 0.8925 - val_loss: 0.5437 - val_acc: 0.7496
# Epoch 44/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.2895 - acc: 0.8883 - val_loss: 0.6518 - val_acc: 0.7250
# Epoch 45/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.2837 - acc: 0.8887 - val_loss: 0.5459 - val_acc: 0.7532
# Epoch 46/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.2817 - acc: 0.8904 - val_loss: 0.5899 - val_acc: 0.7393
# Epoch 47/60
# 8532/8532 [==============================] - 0s 38us/step - loss: 0.2832 - acc: 0.8876 - val_loss: 0.6017 - val_acc: 0.7243
# Epoch 48/60
# 8532/8532 [==============================] - 0s 38us/step - loss: 0.2855 - acc: 0.8867 - val_loss: 0.5594 - val_acc: 0.7797
# Epoch 49/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.2815 - acc: 0.8880 - val_loss: 0.5960 - val_acc: 0.7461
# Epoch 50/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.2820 - acc: 0.8880 - val_loss: 0.5328 - val_acc: 0.7794
# Epoch 51/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.2877 - acc: 0.8870 - val_loss: 0.5334 - val_acc: 0.7764
# Epoch 52/60
# 8532/8532 [==============================] - 0s 36us/step - loss: 0.2847 - acc: 0.8885 - val_loss: 0.5528 - val_acc: 0.7611
# Epoch 53/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.2814 - acc: 0.8888 - val_loss: 0.6073 - val_acc: 0.7602
# Epoch 54/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.2819 - acc: 0.8863 - val_loss: 0.5760 - val_acc: 0.7700
# Epoch 55/60
# 8532/8532 [==============================] - 0s 33us/step - loss: 0.2784 - acc: 0.8884 - val_loss: 0.5503 - val_acc: 0.7651
# Epoch 56/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.2753 - acc: 0.8904 - val_loss: 0.8323 - val_acc: 0.6585
# Epoch 57/60
# 8532/8532 [==============================] - 0s 37us/step - loss: 0.2768 - acc: 0.8919 - val_loss: 0.5584 - val_acc: 0.7733
# Epoch 58/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.2749 - acc: 0.8899 - val_loss: 0.5311 - val_acc: 0.7789
# Epoch 59/60
# 8532/8532 [==============================] - 0s 36us/step - loss: 0.2739 - acc: 0.8918 - val_loss: 0.5842 - val_acc: 0.7743
# Epoch 60/60
# 8532/8532 [==============================] - 0s 34us/step - loss: 0.2768 - acc: 0.8906 - val_loss: 0.5348 - val_acc: 0.7672
# 3200/3200 [==============================] - 0s 23us/step

# %%
def SVM_linear(X_train, Y_train, X_test, C):
    gamma_range = np.logspace(-9, 3, 13)
    param_grid = dict(gamma=gamma_range)
    cv = StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=42)
    grid = GridSearchCV(SVC(cache_size=2048), param_grid=param_grid, cv=cv, n_jobs=4)
    grid.fit(X_train, Y_train)

    print("The best parameters are %s with a score of %0.2f"
      % (grid.best_params_, grid.best_score_))

    clf = SVC(C=C, gamma=grid.best_params_['gamma'], class_weight='balanced', kernel='linear')
    clf.fit(X_train, Y_train)
    
    Y_pred = clf.predict(X_test)
    return Y_pred

def SVM_rbf(X_train, Y_train, X_test, C, gamma):

    clf = SVC(C=C, gamma=gamma, kernel='rbf')
    clf.fit(X_train, Y_train)
    
    Y_pred = clf.predict(X_test)
    return Y_pred

def SVM(array):
    array_train, array_test = SplitVectorData_NoVal(array, 0.8)
    X_train, Y_train, X_val, Y_val, X_test, Y_test = SplitLabelsFromPrimitives(array_train, array_test, array_test) #Val N,est pas utilisé, mais la méthode èa besoin du paremèetre. On lui passe donc les données tests.
    
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    
    Y_pred_lin03= SVM_linear(X_train, Y_train, X_test, 1e-03)
    Y_pred_lin01= SVM_linear(X_train, Y_train, X_test, 1e-01)
    Y_pred_lin1= SVM_linear(X_train, Y_train, X_test, 1.0)
    Y_pred_lin10= SVM_linear(X_train, Y_train, X_test, 10.0)
    Y_pred_rbf03_g03= SVM_rbf(X_train, Y_train, X_test, 1e-03, 1e-03)
    Y_pred_rbf01_g03= SVM_rbf(X_train, Y_train, X_test, 1e-01, 1e-03)
    Y_pred_rbf1_g03= SVM_rbf(X_train, Y_train, X_test, 1.0, 1e-03)
    Y_pred_rbf10_g03= SVM_rbf(X_train, Y_train, X_test, 10.0, 1e-03)
    Y_pred_rbf03_g01= SVM_rbf(X_train, Y_train, X_test, 1e-03, 1e-01)
    Y_pred_rbf01_g01= SVM_rbf(X_train, Y_train, X_test, 1e-01, 1e-01)
    Y_pred_rbf1_g01= SVM_rbf(X_train, Y_train, X_test, 1.0, 1e-01)
    Y_pred_rbf10_g01= SVM_rbf(X_train, Y_train, X_test, 10.0, 1e-01)
    Y_pred_rbf03_g1= SVM_rbf(X_train, Y_train, X_test, 1e-03, 1.0)
    Y_pred_rbf01_g1= SVM_rbf(X_train, Y_train, X_test, 1e-01, 1.0)
    Y_pred_rbf1_g1= SVM_rbf(X_train, Y_train, X_test, 1.0, 1.0)
    Y_pred_rbf10_g1= SVM_rbf(X_train, Y_train, X_test, 10.0, 1.0)
    Y_pred_rbf03_g10= SVM_rbf(X_train, Y_train, X_test, 1e-03, 10.0)
    Y_pred_rbf01_g10= SVM_rbf(X_train, Y_train, X_test, 1e-01, 10.0)
    Y_pred_rbf1_g10= SVM_rbf(X_train, Y_train, X_test, 1.0, 10.0)
    Y_pred_rbf10_g10= SVM_rbf(X_train, Y_train, X_test, 10.0, 10.0)
    
    validations = [[Y_test, Y_pred_lin03],
    [Y_test, Y_pred_lin01],
    [Y_test, Y_pred_lin1],
    [Y_test, Y_pred_lin10],             
    [Y_test, Y_pred_rbf03_g03],
    [Y_test, Y_pred_rbf01_g03],
    [Y_test, Y_pred_rbf1_g03],
    [Y_test, Y_pred_rbf10_g03],            
    [Y_test, Y_pred_rbf03_g01],
    [Y_test, Y_pred_rbf01_g01],
    [Y_test, Y_pred_rbf1_g01],
    [Y_test, Y_pred_rbf10_g01],              
    [Y_test, Y_pred_rbf03_g1],
    [Y_test, Y_pred_rbf01_g1],
    [Y_test, Y_pred_rbf1_g1],
    [Y_test, Y_pred_rbf10_g1],            
    [Y_test, Y_pred_rbf03_g10],
    [Y_test, Y_pred_rbf01_g10],
    [Y_test, Y_pred_rbf1_g10],
    [Y_test, Y_pred_rbf10_g10]]
    
    return GenerateScores(validations)

# %%
acc_svm, f1_svm = SVM(Galaxies)
# Out:
# The best parameters are {'gamma': 0.1} with a score of 0.83
# The best parameters are {'gamma': 0.1} with a score of 0.83
# The best parameters are {'gamma': 0.1} with a score of 0.83
# The best parameters are {'gamma': 0.1} with a score of 0.83

# %%
# For Debugging
#print(acc_svm)
#print(f1_svm)
#print(acc_neurone_holdout)
#print(f1_neurone_holdout)
#print(acc_neurone_kfold)
#print(f1_neurone_kfold)

# %%
def AddAccAndF1ToExcel(name, acc, f1, c_acc, c_f1):
    acc_new = pd.DataFrame({'acc': acc})
    f1_new = pd.DataFrame({'f1': f1})
    wb = load_workbook(name)

    ws = wb['Feuil1']

    for index, row in acc_new.iterrows():
        cell =  c_acc+'%d'  % (index + 2)
        ws[cell] = row[0]
        
    for index, row in f1_new.iterrows():
        cell = c_f1 + '%d'  % (index + 2)
        ws[cell] = row[0]

    wb.save(name)


    return pd.read_excel(name, index_col=0)

svm = AddAccAndF1ToExcel('svm.xlsx', acc_svm, f1_svm, 'D', 'E')
rn_holdout = AddAccAndF1ToExcel('rn_holdout.xlsx', acc_neurone_holdout, f1_neurone_holdout, 'F', 'G')
rn_kfold = AddAccAndF1ToExcel('rn_kfold.xlsx', acc_neurone_kfold, f1_neurone_kfold, 'F', 'G')

# %% [markdown]
# # Rapport

# %% [markdown]
# 1

# %% [markdown]
# 2

# %% [markdown]
# 3

# %% [markdown]
# 4

# %% [markdown]
# 5

# %% [markdown]
# 6

# %% [markdown]
# 7

# %% [markdown]
# 8

# %% [markdown]
# 9

# %% [markdown]
# # Annexe

# %% [markdown]
# ## Réseau neuronaux en modifiant le nombre de couches total

# %% [markdown]
# <img src="rn_layer.png">

# %% [markdown]
# ## Réseau neuronaux en modifiant le nombre de perceptrons dans couche cachée

# %% [markdown]
# <img src="rn_perc.png">

# %% [markdown]
# ## Réseau neuronaux en modifiant le nombre d'itération

# %% [markdown]
# <img src="rn_epoch.png">

# %% [markdown]
# ## Réseau neuronaux en modifiant le taux d'apprentissage

# %% [markdown]
# <img src="rn_lr.png">

# %% [markdown]
# ###  Tableau: Réseau neuronaux avec validation Holdout

# %%
rn_holdout.head(100)
# Out:
#         Layers  Perceptrons  Epochs  Learning Rate  Accuracy        F1
# Title
# base         4          100      60         0.0005  0.420625  0.592169
# perc1        4           50      60         0.0005  0.420625  0.592169
# perc2        4          300      60         0.0005  0.420625  0.592169
# perc3        4          600      60         0.0005  0.420625  0.592169
# epoch1       4          100      30         0.0005  0.420625  0.592169
# epoch2       4          100     120         0.0005  0.420625  0.592169
# epoch3       4          100     240         0.0005  0.420625  0.592169
# layer1       6          100      60         0.0005  0.420625  0.592169
# layer2      12          100      60         0.0005  0.420625  0.592169
# layer3      24          100      60         0.0005  0.420625  0.592169
# lr1          4          100      60         0.1000  0.737812  0.739444
# lr2          4          100      60         0.5000  0.781250  0.782618
# lr3          4          100      60         1.0000  0.785625  0.786886

# %% [markdown]
# ### Tableau 2: Réseau neuronaux avec validation K_Fold(3)

# %%
rn_kfold.head(100)
# Out:
#         Layers  Perceptrons  Epochs  Learning Rate  Accuracy        F1
# Title
# base         4          100      60         0.0005  0.280417  0.394779
# perc1        4           50      60         0.0005  0.280417  0.394779
# perc2        4          300      60         0.0005  0.280417  0.394779
# perc3        4          600      60         0.0005  0.280417  0.394779
# epoch1       4          100      30         0.0005  0.280417  0.394779
# epoch2       4          100     120         0.0005  0.280417  0.394779
# epoch3       4          100     240         0.0005  0.280417  0.394779
# layer1       6          100      60         0.0005  0.280417  0.394779
# layer2      12          100      60         0.0005  0.280417  0.394779
# layer3      24          100      60         0.0005  0.280417  0.394779
# lr1          4          100      60         0.1000  0.499271  0.499966
# lr2          4          100      60         0.5000  0.514479  0.515291
# lr3          4          100      60         1.0000  0.525938  0.526212

# %% [markdown]
# ### Tableau 3: SVM

# %%
svm.head(100)
# Out:
#              C   Gamma  Accuracy        F1
# Kernel
# linear   0.001   0.100  0.733354  0.734472
# linear   0.100   0.100  0.796186  0.797327
# linear   1.000   0.100  0.796186  0.797365
# linear  10.000   0.100  0.795874  0.797057
# rbf      0.001   0.001  0.420756  0.592299
# rbf      0.100   0.001  0.663332  0.658722
# rbf      1.000   0.001  0.750234  0.751792
# rbf     10.000   0.001  0.799937  0.801157
# rbf      0.001   0.100  0.551422  0.496336
# rbf      0.100   0.100  0.815880  0.816874
# rbf      1.000   0.100  0.826508  0.827470
# rbf     10.000   0.100  0.833698  0.834665
# rbf      0.001   1.000  0.420756  0.592299
# rbf      0.100   1.000  0.818068  0.819173
# rbf      1.000   1.000  0.827446  0.828510
# rbf     10.000   1.000  0.820882  0.821968
# rbf      0.001  10.000  0.420756  0.592299
# rbf      0.100  10.000  0.493592  0.395615
# rbf      1.000  10.000  0.773367  0.774527
# rbf     10.000  10.000  0.744295  0.745691
